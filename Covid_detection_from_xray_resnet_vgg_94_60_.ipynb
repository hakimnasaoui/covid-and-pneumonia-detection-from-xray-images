# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/ieee8023/covid-chestxray-dataset.git
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 3229 (delta 9), reused 4 (delta 2), pack-reused 3213
# Receiving objects: 100% (3229/3229), 582.70 MiB | 25.70 MiB/s, done.
# Resolving deltas: 100% (1285/1285), done.
# Checking out files: 100% (987/987), done.

# %%
# !mkdir -p /content/dataset/covid/
# !mkdir -p /content/dataset/normal/
# !mkdir -p /content/dataset/pneumonia/

# %%
# !unzip "/content/drive/My Drive/Datasets/Chest X-Ray Images (Pneumonia).zip"

# %%
# !mv /content/chest_xray/train/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/train/PNEUMONIA/* /content/dataset/pneumonia/
# !mv /content/chest_xray/val/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/val/PNEUMONIA/* /content/dataset/pneumonia/
# !mv /content/chest_xray/test/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/test/PNEUMONIA/* /content/dataset/pneumonia/

# %%
import pandas as pd
import shutil
import os

# Selecting all combination of 'COVID-19' patients with 'PA' X-Ray view
virus = "COVID-19" # Virus to look for
x_ray_view = "PA" # View of X-Ray

meta_data = "/content/covid-chestxray-dataset/metadata.csv"
images_dir = "/content/covid-chestxray-dataset/images"
output_dir = "/content/dataset/covid/"

metadata_csv = pd.read_csv(meta_data)

for (i, row) in metadata_csv.iterrows():
	if row["finding"] != virus or row["view"] != x_ray_view:
		continue

	filename = row["filename"].split(os.path.sep)[-1]
	filePath = os.path.sep.join([images_dir, filename])
	shutil.copy2(filePath, output_dir)

# %%
# !git clone https://github.com/UCSD-AI4H/COVID-CT.git

# %%
# !unzip /content/COVID-CT/Images-processed/CT_COVID.zip
# !unzip /content/COVID-CT/Images-processed/CT_NonCOVID.zip

# %%
# !mv /content/CT_COVID/* /content/dataset/covid/

# %%
# !unzip "/content/drive/My Drive/Datasets/COVID19/COV-Img.zip"

# %%
# !mkdir -p /content/test/covid/

# %%
# !mv /content/COV-Img/* /content/test/covid/

# %% [markdown]
#   ## Dependencies

# %%
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Input, average, Average, concatenate
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense

from keras.models import Sequential, Model
from keras.applications.xception import Xception
from keras.applications.resnet50 import ResNet50
from keras.applications import ResNet101
from keras.applications import DenseNet201
from keras.applications import MobileNet
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.optimizers import Adam, SGD, RMSprop

import tensorflow as tf

import os
import numpy as np
import pandas as pd
import time

import random

from PIL import Image
import glob
import matplotlib.pyplot as plt
from matplotlib import pyplot
import matplotlib.image as mpimg
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
DATASET_DIR = "/content/dataset"

NORMAL_DIR = DATASET_DIR + "/normal"
PNEUMONIA_DIR = DATASET_DIR + "/pneumonia"
COVID_DIR = DATASET_DIR + "/covid"

NORMAL_TRAIN_SAMPLES = 1200 # total samples = 1583
PNEUMONIA_TRAIN_SAMPLES = 2000 # total samples = 4273
COVID_TRAIN_SAMPLES = 160 # total samples = 201

IMG_W = 224
IMG_H = 224
IMG_C = 1
INPUT_SHAPE = (IMG_W, IMG_H, IMG_C)

CLASSES = [ "NORMAL", "PNEUMONIA", "COVID" ]
NB_CLASSES = len(CLASSES)

EPOCHS = 3
BATCH_SIZE = 16

# %%
normal_images = []
pneumonia_images = []
covid_images = []

# %%
for img_path in glob.glob(NORMAL_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    # img = img / 255.
    normal_images.append(img[:np.newaxis])

for img_path in glob.glob(PNEUMONIA_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    # img = img / 255.
    pneumonia_images.append(img[:np.newaxis])

for img_path in glob.glob(COVID_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    # img = img / 255.
    covid_images.append(img[:np.newaxis])

# %%
len(normal_images), len(pneumonia_images), len(covid_images)
# Out:
# (1583, 4273, 204)

# %%
width=150
height=150
rows = 1
cols = 3

imgs = [ normal_images[0], pneumonia_images[0], covid_images[0]]

axes=[]
fig=plt.figure()

for i in range(rows*cols):
    img = imgs[i]
    axes.append( fig.add_subplot(rows, cols, i+1) )
    plt.imshow(img)

axes[0].set_title('NORMAL')
axes[1].set_title('PNEUMONIA')
axes[2].set_title('COVID')
fig.tight_layout()    
plt.show()

# %%
normal_X = []
pneumonia_X = []
covid_X = []
normal_y = []
pneumonia_y = []
covid_y = []
X = []
y = []

for item in normal_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    normal_X.append(img)    
    normal_y.append(CLASSES.index("NORMAL"))   
    X.append(img)    
    y.append(CLASSES.index("NORMAL"))

for item in pneumonia_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    pneumonia_X.append(img)    
    pneumonia_y.append(CLASSES.index("PNEUMONIA"))   
    X.append(img)    
    y.append(CLASSES.index("PNEUMONIA"))

for item in covid_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    covid_X.append(img) 
    covid_y.append(CLASSES.index("COVID"))   
    X.append(img)    
    y.append(CLASSES.index("COVID"))

X = np.asarray(X)
y = np.asarray(y)

# %%
X.shape, y.shape
# Out:
# ((6060, 224, 224, 1), (6060,))

# %%
X_train_normal = normal_X[:NORMAL_TRAIN_SAMPLES]
X_train_pneumonia = pneumonia_X[:PNEUMONIA_TRAIN_SAMPLES]
X_train_covid = covid_X[:COVID_TRAIN_SAMPLES]
X_test_normal = normal_X[NORMAL_TRAIN_SAMPLES:]
X_test_pneumonia = pneumonia_X[PNEUMONIA_TRAIN_SAMPLES:]
X_test_covid = covid_X[COVID_TRAIN_SAMPLES:]

y_train_normal = normal_y[:NORMAL_TRAIN_SAMPLES]
y_train_pneumonia = pneumonia_y[:PNEUMONIA_TRAIN_SAMPLES]
y_train_covid = covid_y[:COVID_TRAIN_SAMPLES]
y_test_normal = normal_y[NORMAL_TRAIN_SAMPLES:]
y_test_pneumonia = pneumonia_y[PNEUMONIA_TRAIN_SAMPLES:]
y_test_covid = covid_y[COVID_TRAIN_SAMPLES:]


X_train = np.concatenate((X_train_normal, X_train_pneumonia, X_train_covid), axis=0) 
y_train = np.concatenate((y_train_normal, y_train_pneumonia, y_train_covid), axis=0) 

X_test = np.concatenate((X_test_normal, X_test_pneumonia, X_test_covid), axis=0) 
y_test = np.concatenate((y_test_normal, y_test_pneumonia, y_test_covid), axis=0)

# %%
# np.full((len(X_train_normal), 1), y_test_normal[0]).shape

# %%
X_train.shape, y_train.shape
# Out:
# ((3360, 224, 224, 1), (3360,))

# %%
X_test.shape, y_test.shape
# Out:
# ((2700, 224, 224, 1), (2700,))

# %%
a = list(zip(X_train, y_train))
random.shuffle(a)
X_train, y_train = zip(*a)
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
# a = list(zip(X_train, y_train))
# random.shuffle(a)
# X_test, y_test = zip(*a)

# %%
X_train.shape, y_train.shape
# Out:
# ((3360, 224, 224, 1), (3360,))

# %%
from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.2, random_state=2020)


# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2

# %%
# ----------------------

# %%
X_train = np.repeat(X_train[...,], 3, 3)
X_val = np.repeat(X_val[...,], 3, 3)
X_test = np.repeat(X_test[...,], 3, 3)

# %%
X_train.shape, y_train.shape
# Out:
# ((2520, 224, 224, 3), (2520,))

# %%
X_val.shape, y_val.shape
# Out:
# ((840, 224, 224, 3), (840,))

# %%
X_test.shape, y_test.shape
# Out:
# ((2700, 224, 224, 3), (2700,))

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1, 2]), array([ 887, 1519,  114]))

# %%
np.unique(y_test, return_counts=True)
# Out:
# (array([0, 1, 2]), array([ 383, 2273,   44]))

# %%
from keras.utils import to_categorical

y_train = to_categorical(y_train)
y_val = to_categorical(y_val)
y_test = to_categorical(y_test)

# %%
train_da_args = dict(rescale=1./255, 
               shear_range=0.2,
               zoom_range=0.05,
               width_shift_range=0.05,
               height_shift_range=0.05,
               rotation_range=360,
               #  brightness_range=[0.2,1.0],
               vertical_flip=True,
               horizontal_flip=True)

# val_da_args = dict(rescale=1./255)

train_da = ImageDataGenerator(train_da_args)
# val_da = ImageDataGenerator(val_da_args)

train_da.fit(X_train, augment=True)
# val_da.fit(X_train)

train_gen = train_da.flow(X_train, y_train, batch_size=BATCH_SIZE)
# val_gen = train_da.flow(X_val, y_val)

# %%
for i in range(9):
	pyplot.subplot(330 + 1 + i)
	batch = train_gen.next()
	image = batch[0][0].astype('uint8')
	pyplot.imshow(image)

pyplot.show()

# %%
for i in range(9):
	
	pyplot.subplot(330 + 1 + i)
	batch = train_gen.next()
	image = batch[0][-1].astype('uint8')
	pyplot.imshow(image)

pyplot.show()

# %%
# augmented_data = []
# num_augmented = 0
# for X_batch, y_batch in train_da.flow(X_train, y_train, batch_size=BATCH_SIZE, shuffle=False):
#     augmented_data.append(X_batch)
#     num_augmented += BATCH_SIZE
#     if num_augmented == X_train.shape[0]:
#         break
# augmented_data = np.concatenate(augmented_data)

# %%
# -------------------------

# %%
# len(train_gen.x)

# %%
# vgg_model = VGG16(weights='imagenet', 
#                         include_top=False, 
#                         input_shape=(IMG_H, IMG_W, 3))

# for layer in vgg_model.layers:
#     if isinstance(layer, BatchNormalization):
#         layer.trainable = True
#     else:
#         layer.trainable = False

# model = Sequential()
# model.add(vgg_model)
# model.add(GlobalAveragePooling2D())
# model.add(Dense(256, activation='relu'))
# model.add(Dropout(0.5))
# model.add(BatchNormalization())
# model.add(Dense(NB_CLASSES, activation='softmax'))

# %%
models_input = Input(shape=(IMG_H, IMG_W, 3))


resnet_model = ResNet50(weights='imagenet', 
                        include_top=False, 
                        input_tensor=models_input)

for layer in resnet_model.layers:
    layer.name = "resnet50_" + layer.name
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False
        
        
resnet_gap = GlobalAveragePooling2D()(resnet_model.output)

# x = Dense(256)(x)
# x = Activation('relu')(x)
# x = Dropout(0.5)(x)
# x = Activation('relu')(x)
# x = BatchNormalization()(x)
# x = Dense(NB_CLASSES)(x)
# out = Activation('softmax')(x)
# resnet_model = Model(inputs=resnet_model.input, outputs=out)


vgg_model = VGG16(weights='imagenet', 
                        include_top=False, 
                        input_tensor=models_input)

for layer in vgg_model.layers:
    layer.name = "vgg16_" + layer.name
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False

        
vgg_gap = GlobalAveragePooling2D()(vgg_model.output)

# # x = GlobalAveragePooling2D()(vgg_model.output)
# x = Dense(256)(vgg_gap)
# x = Activation('relu')(x)
# x = Dropout(0.5)(x)
# x = Activation('relu')(x)
# vgg_out = BatchNormalization()(x)
# x = Dense(NB_CLASSES)(x)
# out = Activation('softmax')(x)

merged_nets = concatenate([resnet_gap, vgg_gap])

x = Dense(NB_CLASSES)(merged_nets)
out = Activation('softmax')(x)

inputs = input_tensor=models_input
outputs = out # out # average([resnet_model.output, vgg_model.output])
model = Model(inputs, outputs)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
# model.compile(loss='categorical_crossentropy',
#               optimizer='adam',
#               metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# vgg16_resnet50_input_4 (InputLa (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# resnet50_conv1_pad (ZeroPadding (None, 230, 230, 3)  0           vgg16_resnet50_input_4[0][0]
# __________________________________________________________________________________________________
# resnet50_conv1 (Conv2D)         (None, 112, 112, 64) 9472        resnet50_conv1_pad[0][0]
# __________________________________________________________________________________________________
# resnet50_bn_conv1 (BatchNormali (None, 112, 112, 64) 256         resnet50_conv1[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_151 (Activa (None, 112, 112, 64) 0           resnet50_bn_conv1[0][0]
# __________________________________________________________________________________________________
# resnet50_pool1_pad (ZeroPadding (None, 114, 114, 64) 0           resnet50_activation_151[0][0]
# __________________________________________________________________________________________________
# resnet50_max_pooling2d_4 (MaxPo (None, 56, 56, 64)   0           resnet50_pool1_pad[0][0]
# __________________________________________________________________________________________________
# resnet50_res2a_branch2a (Conv2D (None, 56, 56, 64)   4160        resnet50_max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2a_branch2a (BatchNo (None, 56, 56, 64)   256         resnet50_res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_152 (Activa (None, 56, 56, 64)   0           resnet50_bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res2a_branch2b (Conv2D (None, 56, 56, 64)   36928       resnet50_activation_152[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2a_branch2b (BatchNo (None, 56, 56, 64)   256         resnet50_res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_153 (Activa (None, 56, 56, 64)   0           resnet50_bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res2a_branch2c (Conv2D (None, 56, 56, 256)  16640       resnet50_activation_153[0][0]
# __________________________________________________________________________________________________
# resnet50_res2a_branch1 (Conv2D) (None, 56, 56, 256)  16640       resnet50_max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2a_branch2c (BatchNo (None, 56, 56, 256)  1024        resnet50_res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2a_branch1 (BatchNor (None, 56, 56, 256)  1024        resnet50_res2a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_add_49 (Add)           (None, 56, 56, 256)  0           resnet50_bn2a_branch2c[0][0]
#                                                                  resnet50_bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_154 (Activa (None, 56, 56, 256)  0           resnet50_add_49[0][0]
# __________________________________________________________________________________________________
# resnet50_res2b_branch2a (Conv2D (None, 56, 56, 64)   16448       resnet50_activation_154[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2b_branch2a (BatchNo (None, 56, 56, 64)   256         resnet50_res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_155 (Activa (None, 56, 56, 64)   0           resnet50_bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res2b_branch2b (Conv2D (None, 56, 56, 64)   36928       resnet50_activation_155[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2b_branch2b (BatchNo (None, 56, 56, 64)   256         resnet50_res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_156 (Activa (None, 56, 56, 64)   0           resnet50_bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res2b_branch2c (Conv2D (None, 56, 56, 256)  16640       resnet50_activation_156[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2b_branch2c (BatchNo (None, 56, 56, 256)  1024        resnet50_res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_50 (Add)           (None, 56, 56, 256)  0           resnet50_bn2b_branch2c[0][0]
#                                                                  resnet50_activation_154[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_157 (Activa (None, 56, 56, 256)  0           resnet50_add_50[0][0]
# __________________________________________________________________________________________________
# resnet50_res2c_branch2a (Conv2D (None, 56, 56, 64)   16448       resnet50_activation_157[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2c_branch2a (BatchNo (None, 56, 56, 64)   256         resnet50_res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_158 (Activa (None, 56, 56, 64)   0           resnet50_bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res2c_branch2b (Conv2D (None, 56, 56, 64)   36928       resnet50_activation_158[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2c_branch2b (BatchNo (None, 56, 56, 64)   256         resnet50_res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_159 (Activa (None, 56, 56, 64)   0           resnet50_bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res2c_branch2c (Conv2D (None, 56, 56, 256)  16640       resnet50_activation_159[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2c_branch2c (BatchNo (None, 56, 56, 256)  1024        resnet50_res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_51 (Add)           (None, 56, 56, 256)  0           resnet50_bn2c_branch2c[0][0]
#                                                                  resnet50_activation_157[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_160 (Activa (None, 56, 56, 256)  0           resnet50_add_51[0][0]
# __________________________________________________________________________________________________
# resnet50_res3a_branch2a (Conv2D (None, 28, 28, 128)  32896       resnet50_activation_160[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3a_branch2a (BatchNo (None, 28, 28, 128)  512         resnet50_res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_161 (Activa (None, 28, 28, 128)  0           resnet50_bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res3a_branch2b (Conv2D (None, 28, 28, 128)  147584      resnet50_activation_161[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3a_branch2b (BatchNo (None, 28, 28, 128)  512         resnet50_res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_162 (Activa (None, 28, 28, 128)  0           resnet50_bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res3a_branch2c (Conv2D (None, 28, 28, 512)  66048       resnet50_activation_162[0][0]
# __________________________________________________________________________________________________
# resnet50_res3a_branch1 (Conv2D) (None, 28, 28, 512)  131584      resnet50_activation_160[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3a_branch2c (BatchNo (None, 28, 28, 512)  2048        resnet50_res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3a_branch1 (BatchNor (None, 28, 28, 512)  2048        resnet50_res3a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_add_52 (Add)           (None, 28, 28, 512)  0           resnet50_bn3a_branch2c[0][0]
#                                                                  resnet50_bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_163 (Activa (None, 28, 28, 512)  0           resnet50_add_52[0][0]
# __________________________________________________________________________________________________
# resnet50_res3b_branch2a (Conv2D (None, 28, 28, 128)  65664       resnet50_activation_163[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3b_branch2a (BatchNo (None, 28, 28, 128)  512         resnet50_res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_164 (Activa (None, 28, 28, 128)  0           resnet50_bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res3b_branch2b (Conv2D (None, 28, 28, 128)  147584      resnet50_activation_164[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3b_branch2b (BatchNo (None, 28, 28, 128)  512         resnet50_res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_165 (Activa (None, 28, 28, 128)  0           resnet50_bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res3b_branch2c (Conv2D (None, 28, 28, 512)  66048       resnet50_activation_165[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3b_branch2c (BatchNo (None, 28, 28, 512)  2048        resnet50_res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_53 (Add)           (None, 28, 28, 512)  0           resnet50_bn3b_branch2c[0][0]
#                                                                  resnet50_activation_163[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_166 (Activa (None, 28, 28, 512)  0           resnet50_add_53[0][0]
# __________________________________________________________________________________________________
# resnet50_res3c_branch2a (Conv2D (None, 28, 28, 128)  65664       resnet50_activation_166[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3c_branch2a (BatchNo (None, 28, 28, 128)  512         resnet50_res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_167 (Activa (None, 28, 28, 128)  0           resnet50_bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res3c_branch2b (Conv2D (None, 28, 28, 128)  147584      resnet50_activation_167[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3c_branch2b (BatchNo (None, 28, 28, 128)  512         resnet50_res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_168 (Activa (None, 28, 28, 128)  0           resnet50_bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res3c_branch2c (Conv2D (None, 28, 28, 512)  66048       resnet50_activation_168[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3c_branch2c (BatchNo (None, 28, 28, 512)  2048        resnet50_res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_54 (Add)           (None, 28, 28, 512)  0           resnet50_bn3c_branch2c[0][0]
#                                                                  resnet50_activation_166[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_169 (Activa (None, 28, 28, 512)  0           resnet50_add_54[0][0]
# __________________________________________________________________________________________________
# resnet50_res3d_branch2a (Conv2D (None, 28, 28, 128)  65664       resnet50_activation_169[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3d_branch2a (BatchNo (None, 28, 28, 128)  512         resnet50_res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_170 (Activa (None, 28, 28, 128)  0           resnet50_bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res3d_branch2b (Conv2D (None, 28, 28, 128)  147584      resnet50_activation_170[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3d_branch2b (BatchNo (None, 28, 28, 128)  512         resnet50_res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_171 (Activa (None, 28, 28, 128)  0           resnet50_bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res3d_branch2c (Conv2D (None, 28, 28, 512)  66048       resnet50_activation_171[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3d_branch2c (BatchNo (None, 28, 28, 512)  2048        resnet50_res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_55 (Add)           (None, 28, 28, 512)  0           resnet50_bn3d_branch2c[0][0]
#                                                                  resnet50_activation_169[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_172 (Activa (None, 28, 28, 512)  0           resnet50_add_55[0][0]
# __________________________________________________________________________________________________
# resnet50_res4a_branch2a (Conv2D (None, 14, 14, 256)  131328      resnet50_activation_172[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4a_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_173 (Activa (None, 14, 14, 256)  0           resnet50_bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res4a_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_173[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4a_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_174 (Activa (None, 14, 14, 256)  0           resnet50_bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res4a_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_174[0][0]
# __________________________________________________________________________________________________
# resnet50_res4a_branch1 (Conv2D) (None, 14, 14, 1024) 525312      resnet50_activation_172[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4a_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4a_branch1 (BatchNor (None, 14, 14, 1024) 4096        resnet50_res4a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_add_56 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4a_branch2c[0][0]
#                                                                  resnet50_bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_175 (Activa (None, 14, 14, 1024) 0           resnet50_add_56[0][0]
# __________________________________________________________________________________________________
# resnet50_res4b_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_175[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4b_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_176 (Activa (None, 14, 14, 256)  0           resnet50_bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res4b_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_176[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4b_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_177 (Activa (None, 14, 14, 256)  0           resnet50_bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res4b_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_177[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4b_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_57 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4b_branch2c[0][0]
#                                                                  resnet50_activation_175[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_178 (Activa (None, 14, 14, 1024) 0           resnet50_add_57[0][0]
# __________________________________________________________________________________________________
# resnet50_res4c_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_178[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4c_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_179 (Activa (None, 14, 14, 256)  0           resnet50_bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res4c_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_179[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4c_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_180 (Activa (None, 14, 14, 256)  0           resnet50_bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res4c_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_180[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4c_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_58 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4c_branch2c[0][0]
#                                                                  resnet50_activation_178[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_181 (Activa (None, 14, 14, 1024) 0           resnet50_add_58[0][0]
# __________________________________________________________________________________________________
# resnet50_res4d_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_181[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4d_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_182 (Activa (None, 14, 14, 256)  0           resnet50_bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res4d_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_182[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4d_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_183 (Activa (None, 14, 14, 256)  0           resnet50_bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res4d_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_183[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4d_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_59 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4d_branch2c[0][0]
#                                                                  resnet50_activation_181[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_184 (Activa (None, 14, 14, 1024) 0           resnet50_add_59[0][0]
# __________________________________________________________________________________________________
# resnet50_res4e_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_184[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4e_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_185 (Activa (None, 14, 14, 256)  0           resnet50_bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res4e_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_185[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4e_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_186 (Activa (None, 14, 14, 256)  0           resnet50_bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res4e_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_186[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4e_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_60 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4e_branch2c[0][0]
#                                                                  resnet50_activation_184[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_187 (Activa (None, 14, 14, 1024) 0           resnet50_add_60[0][0]
# __________________________________________________________________________________________________
# resnet50_res4f_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_187[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4f_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_188 (Activa (None, 14, 14, 256)  0           resnet50_bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res4f_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_188[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4f_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_189 (Activa (None, 14, 14, 256)  0           resnet50_bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res4f_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_189[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4f_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_61 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4f_branch2c[0][0]
#                                                                  resnet50_activation_187[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_190 (Activa (None, 14, 14, 1024) 0           resnet50_add_61[0][0]
# __________________________________________________________________________________________________
# resnet50_res5a_branch2a (Conv2D (None, 7, 7, 512)    524800      resnet50_activation_190[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5a_branch2a (BatchNo (None, 7, 7, 512)    2048        resnet50_res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_191 (Activa (None, 7, 7, 512)    0           resnet50_bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res5a_branch2b (Conv2D (None, 7, 7, 512)    2359808     resnet50_activation_191[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5a_branch2b (BatchNo (None, 7, 7, 512)    2048        resnet50_res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_192 (Activa (None, 7, 7, 512)    0           resnet50_bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res5a_branch2c (Conv2D (None, 7, 7, 2048)   1050624     resnet50_activation_192[0][0]
# __________________________________________________________________________________________________
# resnet50_res5a_branch1 (Conv2D) (None, 7, 7, 2048)   2099200     resnet50_activation_190[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5a_branch2c (BatchNo (None, 7, 7, 2048)   8192        resnet50_res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5a_branch1 (BatchNor (None, 7, 7, 2048)   8192        resnet50_res5a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_add_62 (Add)           (None, 7, 7, 2048)   0           resnet50_bn5a_branch2c[0][0]
#                                                                  resnet50_bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_193 (Activa (None, 7, 7, 2048)   0           resnet50_add_62[0][0]
# __________________________________________________________________________________________________
# resnet50_res5b_branch2a (Conv2D (None, 7, 7, 512)    1049088     resnet50_activation_193[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5b_branch2a (BatchNo (None, 7, 7, 512)    2048        resnet50_res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_194 (Activa (None, 7, 7, 512)    0           resnet50_bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# vgg16_block1_conv1 (Conv2D)     (None, 224, 224, 64) 1792        vgg16_resnet50_input_4[0][0]
# __________________________________________________________________________________________________
# resnet50_res5b_branch2b (Conv2D (None, 7, 7, 512)    2359808     resnet50_activation_194[0][0]
# __________________________________________________________________________________________________
# vgg16_block1_conv2 (Conv2D)     (None, 224, 224, 64) 36928       vgg16_block1_conv1[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5b_branch2b (BatchNo (None, 7, 7, 512)    2048        resnet50_res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# vgg16_block1_pool (MaxPooling2D (None, 112, 112, 64) 0           vgg16_block1_conv2[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_195 (Activa (None, 7, 7, 512)    0           resnet50_bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# vgg16_block2_conv1 (Conv2D)     (None, 112, 112, 128 73856       vgg16_block1_pool[0][0]
# __________________________________________________________________________________________________
# resnet50_res5b_branch2c (Conv2D (None, 7, 7, 2048)   1050624     resnet50_activation_195[0][0]
# __________________________________________________________________________________________________
# vgg16_block2_conv2 (Conv2D)     (None, 112, 112, 128 147584      vgg16_block2_conv1[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5b_branch2c (BatchNo (None, 7, 7, 2048)   8192        resnet50_res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# vgg16_block2_pool (MaxPooling2D (None, 56, 56, 128)  0           vgg16_block2_conv2[0][0]
# __________________________________________________________________________________________________
# resnet50_add_63 (Add)           (None, 7, 7, 2048)   0           resnet50_bn5b_branch2c[0][0]
#                                                                  resnet50_activation_193[0][0]
# __________________________________________________________________________________________________
# vgg16_block3_conv1 (Conv2D)     (None, 56, 56, 256)  295168      vgg16_block2_pool[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_196 (Activa (None, 7, 7, 2048)   0           resnet50_add_63[0][0]
# __________________________________________________________________________________________________
# vgg16_block3_conv2 (Conv2D)     (None, 56, 56, 256)  590080      vgg16_block3_conv1[0][0]
# __________________________________________________________________________________________________
# resnet50_res5c_branch2a (Conv2D (None, 7, 7, 512)    1049088     resnet50_activation_196[0][0]
# __________________________________________________________________________________________________
# vgg16_block3_conv3 (Conv2D)     (None, 56, 56, 256)  590080      vgg16_block3_conv2[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5c_branch2a (BatchNo (None, 7, 7, 512)    2048        resnet50_res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# vgg16_block3_pool (MaxPooling2D (None, 28, 28, 256)  0           vgg16_block3_conv3[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_197 (Activa (None, 7, 7, 512)    0           resnet50_bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_conv1 (Conv2D)     (None, 28, 28, 512)  1180160     vgg16_block3_pool[0][0]
# __________________________________________________________________________________________________
# resnet50_res5c_branch2b (Conv2D (None, 7, 7, 512)    2359808     resnet50_activation_197[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_conv2 (Conv2D)     (None, 28, 28, 512)  2359808     vgg16_block4_conv1[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5c_branch2b (BatchNo (None, 7, 7, 512)    2048        resnet50_res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_conv3 (Conv2D)     (None, 28, 28, 512)  2359808     vgg16_block4_conv2[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_198 (Activa (None, 7, 7, 512)    0           resnet50_bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_pool (MaxPooling2D (None, 14, 14, 512)  0           vgg16_block4_conv3[0][0]
# __________________________________________________________________________________________________
# resnet50_res5c_branch2c (Conv2D (None, 7, 7, 2048)   1050624     resnet50_activation_198[0][0]
# __________________________________________________________________________________________________
# vgg16_block5_conv1 (Conv2D)     (None, 14, 14, 512)  2359808     vgg16_block4_pool[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5c_branch2c (BatchNo (None, 7, 7, 2048)   8192        resnet50_res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# vgg16_block5_conv2 (Conv2D)     (None, 14, 14, 512)  2359808     vgg16_block5_conv1[0][0]
# __________________________________________________________________________________________________
# resnet50_add_64 (Add)           (None, 7, 7, 2048)   0           resnet50_bn5c_branch2c[0][0]
#                                                                  resnet50_activation_196[0][0]
# __________________________________________________________________________________________________
# vgg16_block5_conv3 (Conv2D)     (None, 14, 14, 512)  2359808     vgg16_block5_conv2[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_199 (Activa (None, 7, 7, 2048)   0           resnet50_add_64[0][0]
# __________________________________________________________________________________________________
# vgg16_block5_pool (MaxPooling2D (None, 7, 7, 512)    0           vgg16_block5_conv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 2048)         0           resnet50_activation_199[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 512)          0           vgg16_block5_pool[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 2560)         0           global_average_pooling2d_7[0][0]
#                                                                  global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 3)            7683        concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 3)            0           dense_4[0][0]
# ==================================================================================================
# Total params: 38,310,083
# Trainable params: 60,803
# Non-trainable params: 38,249,280
# __________________________________________________________________________________________________

# %%
len(train_gen.x) // BATCH_SIZE
# Out:
# 157

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# # model.fit_generator(image_gen.flow(x_train, y_train.toarray(), batch_size=batch_size),
# #           steps_per_epoch=  x_train.shape[0]//batch_size,
# #           epochs=epochs,
# #           verbose=1,
# #           class_weight=class_weight_dic)

# hist = model.fit_generator(train_gen,
#                     steps_per_epoch=len(train_gen.x)//BATCH_SIZE,
#                     epochs=EPOCHS,
#                     validation_data=(X_val, y_val),
#                     validation_steps=X_val.shape[0]//BATCH_SIZE)

# %%
hist = model.fit(X_train, 
                 y_train, 
                 batch_size=BATCH_SIZE, 
                 epochs=BATCH_SIZE, 
                 verbose=1, 
                 callbacks=None, 
                 validation_data=(X_val, y_val))
# Out:
# Train on 2520 samples, validate on 840 samples
# Epoch 1/3
# 2520/2520 [==============================] - 147s 58ms/step - loss: 0.4128 - accuracy: 0.8853 - val_loss: 0.2420 - val_accuracy: 0.9155
# Epoch 2/3
# 2520/2520 [==============================] - 134s 53ms/step - loss: 0.1426 - accuracy: 0.9460 - val_loss: 0.6310 - val_accuracy: 0.8119
# Epoch 3/3
# 2520/2520 [==============================] - 134s 53ms/step - loss: 0.0834 - accuracy: 0.9690 - val_loss: 0.3111 - val_accuracy: 0.8976

# %%
model.evaluate(X_test, y_test)
# Out:
# 2700/2700 [==============================] - 53s 20ms/step
# [0.15546016060643725, 0.9459259510040283]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

# Plot training & validation accuracy values
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy') 
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Confusion matrix
# Credit: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.round(cm, 2)

    thresh = np.max(cm) // 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
Y_pred = model.predict(X_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
Y_true = np.argmax(y_test,axis = 1) 
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)

# %%
plot_confusion_matrix(confusion_mtx, classes = CLASSES)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# plot_confusion_matrix(confusion_mtx, classes = CLASSES, normalize=True)
conf_mat = confusion_matrix(Y_true, Y_pred_classes)
# Normalise
conf_mat_norm = conf_mat.astype('float') / conf_mat.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat_norm, annot=True, cmap=plt.cm.Blues, fmt='.2f', xticklabels=CLASSES, yticklabels=CLASSES)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show(block=False)

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_true, Y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.72      0.82       383
#            1       0.96      0.98      0.97      2273
#            2       0.62      0.95      0.75        44
#
#     accuracy                           0.95      2700
#    macro avg       0.84      0.89      0.85      2700
# weighted avg       0.95      0.95      0.94      2700

# %%
model.save_weights('Covid19_Detection_pretrained_ResNet_VGG_3_Epochs.h5')

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True, to_file='Covid19_Detection_pretrained_ResNet_VGG_3_Epochs.png')
