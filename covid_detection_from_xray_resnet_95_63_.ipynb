# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/ieee8023/covid-chestxray-dataset.git
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 3237, done.
# remote: Total 3237 (delta 0), reused 0 (delta 0), pack-reused 3237
# Receiving objects: 100% (3237/3237), 582.59 MiB | 14.09 MiB/s, done.
# Resolving deltas: 100% (1289/1289), done.
# Checking out files: 100% (987/987), done.

# %%
# !mkdir -p /content/dataset/covid/
# !mkdir -p /content/dataset/normal/
# !mkdir -p /content/dataset/pneumonia/

# %%
# !unzip "/content/drive/My Drive/Datasets/Chest X-Ray Images (Pneumonia).zip"

# %%
# !mv /content/chest_xray/train/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/train/PNEUMONIA/* /content/dataset/pneumonia/
# !mv /content/chest_xray/val/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/val/PNEUMONIA/* /content/dataset/pneumonia/
# !mv /content/chest_xray/test/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/test/PNEUMONIA/* /content/dataset/pneumonia/

# %%
import pandas as pd
import shutil
import os

# Selecting all combination of 'COVID-19' patients with 'PA' X-Ray view
virus = "COVID-19" # Virus to look for
x_ray_view = "PA" # View of X-Ray

meta_data = "/content/covid-chestxray-dataset/metadata.csv"
images_dir = "/content/covid-chestxray-dataset/images"
output_dir = "/content/dataset/covid/"

metadata_csv = pd.read_csv(meta_data)

for (i, row) in metadata_csv.iterrows():
	if row["finding"] != virus or row["view"] != x_ray_view:
		continue

	filename = row["filename"].split(os.path.sep)[-1]
	filePath = os.path.sep.join([images_dir, filename])
	shutil.copy2(filePath, output_dir)

# %%
# !git clone https://github.com/UCSD-AI4H/COVID-CT.git

# %%
# !unzip /content/COVID-CT/Images-processed/CT_COVID.zip
# !unzip /content/COVID-CT/Images-processed/CT_NonCOVID.zip

# %%
# !mv /content/CT_COVID/* /content/dataset/covid/

# %%
# !unzip "/content/drive/My Drive/Datasets/COVID19/COV-Img.zip"

# %%
# !mkdir -p /content/test/covid/

# %%
# !mv /content/COV-Img/* /content/test/covid/

# %% [markdown]
#   ## Dependencies

# %%
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Input, average, Average, concatenate
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense

from keras.models import Sequential, Model
from keras.applications.xception import Xception
from keras.applications.resnet50 import ResNet50
from keras.applications import ResNet101
from keras.applications import DenseNet201
from keras.applications import MobileNet
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.optimizers import Adam, SGD, RMSprop

import tensorflow as tf

import os
import numpy as np
import pandas as pd
import time

import random

from PIL import Image
import glob
import matplotlib.pyplot as plt
from matplotlib import pyplot
import matplotlib.image as mpimg
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
DATASET_DIR = "/content/dataset"

NORMAL_DIR = DATASET_DIR + "/normal"
PNEUMONIA_DIR = DATASET_DIR + "/pneumonia"
COVID_DIR = DATASET_DIR + "/covid"

NORMAL_TRAIN_SAMPLES = 1200 # total samples = 1583
PNEUMONIA_TRAIN_SAMPLES = 2000 # total samples = 4273
COVID_TRAIN_SAMPLES = 160 # total samples = 201

IMG_W = 224
IMG_H = 224
IMG_C = 1
INPUT_SHAPE = (IMG_W, IMG_H, IMG_C)

CLASSES = [ "NORMAL", "PNEUMONIA", "COVID" ]
NB_CLASSES = len(CLASSES)

EPOCHS = 5
BATCH_SIZE = 16

# %%
normal_images = []
pneumonia_images = []
covid_images = []

# %%
for img_path in glob.glob(NORMAL_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    # img = img / 255.
    normal_images.append(img[:np.newaxis])

for img_path in glob.glob(PNEUMONIA_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    # img = img / 255.
    pneumonia_images.append(img[:np.newaxis])

for img_path in glob.glob(COVID_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    # img = img / 255.
    covid_images.append(img[:np.newaxis])

# %%
len(normal_images), len(pneumonia_images), len(covid_images)
# Out:
# (1583, 4273, 204)

# %%
width=150
height=150
rows = 1
cols = 3

imgs = [ normal_images[0], pneumonia_images[0], covid_images[0]]

axes=[]
fig=plt.figure()

for i in range(rows*cols):
    img = imgs[i]
    axes.append( fig.add_subplot(rows, cols, i+1) )
    plt.imshow(img)

axes[0].set_title('NORMAL')
axes[1].set_title('PNEUMONIA')
axes[2].set_title('COVID')
fig.tight_layout()    
plt.show()

# %%
normal_X = []
pneumonia_X = []
covid_X = []
normal_y = []
pneumonia_y = []
covid_y = []
X = []
y = []

for item in normal_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    normal_X.append(img)    
    normal_y.append(CLASSES.index("NORMAL"))   
    X.append(img)    
    y.append(CLASSES.index("NORMAL"))

for item in pneumonia_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    pneumonia_X.append(img)    
    pneumonia_y.append(CLASSES.index("PNEUMONIA"))   
    X.append(img)    
    y.append(CLASSES.index("PNEUMONIA"))

for item in covid_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    covid_X.append(img) 
    covid_y.append(CLASSES.index("COVID"))   
    X.append(img)    
    y.append(CLASSES.index("COVID"))

X = np.asarray(X)
y = np.asarray(y)

# %%
X.shape, y.shape
# Out:
# ((6060, 224, 224, 1), (6060,))

# %%
X_train_normal = normal_X[:NORMAL_TRAIN_SAMPLES]
X_train_pneumonia = pneumonia_X[:PNEUMONIA_TRAIN_SAMPLES]
X_train_covid = covid_X[:COVID_TRAIN_SAMPLES]
X_test_normal = normal_X[NORMAL_TRAIN_SAMPLES:]
X_test_pneumonia = pneumonia_X[PNEUMONIA_TRAIN_SAMPLES:]
X_test_covid = covid_X[COVID_TRAIN_SAMPLES:]

y_train_normal = normal_y[:NORMAL_TRAIN_SAMPLES]
y_train_pneumonia = pneumonia_y[:PNEUMONIA_TRAIN_SAMPLES]
y_train_covid = covid_y[:COVID_TRAIN_SAMPLES]
y_test_normal = normal_y[NORMAL_TRAIN_SAMPLES:]
y_test_pneumonia = pneumonia_y[PNEUMONIA_TRAIN_SAMPLES:]
y_test_covid = covid_y[COVID_TRAIN_SAMPLES:]


X_train = np.concatenate((X_train_normal, X_train_pneumonia, X_train_covid), axis=0) 
y_train = np.concatenate((y_train_normal, y_train_pneumonia, y_train_covid), axis=0) 

X_test = np.concatenate((X_test_normal, X_test_pneumonia, X_test_covid), axis=0) 
y_test = np.concatenate((y_test_normal, y_test_pneumonia, y_test_covid), axis=0)

# %%
# np.full((len(X_train_normal), 1), y_test_normal[0]).shape

# %%
X_train.shape, y_train.shape
# Out:
# ((3360, 224, 224, 1), (3360,))

# %%
X_test.shape, y_test.shape
# Out:
# ((2700, 224, 224, 1), (2700,))

# %%
a = list(zip(X_train, y_train))
random.shuffle(a)
X_train, y_train = zip(*a)
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
# a = list(zip(X_train, y_train))
# random.shuffle(a)
# X_test, y_test = zip(*a)

# %%
X_train.shape, y_train.shape
# Out:
# ((3360, 224, 224, 1), (3360,))

# %%
from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.2, random_state=2020)


# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2

# %%
# ----------------------

# %%
X_train = np.repeat(X_train[...,], 3, 3)
X_val = np.repeat(X_val[...,], 3, 3)
X_test = np.repeat(X_test[...,], 3, 3)

# %%
X_train.shape, y_train.shape
# Out:
# ((2520, 224, 224, 3), (2520,))

# %%
X_val.shape, y_val.shape
# Out:
# ((840, 224, 224, 3), (840,))

# %%
X_test.shape, y_test.shape
# Out:
# ((2700, 224, 224, 3), (2700,))

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1, 2]), array([ 913, 1485,  122]))

# %%
np.unique(y_test, return_counts=True)
# Out:
# (array([0, 1, 2]), array([ 383, 2273,   44]))

# %%
from keras.utils import to_categorical

y_train = to_categorical(y_train)
y_val = to_categorical(y_val)
y_test = to_categorical(y_test)

# %%
train_da_args = dict(rescale=1./255, 
               shear_range=0.2,
               zoom_range=0.05,
               width_shift_range=0.05,
               height_shift_range=0.05,
               rotation_range=360,
               #  brightness_range=[0.2,1.0],
               vertical_flip=True,
               horizontal_flip=True)

# val_da_args = dict(rescale=1./255)

train_da = ImageDataGenerator(train_da_args)
# val_da = ImageDataGenerator(val_da_args)

train_da.fit(X_train, augment=True)
# val_da.fit(X_train)

train_gen = train_da.flow(X_train, y_train, batch_size=BATCH_SIZE)
# val_gen = train_da.flow(X_val, y_val)

# %%
for i in range(9):
	pyplot.subplot(330 + 1 + i)
	batch = train_gen.next()
	image = batch[0][0].astype('uint8')
	pyplot.imshow(image)

pyplot.show()

# %%
for i in range(9):
	
	pyplot.subplot(330 + 1 + i)
	batch = train_gen.next()
	image = batch[0][-1].astype('uint8')
	pyplot.imshow(image)

pyplot.show()

# %%
# augmented_data = []
# num_augmented = 0
# for X_batch, y_batch in train_da.flow(X_train, y_train, batch_size=BATCH_SIZE, shuffle=False):
#     augmented_data.append(X_batch)
#     num_augmented += BATCH_SIZE
#     if num_augmented == X_train.shape[0]:
#         break
# augmented_data = np.concatenate(augmented_data)

# %%
# -------------------------

# %%
# len(train_gen.x)

# %%
# vgg_model = VGG16(weights='imagenet', 
#                         include_top=False, 
#                         input_shape=(IMG_H, IMG_W, 3))

# for layer in vgg_model.layers:
#     if isinstance(layer, BatchNormalization):
#         layer.trainable = True
#     else:
#         layer.trainable = False

# model = Sequential()
# model.add(vgg_model)
# model.add(GlobalAveragePooling2D())
# model.add(Dense(256, activation='relu'))
# model.add(Dropout(0.5))
# model.add(BatchNormalization())
# model.add(Dense(NB_CLASSES, activation='softmax'))

# %%
models_input = Input(shape=(IMG_H, IMG_W, 3))


resnet_model = ResNet50(weights='imagenet', 
                        include_top=False, 
                        input_tensor=models_input)

for layer in resnet_model.layers:
    layer.name = "resnet50_" + layer.name
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False
        
resnet_gap = GlobalAveragePooling2D()(resnet_model.output)

# x = Dense(256)(x)
# x = Activation('relu')(x)
# x = Dropout(0.5)(x)
# x = Activation('relu')(x)
# x = BatchNormalization()(x)
# x = Dense(NB_CLASSES)(x)
# out = Activation('softmax')(x)
# resnet_model = Model(inputs=resnet_model.input, outputs=out)


# vgg_model = VGG16(weights='imagenet', 
#                         include_top=False, 
#                         input_tensor=models_input)

# for layer in vgg_model.layers:
#     layer.name = "vgg16_" + layer.name
#     if isinstance(layer, BatchNormalization):
#         layer.trainable = True
#     else:
#         layer.trainable = False

        
# vgg_gap = GlobalAveragePooling2D()(vgg_model.output)

# # x = GlobalAveragePooling2D()(vgg_model.output)
# x = Dense(256)(vgg_gap)
# x = Activation('relu')(x)
# x = Dropout(0.5)(x)
# x = Activation('relu')(x)
# vgg_out = BatchNormalization()(x)
# x = Dense(NB_CLASSES)(x)
# out = Activation('softmax')(x)

# merged_nets = concatenate([resnet_gap, vgg_gap])

x = Dense(NB_CLASSES)(resnet_gap)
out = Activation('softmax')(x)

inputs = input_tensor=models_input
outputs = out # out # average([resnet_model.output, vgg_model.output])
model = Model(inputs, outputs)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 8s 0us/step

# %%
# model.compile(loss='categorical_crossentropy',
#               optimizer='adam',
#               metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# resnet50_input_3 (InputLayer)   (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# resnet50_conv1_pad (ZeroPadding (None, 230, 230, 3)  0           resnet50_input_3[0][0]
# __________________________________________________________________________________________________
# resnet50_conv1 (Conv2D)         (None, 112, 112, 64) 9472        resnet50_conv1_pad[0][0]
# __________________________________________________________________________________________________
# resnet50_bn_conv1 (BatchNormali (None, 112, 112, 64) 256         resnet50_conv1[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_3 (Activati (None, 112, 112, 64) 0           resnet50_bn_conv1[0][0]
# __________________________________________________________________________________________________
# resnet50_pool1_pad (ZeroPadding (None, 114, 114, 64) 0           resnet50_activation_3[0][0]
# __________________________________________________________________________________________________
# resnet50_max_pooling2d_1 (MaxPo (None, 56, 56, 64)   0           resnet50_pool1_pad[0][0]
# __________________________________________________________________________________________________
# resnet50_res2a_branch2a (Conv2D (None, 56, 56, 64)   4160        resnet50_max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2a_branch2a (BatchNo (None, 56, 56, 64)   256         resnet50_res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_4 (Activati (None, 56, 56, 64)   0           resnet50_bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res2a_branch2b (Conv2D (None, 56, 56, 64)   36928       resnet50_activation_4[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2a_branch2b (BatchNo (None, 56, 56, 64)   256         resnet50_res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_5 (Activati (None, 56, 56, 64)   0           resnet50_bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res2a_branch2c (Conv2D (None, 56, 56, 256)  16640       resnet50_activation_5[0][0]
# __________________________________________________________________________________________________
# resnet50_res2a_branch1 (Conv2D) (None, 56, 56, 256)  16640       resnet50_max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2a_branch2c (BatchNo (None, 56, 56, 256)  1024        resnet50_res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2a_branch1 (BatchNor (None, 56, 56, 256)  1024        resnet50_res2a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_add_25 (Add)           (None, 56, 56, 256)  0           resnet50_bn2a_branch2c[0][0]
#                                                                  resnet50_bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_6 (Activati (None, 56, 56, 256)  0           resnet50_add_25[0][0]
# __________________________________________________________________________________________________
# resnet50_res2b_branch2a (Conv2D (None, 56, 56, 64)   16448       resnet50_activation_6[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2b_branch2a (BatchNo (None, 56, 56, 64)   256         resnet50_res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_7 (Activati (None, 56, 56, 64)   0           resnet50_bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res2b_branch2b (Conv2D (None, 56, 56, 64)   36928       resnet50_activation_7[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2b_branch2b (BatchNo (None, 56, 56, 64)   256         resnet50_res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_8 (Activati (None, 56, 56, 64)   0           resnet50_bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res2b_branch2c (Conv2D (None, 56, 56, 256)  16640       resnet50_activation_8[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2b_branch2c (BatchNo (None, 56, 56, 256)  1024        resnet50_res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_26 (Add)           (None, 56, 56, 256)  0           resnet50_bn2b_branch2c[0][0]
#                                                                  resnet50_activation_6[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_9 (Activati (None, 56, 56, 256)  0           resnet50_add_26[0][0]
# __________________________________________________________________________________________________
# resnet50_res2c_branch2a (Conv2D (None, 56, 56, 64)   16448       resnet50_activation_9[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2c_branch2a (BatchNo (None, 56, 56, 64)   256         resnet50_res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_10 (Activat (None, 56, 56, 64)   0           resnet50_bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res2c_branch2b (Conv2D (None, 56, 56, 64)   36928       resnet50_activation_10[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2c_branch2b (BatchNo (None, 56, 56, 64)   256         resnet50_res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_11 (Activat (None, 56, 56, 64)   0           resnet50_bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res2c_branch2c (Conv2D (None, 56, 56, 256)  16640       resnet50_activation_11[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2c_branch2c (BatchNo (None, 56, 56, 256)  1024        resnet50_res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_27 (Add)           (None, 56, 56, 256)  0           resnet50_bn2c_branch2c[0][0]
#                                                                  resnet50_activation_9[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_12 (Activat (None, 56, 56, 256)  0           resnet50_add_27[0][0]
# __________________________________________________________________________________________________
# resnet50_res3a_branch2a (Conv2D (None, 28, 28, 128)  32896       resnet50_activation_12[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3a_branch2a (BatchNo (None, 28, 28, 128)  512         resnet50_res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_13 (Activat (None, 28, 28, 128)  0           resnet50_bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res3a_branch2b (Conv2D (None, 28, 28, 128)  147584      resnet50_activation_13[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3a_branch2b (BatchNo (None, 28, 28, 128)  512         resnet50_res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_14 (Activat (None, 28, 28, 128)  0           resnet50_bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res3a_branch2c (Conv2D (None, 28, 28, 512)  66048       resnet50_activation_14[0][0]
# __________________________________________________________________________________________________
# resnet50_res3a_branch1 (Conv2D) (None, 28, 28, 512)  131584      resnet50_activation_12[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3a_branch2c (BatchNo (None, 28, 28, 512)  2048        resnet50_res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3a_branch1 (BatchNor (None, 28, 28, 512)  2048        resnet50_res3a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_add_28 (Add)           (None, 28, 28, 512)  0           resnet50_bn3a_branch2c[0][0]
#                                                                  resnet50_bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_15 (Activat (None, 28, 28, 512)  0           resnet50_add_28[0][0]
# __________________________________________________________________________________________________
# resnet50_res3b_branch2a (Conv2D (None, 28, 28, 128)  65664       resnet50_activation_15[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3b_branch2a (BatchNo (None, 28, 28, 128)  512         resnet50_res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_16 (Activat (None, 28, 28, 128)  0           resnet50_bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res3b_branch2b (Conv2D (None, 28, 28, 128)  147584      resnet50_activation_16[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3b_branch2b (BatchNo (None, 28, 28, 128)  512         resnet50_res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_17 (Activat (None, 28, 28, 128)  0           resnet50_bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res3b_branch2c (Conv2D (None, 28, 28, 512)  66048       resnet50_activation_17[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3b_branch2c (BatchNo (None, 28, 28, 512)  2048        resnet50_res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_29 (Add)           (None, 28, 28, 512)  0           resnet50_bn3b_branch2c[0][0]
#                                                                  resnet50_activation_15[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_18 (Activat (None, 28, 28, 512)  0           resnet50_add_29[0][0]
# __________________________________________________________________________________________________
# resnet50_res3c_branch2a (Conv2D (None, 28, 28, 128)  65664       resnet50_activation_18[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3c_branch2a (BatchNo (None, 28, 28, 128)  512         resnet50_res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_19 (Activat (None, 28, 28, 128)  0           resnet50_bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res3c_branch2b (Conv2D (None, 28, 28, 128)  147584      resnet50_activation_19[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3c_branch2b (BatchNo (None, 28, 28, 128)  512         resnet50_res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_20 (Activat (None, 28, 28, 128)  0           resnet50_bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res3c_branch2c (Conv2D (None, 28, 28, 512)  66048       resnet50_activation_20[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3c_branch2c (BatchNo (None, 28, 28, 512)  2048        resnet50_res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_30 (Add)           (None, 28, 28, 512)  0           resnet50_bn3c_branch2c[0][0]
#                                                                  resnet50_activation_18[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_21 (Activat (None, 28, 28, 512)  0           resnet50_add_30[0][0]
# __________________________________________________________________________________________________
# resnet50_res3d_branch2a (Conv2D (None, 28, 28, 128)  65664       resnet50_activation_21[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3d_branch2a (BatchNo (None, 28, 28, 128)  512         resnet50_res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_22 (Activat (None, 28, 28, 128)  0           resnet50_bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res3d_branch2b (Conv2D (None, 28, 28, 128)  147584      resnet50_activation_22[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3d_branch2b (BatchNo (None, 28, 28, 128)  512         resnet50_res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_23 (Activat (None, 28, 28, 128)  0           resnet50_bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res3d_branch2c (Conv2D (None, 28, 28, 512)  66048       resnet50_activation_23[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3d_branch2c (BatchNo (None, 28, 28, 512)  2048        resnet50_res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_31 (Add)           (None, 28, 28, 512)  0           resnet50_bn3d_branch2c[0][0]
#                                                                  resnet50_activation_21[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_24 (Activat (None, 28, 28, 512)  0           resnet50_add_31[0][0]
# __________________________________________________________________________________________________
# resnet50_res4a_branch2a (Conv2D (None, 14, 14, 256)  131328      resnet50_activation_24[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4a_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_25 (Activat (None, 14, 14, 256)  0           resnet50_bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res4a_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_25[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4a_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_26 (Activat (None, 14, 14, 256)  0           resnet50_bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res4a_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_26[0][0]
# __________________________________________________________________________________________________
# resnet50_res4a_branch1 (Conv2D) (None, 14, 14, 1024) 525312      resnet50_activation_24[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4a_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4a_branch1 (BatchNor (None, 14, 14, 1024) 4096        resnet50_res4a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_add_32 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4a_branch2c[0][0]
#                                                                  resnet50_bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_27 (Activat (None, 14, 14, 1024) 0           resnet50_add_32[0][0]
# __________________________________________________________________________________________________
# resnet50_res4b_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_27[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4b_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_28 (Activat (None, 14, 14, 256)  0           resnet50_bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res4b_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_28[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4b_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_29 (Activat (None, 14, 14, 256)  0           resnet50_bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res4b_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_29[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4b_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_33 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4b_branch2c[0][0]
#                                                                  resnet50_activation_27[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_30 (Activat (None, 14, 14, 1024) 0           resnet50_add_33[0][0]
# __________________________________________________________________________________________________
# resnet50_res4c_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_30[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4c_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_31 (Activat (None, 14, 14, 256)  0           resnet50_bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res4c_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_31[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4c_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_32 (Activat (None, 14, 14, 256)  0           resnet50_bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res4c_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_32[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4c_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_34 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4c_branch2c[0][0]
#                                                                  resnet50_activation_30[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_33 (Activat (None, 14, 14, 1024) 0           resnet50_add_34[0][0]
# __________________________________________________________________________________________________
# resnet50_res4d_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_33[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4d_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_34 (Activat (None, 14, 14, 256)  0           resnet50_bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res4d_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_34[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4d_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_35 (Activat (None, 14, 14, 256)  0           resnet50_bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res4d_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_35[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4d_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_35 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4d_branch2c[0][0]
#                                                                  resnet50_activation_33[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_36 (Activat (None, 14, 14, 1024) 0           resnet50_add_35[0][0]
# __________________________________________________________________________________________________
# resnet50_res4e_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_36[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4e_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_37 (Activat (None, 14, 14, 256)  0           resnet50_bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res4e_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_37[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4e_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_38 (Activat (None, 14, 14, 256)  0           resnet50_bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res4e_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_38[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4e_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_36 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4e_branch2c[0][0]
#                                                                  resnet50_activation_36[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_39 (Activat (None, 14, 14, 1024) 0           resnet50_add_36[0][0]
# __________________________________________________________________________________________________
# resnet50_res4f_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_39[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4f_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_40 (Activat (None, 14, 14, 256)  0           resnet50_bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res4f_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_40[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4f_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_41 (Activat (None, 14, 14, 256)  0           resnet50_bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res4f_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_41[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4f_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_37 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4f_branch2c[0][0]
#                                                                  resnet50_activation_39[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_42 (Activat (None, 14, 14, 1024) 0           resnet50_add_37[0][0]
# __________________________________________________________________________________________________
# resnet50_res5a_branch2a (Conv2D (None, 7, 7, 512)    524800      resnet50_activation_42[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5a_branch2a (BatchNo (None, 7, 7, 512)    2048        resnet50_res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_43 (Activat (None, 7, 7, 512)    0           resnet50_bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res5a_branch2b (Conv2D (None, 7, 7, 512)    2359808     resnet50_activation_43[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5a_branch2b (BatchNo (None, 7, 7, 512)    2048        resnet50_res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_44 (Activat (None, 7, 7, 512)    0           resnet50_bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res5a_branch2c (Conv2D (None, 7, 7, 2048)   1050624     resnet50_activation_44[0][0]
# __________________________________________________________________________________________________
# resnet50_res5a_branch1 (Conv2D) (None, 7, 7, 2048)   2099200     resnet50_activation_42[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5a_branch2c (BatchNo (None, 7, 7, 2048)   8192        resnet50_res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5a_branch1 (BatchNor (None, 7, 7, 2048)   8192        resnet50_res5a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_add_38 (Add)           (None, 7, 7, 2048)   0           resnet50_bn5a_branch2c[0][0]
#                                                                  resnet50_bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_45 (Activat (None, 7, 7, 2048)   0           resnet50_add_38[0][0]
# __________________________________________________________________________________________________
# resnet50_res5b_branch2a (Conv2D (None, 7, 7, 512)    1049088     resnet50_activation_45[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5b_branch2a (BatchNo (None, 7, 7, 512)    2048        resnet50_res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_46 (Activat (None, 7, 7, 512)    0           resnet50_bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res5b_branch2b (Conv2D (None, 7, 7, 512)    2359808     resnet50_activation_46[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5b_branch2b (BatchNo (None, 7, 7, 512)    2048        resnet50_res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_47 (Activat (None, 7, 7, 512)    0           resnet50_bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res5b_branch2c (Conv2D (None, 7, 7, 2048)   1050624     resnet50_activation_47[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5b_branch2c (BatchNo (None, 7, 7, 2048)   8192        resnet50_res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_39 (Add)           (None, 7, 7, 2048)   0           resnet50_bn5b_branch2c[0][0]
#                                                                  resnet50_activation_45[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_48 (Activat (None, 7, 7, 2048)   0           resnet50_add_39[0][0]
# __________________________________________________________________________________________________
# resnet50_res5c_branch2a (Conv2D (None, 7, 7, 512)    1049088     resnet50_activation_48[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5c_branch2a (BatchNo (None, 7, 7, 512)    2048        resnet50_res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_49 (Activat (None, 7, 7, 512)    0           resnet50_bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res5c_branch2b (Conv2D (None, 7, 7, 512)    2359808     resnet50_activation_49[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5c_branch2b (BatchNo (None, 7, 7, 512)    2048        resnet50_res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_50 (Activat (None, 7, 7, 512)    0           resnet50_bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res5c_branch2c (Conv2D (None, 7, 7, 2048)   1050624     resnet50_activation_50[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5c_branch2c (BatchNo (None, 7, 7, 2048)   8192        resnet50_res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_40 (Add)           (None, 7, 7, 2048)   0           resnet50_bn5c_branch2c[0][0]
#                                                                  resnet50_activation_48[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_51 (Activat (None, 7, 7, 2048)   0           resnet50_add_40[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 2048)         0           resnet50_activation_51[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 3)            6147        global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 3)            0           dense_3[0][0]
# ==================================================================================================
# Total params: 23,593,859
# Trainable params: 59,267
# Non-trainable params: 23,534,592
# __________________________________________________________________________________________________

# %%
len(train_gen.x) // BATCH_SIZE
# Out:
# 157

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# # model.fit_generator(image_gen.flow(x_train, y_train.toarray(), batch_size=batch_size),
# #           steps_per_epoch=  x_train.shape[0]//batch_size,
# #           epochs=epochs,
# #           verbose=1,
# #           class_weight=class_weight_dic)

# hist = model.fit_generator(train_gen,
#                     steps_per_epoch=len(train_gen.x)//BATCH_SIZE,
#                     epochs=EPOCHS,
#                     validation_data=(X_val, y_val),
#                     validation_steps=X_val.shape[0]//BATCH_SIZE)

# %%
hist = model.fit(X_train, 
                 y_train, 
                 batch_size=BATCH_SIZE, 
                 epochs=EPOCHS, 
                 verbose=1, 
                 callbacks=None, 
                 validation_data=(X_val, y_val))
# Out:
# Train on 2520 samples, validate on 840 samples
# Epoch 1/5
# 2520/2520 [==============================] - 61s 24ms/step - loss: 0.3294 - accuracy: 0.8687 - val_loss: 0.4400 - val_accuracy: 0.8333
# Epoch 2/5
# 2520/2520 [==============================] - 49s 19ms/step - loss: 0.1694 - accuracy: 0.9361 - val_loss: 0.6227 - val_accuracy: 0.7881
# Epoch 3/5
# 2520/2520 [==============================] - 49s 19ms/step - loss: 0.1243 - accuracy: 0.9567 - val_loss: 0.6939 - val_accuracy: 0.7571
# Epoch 4/5
# 2520/2520 [==============================] - 49s 19ms/step - loss: 0.0750 - accuracy: 0.9754 - val_loss: 0.2303 - val_accuracy: 0.9179
# Epoch 5/5
# 2520/2520 [==============================] - 49s 19ms/step - loss: 0.0493 - accuracy: 0.9806 - val_loss: 0.2603 - val_accuracy: 0.9060

# %%
model.evaluate(X_test, y_test)
# Out:
# 2700/2700 [==============================] - 16s 6ms/step
# [0.12925947195505377, 0.9562963247299194]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

# Plot training & validation accuracy values
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy') 
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Confusion matrix
# Credit: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.round(cm, 2)

    thresh = np.max(cm) // 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
Y_pred = model.predict(X_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
Y_true = np.argmax(y_test,axis = 1) 
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)

# %%
plot_confusion_matrix(confusion_mtx, classes = CLASSES)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# plot_confusion_matrix(confusion_mtx, classes = CLASSES, normalize=True)
conf_mat = confusion_matrix(Y_true, Y_pred_classes)
# Normalise
conf_mat_norm = conf_mat.astype('float') / conf_mat.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat_norm, annot=True, cmap=plt.cm.Blues, fmt='.2f', xticklabels=CLASSES, yticklabels=CLASSES)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show(block=False)

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_true, Y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.74      0.84       383
#            1       0.96      1.00      0.98      2273
#            2       0.83      0.86      0.84        44
#
#     accuracy                           0.96      2700
#    macro avg       0.92      0.87      0.89      2700
# weighted avg       0.96      0.96      0.95      2700

# %%
model.save_weights('Covid19_Detection_pretrained_ResNet_VGG_3_Epochs.h5')

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True, to_file='Covid19_Detection_pretrained_ResNet_VGG_3_Epochs.png')
