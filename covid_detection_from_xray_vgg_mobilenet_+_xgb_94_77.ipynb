# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/ieee8023/covid-chestxray-dataset.git
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 3213, done.
# remote: Total 3213 (delta 0), reused 0 (delta 0), pack-reused 3213
# Receiving objects: 100% (3213/3213), 582.57 MiB | 15.62 MiB/s, done.
# Resolving deltas: 100% (1276/1276), done.
# Checking out files: 100% (991/991), done.

# %%
# !mkdir -p /content/dataset/covid/
# !mkdir -p /content/dataset/normal/
# !mkdir -p /content/dataset/pneumonia/

# %%
# !unzip "/content/drive/My Drive/Datasets/Chest X-Ray Images (Pneumonia).zip"

# %%
# !mv /content/chest_xray/train/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/train/PNEUMONIA/* /content/dataset/pneumonia/
# !mv /content/chest_xray/val/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/val/PNEUMONIA/* /content/dataset/pneumonia/
# !mv /content/chest_xray/test/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/test/PNEUMONIA/* /content/dataset/pneumonia/

# %%
import pandas as pd
import shutil
import os

# Selecting all combination of 'COVID-19' patients with 'PA' X-Ray view
virus = "COVID-19" # Virus to look for
x_ray_view = "PA" # View of X-Ray

meta_data = "/content/covid-chestxray-dataset/metadata.csv"
images_dir = "/content/covid-chestxray-dataset/images"
output_dir = "/content/dataset/covid/"

metadata_csv = pd.read_csv(meta_data)

for (i, row) in metadata_csv.iterrows():
	if row["finding"] != virus or row["view"] != x_ray_view:
		continue

	filename = row["filename"].split(os.path.sep)[-1]
	filePath = os.path.sep.join([images_dir, filename])
	shutil.copy2(filePath, output_dir)

# %% [markdown]
#   ## Pre-processing

# %%
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Input, average, Average, concatenate
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense

from keras.models import Sequential, Model
from keras.applications.xception import Xception
from keras.applications.resnet50 import ResNet50
from keras.applications import ResNet101
from keras.applications import DenseNet201
from keras.applications import MobileNet
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.optimizers import Adam, SGD, RMSprop

import tensorflow as tf

import os
import numpy as np
import pandas as pd
import time

import random

from PIL import Image
import glob
import matplotlib.pyplot as plt
from matplotlib import pyplot
import matplotlib.image as mpimg
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
DATASET_DIR = "/content/dataset"

NORMAL_DIR = DATASET_DIR + "/normal"
PNEUMONIA_DIR = DATASET_DIR + "/pneumonia"
COVID_DIR = DATASET_DIR + "/covid"

NORMAL_TRAIN_SAMPLES = 1000 # total samples = 1583
PNEUMONIA_TRAIN_SAMPLES = 1000 # total samples = 4273
COVID_TRAIN_SAMPLES = 120 # total samples = 201

IMG_W = 224
IMG_H = 224
IMG_C = 1
INPUT_SHAPE = (IMG_W, IMG_H, IMG_C)

CLASSES = [ "NORMAL", "PNEUMONIA", "COVID" ]
NB_CLASSES = len(CLASSES)

EPOCHS = 2
BATCH_SIZE = 16

# %%
normal_images = []
pneumonia_images = []
covid_images = []

# %%
for img_path in glob.glob(NORMAL_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    normal_images.append(img[:np.newaxis])

for img_path in glob.glob(PNEUMONIA_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    pneumonia_images.append(img[:np.newaxis])

for img_path in glob.glob(COVID_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    covid_images.append(img[:np.newaxis])

# %%
len(normal_images), len(pneumonia_images), len(covid_images)
# Out:
# (1583, 4273, 201)

# %%
width=150
height=150
rows = 1
cols = 3

imgs = [ normal_images[0], pneumonia_images[0], covid_images[0]]

axes=[]
fig=plt.figure()

for i in range(rows*cols):
    img = imgs[i]
    axes.append( fig.add_subplot(rows, cols, i+1) )
    plt.imshow(img)

axes[0].set_title('NORMAL')
axes[1].set_title('PNEUMONIA')
axes[2].set_title('COVID')
fig.tight_layout()    
plt.show()

# %%
# X = []
# y = []

# for item in normal_images:
#     img = np.asarray(item)
#     img = img.reshape(INPUT_SHAPE)
#     X.append(img)    
#     y.append(CLASSES.index("NORMAL"))

# for item in pneumonia_images:
#     img = np.asarray(item)
#     img = img.reshape(INPUT_SHAPE)
#     X.append(img)    
#     y.append(CLASSES.index("PNEUMONIA"))

# for item in covid_images:
#     img = np.asarray(item)
#     img = img.reshape(INPUT_SHAPE)
#     X.append(img)    
#     y.append(CLASSES.index("COVID"))

# X = np.asarray(X)
# y = np.asarray(y)

# %%
normal_X = []
pneumonia_X = []
covid_X = []
normal_y = []
pneumonia_y = []
covid_y = []
X = []
y = []

for item in normal_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    normal_X.append(img)    
    normal_y.append(CLASSES.index("NORMAL"))   
    X.append(img)    
    y.append(CLASSES.index("NORMAL"))

for item in pneumonia_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    pneumonia_X.append(img)    
    pneumonia_y.append(CLASSES.index("PNEUMONIA"))   
    X.append(img)    
    y.append(CLASSES.index("PNEUMONIA"))

for item in covid_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    covid_X.append(img) 
    covid_y.append(CLASSES.index("COVID"))   
    X.append(img)    
    y.append(CLASSES.index("COVID"))

X = np.asarray(X)
y = np.asarray(y)

# %%
X.shape, y.shape
# Out:
# ((6057, 224, 224, 1), (6057,))

# %%
# from sklearn.model_selection import train_test_split
# # X_train, X_test, y_train, y_test = train_test_split(
# #     X, y, test_size=0.2, random_state=2020)


# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2

# %%
X_train_normal = normal_X[:NORMAL_TRAIN_SAMPLES]
X_train_pneumonia = pneumonia_X[:PNEUMONIA_TRAIN_SAMPLES]
X_train_covid = covid_X[:COVID_TRAIN_SAMPLES]
X_test_normal = normal_X[NORMAL_TRAIN_SAMPLES:]
X_test_pneumonia = pneumonia_X[PNEUMONIA_TRAIN_SAMPLES:]
X_test_covid = covid_X[COVID_TRAIN_SAMPLES:]

y_train_normal = normal_y[:NORMAL_TRAIN_SAMPLES]
y_train_pneumonia = pneumonia_y[:PNEUMONIA_TRAIN_SAMPLES]
y_train_covid = covid_y[:COVID_TRAIN_SAMPLES]
y_test_normal = normal_y[NORMAL_TRAIN_SAMPLES:]
y_test_pneumonia = pneumonia_y[PNEUMONIA_TRAIN_SAMPLES:]
y_test_covid = covid_y[COVID_TRAIN_SAMPLES:]


X_train = np.concatenate((X_train_normal, X_train_pneumonia, X_train_covid), axis=0) 
y_train = np.concatenate((y_train_normal, y_train_pneumonia, y_train_covid), axis=0) 

X_test = np.concatenate((X_test_normal, X_test_pneumonia, X_test_covid), axis=0) 
y_test = np.concatenate((y_test_normal, y_test_pneumonia, y_test_covid), axis=0)

# %%
# np.full((len(X_train_normal), 1), y_test_normal[0]).shape

# %%
X_train.shape, y_train.shape
# Out:
# ((2120, 224, 224, 1), (2120,))

# %%
X_test.shape, y_test.shape
# Out:
# ((3937, 224, 224, 1), (3937,))

# %%
a = list(zip(X_train, y_train))
random.shuffle(a)
X_train, y_train = zip(*a)
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
# a = list(zip(X_train, y_train))
# random.shuffle(a)
# X_test, y_test = zip(*a)

# %%
X_train.shape, y_train.shape
# Out:
# ((2120, 224, 224, 1), (2120,))

# %%
# ----------------------

# %%
from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.2, random_state=2020)


# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2
X_val = X_test
y_val = y_test

# %%
X_train = np.repeat(X_train[...,], 3, 3)
X_val = np.repeat(X_val[...,], 3, 3)
X_test = np.repeat(X_test[...,], 3, 3)

# %%
X_train.shape, y_train.shape
# Out:
# ((2120, 224, 224, 3), (2120,))

# %%
X_test.shape, y_test.shape
# Out:
# ((3937, 224, 224, 3), (3937,))

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1, 2]), array([1000, 1000,  120]))

# %%
np.unique(y_test, return_counts=True)
# Out:
# (array([0, 1, 2]), array([ 583, 3273,   81]))

# %%
from keras.utils import to_categorical

y_train = to_categorical(y_train)
y_val = to_categorical(y_val)
y_test = to_categorical(y_test)

# %%
train_da_args = dict(rescale=1./255, 
               shear_range=0.2,
               zoom_range=0.05,
               width_shift_range=0.05,
               height_shift_range=0.05,
               rotation_range=360,
               #  brightness_range=[0.2,1.0],
               vertical_flip=True,
               horizontal_flip=True)

# val_da_args = dict(rescale=1./255)

train_da = ImageDataGenerator(train_da_args)
# val_da = ImageDataGenerator(val_da_args)

train_da.fit(X_train, augment=True)
# val_da.fit(X_train)

train_gen = train_da.flow(X_train, y_train, batch_size=BATCH_SIZE)
# val_gen = train_da.flow(X_val, y_val)

# %%
for i in range(9):
	pyplot.subplot(330 + 1 + i)
	batch = train_gen.next()
	image = batch[0][0].astype('uint8')
	pyplot.imshow(image)

pyplot.show()

# %%
for i in range(9):
	pyplot.subplot(330 + 1 + i)
	batch = train_gen.next()
	image = batch[0][-1].astype('uint8')
	pyplot.imshow(image)

pyplot.show()

# %%
# augmented_data = []
# num_augmented = 0
# for X_batch, y_batch in train_da.flow(X_train, y_train, batch_size=BATCH_SIZE, shuffle=False):
#     augmented_data.append(X_batch)
#     num_augmented += BATCH_SIZE
#     if num_augmented == X_train.shape[0]:
#         break
# augmented_data = np.concatenate(augmented_data)

# %%
# -------------------------

# %%
# len(train_gen.x)

# %%
# vgg_model = VGG16(weights='imagenet', 
#                         include_top=False, 
#                         input_shape=(IMG_H, IMG_W, 3))

# for layer in vgg_model.layers:
#     if isinstance(layer, BatchNormalization):
#         layer.trainable = True
#     else:
#         layer.trainable = False

# model = Sequential()
# model.add(vgg_model)
# model.add(GlobalAveragePooling2D())
# model.add(Dense(256, activation='relu'))
# model.add(Dropout(0.5))
# model.add(BatchNormalization())
# model.add(Dense(NB_CLASSES, activation='softmax'))

# %%
models_input = Input(shape=(IMG_H, IMG_W, 3))

resnet_model = ResNet50(weights='imagenet', 
                        include_top=False, 
                        input_tensor=models_input)

for layer in resnet_model.layers:
    layer.name = "resnet50_" + layer.name
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False
        
        
resnet_gap = GlobalAveragePooling2D()(resnet_model.output)

vgg_model = VGG16(weights='imagenet', 
                        include_top=False, 
                        input_tensor=models_input)

for layer in vgg_model.layers:
    layer.name = "vgg16_" + layer.name
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False

        
vgg_gap = GlobalAveragePooling2D()(vgg_model.output)


mobilenet_model = MobileNet(weights='imagenet', 
                        include_top=False, 
                        input_tensor=models_input)

for layer in mobilenet_model.layers:
    layer.name = "mobilenet_" + layer.name
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False

        
mobilenet_gap = GlobalAveragePooling2D()(mobilenet_model.output)

# Merging subnetworks
merged_nets = concatenate([resnet_gap, vgg_gap, mobilenet_gap])

# x = Dense(NB_CLASSES)(merged_nets)
# out = Activation('softmax')(x)

inputs = input_tensor=models_input
outputs = merged_nets # out # average([resnet_model.output, vgg_model.output])
model = Model(inputs, outputs)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# /usr/local/lib/python3.6/dist-packages/keras_applications/mobilenet.py:207: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 3s 0us/step

# %%
# model.compile(loss='categorical_crossentropy',
#               optimizer='adam',
#               metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# mobilenet_vgg16_resnet50_input_ (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# resnet50_conv1_pad (ZeroPadding (None, 230, 230, 3)  0           mobilenet_vgg16_resnet50_input_2[
# __________________________________________________________________________________________________
# resnet50_conv1 (Conv2D)         (None, 112, 112, 64) 9472        resnet50_conv1_pad[0][0]
# __________________________________________________________________________________________________
# resnet50_bn_conv1 (BatchNormali (None, 112, 112, 64) 256         resnet50_conv1[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_50 (Activat (None, 112, 112, 64) 0           resnet50_bn_conv1[0][0]
# __________________________________________________________________________________________________
# resnet50_pool1_pad (ZeroPadding (None, 114, 114, 64) 0           resnet50_activation_50[0][0]
# __________________________________________________________________________________________________
# resnet50_max_pooling2d_2 (MaxPo (None, 56, 56, 64)   0           resnet50_pool1_pad[0][0]
# __________________________________________________________________________________________________
# resnet50_res2a_branch2a (Conv2D (None, 56, 56, 64)   4160        resnet50_max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2a_branch2a (BatchNo (None, 56, 56, 64)   256         resnet50_res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_51 (Activat (None, 56, 56, 64)   0           resnet50_bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res2a_branch2b (Conv2D (None, 56, 56, 64)   36928       resnet50_activation_51[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2a_branch2b (BatchNo (None, 56, 56, 64)   256         resnet50_res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_52 (Activat (None, 56, 56, 64)   0           resnet50_bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res2a_branch2c (Conv2D (None, 56, 56, 256)  16640       resnet50_activation_52[0][0]
# __________________________________________________________________________________________________
# resnet50_res2a_branch1 (Conv2D) (None, 56, 56, 256)  16640       resnet50_max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2a_branch2c (BatchNo (None, 56, 56, 256)  1024        resnet50_res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2a_branch1 (BatchNor (None, 56, 56, 256)  1024        resnet50_res2a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_add_17 (Add)           (None, 56, 56, 256)  0           resnet50_bn2a_branch2c[0][0]
#                                                                  resnet50_bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_53 (Activat (None, 56, 56, 256)  0           resnet50_add_17[0][0]
# __________________________________________________________________________________________________
# resnet50_res2b_branch2a (Conv2D (None, 56, 56, 64)   16448       resnet50_activation_53[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2b_branch2a (BatchNo (None, 56, 56, 64)   256         resnet50_res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_54 (Activat (None, 56, 56, 64)   0           resnet50_bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res2b_branch2b (Conv2D (None, 56, 56, 64)   36928       resnet50_activation_54[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2b_branch2b (BatchNo (None, 56, 56, 64)   256         resnet50_res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_55 (Activat (None, 56, 56, 64)   0           resnet50_bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res2b_branch2c (Conv2D (None, 56, 56, 256)  16640       resnet50_activation_55[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2b_branch2c (BatchNo (None, 56, 56, 256)  1024        resnet50_res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_18 (Add)           (None, 56, 56, 256)  0           resnet50_bn2b_branch2c[0][0]
#                                                                  resnet50_activation_53[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_56 (Activat (None, 56, 56, 256)  0           resnet50_add_18[0][0]
# __________________________________________________________________________________________________
# resnet50_res2c_branch2a (Conv2D (None, 56, 56, 64)   16448       resnet50_activation_56[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2c_branch2a (BatchNo (None, 56, 56, 64)   256         resnet50_res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_57 (Activat (None, 56, 56, 64)   0           resnet50_bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res2c_branch2b (Conv2D (None, 56, 56, 64)   36928       resnet50_activation_57[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2c_branch2b (BatchNo (None, 56, 56, 64)   256         resnet50_res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_58 (Activat (None, 56, 56, 64)   0           resnet50_bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res2c_branch2c (Conv2D (None, 56, 56, 256)  16640       resnet50_activation_58[0][0]
# __________________________________________________________________________________________________
# resnet50_bn2c_branch2c (BatchNo (None, 56, 56, 256)  1024        resnet50_res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_19 (Add)           (None, 56, 56, 256)  0           resnet50_bn2c_branch2c[0][0]
#                                                                  resnet50_activation_56[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_59 (Activat (None, 56, 56, 256)  0           resnet50_add_19[0][0]
# __________________________________________________________________________________________________
# resnet50_res3a_branch2a (Conv2D (None, 28, 28, 128)  32896       resnet50_activation_59[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3a_branch2a (BatchNo (None, 28, 28, 128)  512         resnet50_res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_60 (Activat (None, 28, 28, 128)  0           resnet50_bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res3a_branch2b (Conv2D (None, 28, 28, 128)  147584      resnet50_activation_60[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3a_branch2b (BatchNo (None, 28, 28, 128)  512         resnet50_res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_61 (Activat (None, 28, 28, 128)  0           resnet50_bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res3a_branch2c (Conv2D (None, 28, 28, 512)  66048       resnet50_activation_61[0][0]
# __________________________________________________________________________________________________
# resnet50_res3a_branch1 (Conv2D) (None, 28, 28, 512)  131584      resnet50_activation_59[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3a_branch2c (BatchNo (None, 28, 28, 512)  2048        resnet50_res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3a_branch1 (BatchNor (None, 28, 28, 512)  2048        resnet50_res3a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_add_20 (Add)           (None, 28, 28, 512)  0           resnet50_bn3a_branch2c[0][0]
#                                                                  resnet50_bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_62 (Activat (None, 28, 28, 512)  0           resnet50_add_20[0][0]
# __________________________________________________________________________________________________
# resnet50_res3b_branch2a (Conv2D (None, 28, 28, 128)  65664       resnet50_activation_62[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3b_branch2a (BatchNo (None, 28, 28, 128)  512         resnet50_res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_63 (Activat (None, 28, 28, 128)  0           resnet50_bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res3b_branch2b (Conv2D (None, 28, 28, 128)  147584      resnet50_activation_63[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3b_branch2b (BatchNo (None, 28, 28, 128)  512         resnet50_res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_64 (Activat (None, 28, 28, 128)  0           resnet50_bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res3b_branch2c (Conv2D (None, 28, 28, 512)  66048       resnet50_activation_64[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3b_branch2c (BatchNo (None, 28, 28, 512)  2048        resnet50_res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_21 (Add)           (None, 28, 28, 512)  0           resnet50_bn3b_branch2c[0][0]
#                                                                  resnet50_activation_62[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_65 (Activat (None, 28, 28, 512)  0           resnet50_add_21[0][0]
# __________________________________________________________________________________________________
# resnet50_res3c_branch2a (Conv2D (None, 28, 28, 128)  65664       resnet50_activation_65[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3c_branch2a (BatchNo (None, 28, 28, 128)  512         resnet50_res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_66 (Activat (None, 28, 28, 128)  0           resnet50_bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res3c_branch2b (Conv2D (None, 28, 28, 128)  147584      resnet50_activation_66[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3c_branch2b (BatchNo (None, 28, 28, 128)  512         resnet50_res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_67 (Activat (None, 28, 28, 128)  0           resnet50_bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res3c_branch2c (Conv2D (None, 28, 28, 512)  66048       resnet50_activation_67[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3c_branch2c (BatchNo (None, 28, 28, 512)  2048        resnet50_res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_22 (Add)           (None, 28, 28, 512)  0           resnet50_bn3c_branch2c[0][0]
#                                                                  resnet50_activation_65[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_68 (Activat (None, 28, 28, 512)  0           resnet50_add_22[0][0]
# __________________________________________________________________________________________________
# resnet50_res3d_branch2a (Conv2D (None, 28, 28, 128)  65664       resnet50_activation_68[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3d_branch2a (BatchNo (None, 28, 28, 128)  512         resnet50_res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_69 (Activat (None, 28, 28, 128)  0           resnet50_bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res3d_branch2b (Conv2D (None, 28, 28, 128)  147584      resnet50_activation_69[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3d_branch2b (BatchNo (None, 28, 28, 128)  512         resnet50_res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_70 (Activat (None, 28, 28, 128)  0           resnet50_bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# resnet50_res3d_branch2c (Conv2D (None, 28, 28, 512)  66048       resnet50_activation_70[0][0]
# __________________________________________________________________________________________________
# resnet50_bn3d_branch2c (BatchNo (None, 28, 28, 512)  2048        resnet50_res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_add_23 (Add)           (None, 28, 28, 512)  0           resnet50_bn3d_branch2c[0][0]
#                                                                  resnet50_activation_68[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_71 (Activat (None, 28, 28, 512)  0           resnet50_add_23[0][0]
# __________________________________________________________________________________________________
# resnet50_res4a_branch2a (Conv2D (None, 14, 14, 256)  131328      resnet50_activation_71[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4a_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_72 (Activat (None, 14, 14, 256)  0           resnet50_bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# resnet50_res4a_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_72[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4a_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv1_pad (ZeroPaddin (None, 225, 225, 3)  0           mobilenet_vgg16_resnet50_input_2[
# __________________________________________________________________________________________________
# resnet50_activation_73 (Activat (None, 14, 14, 256)  0           resnet50_bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv1 (Conv2D)        (None, 112, 112, 32) 864         mobilenet_conv1_pad[0][0]
# __________________________________________________________________________________________________
# resnet50_res4a_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_73[0][0]
# __________________________________________________________________________________________________
# resnet50_res4a_branch1 (Conv2D) (None, 14, 14, 1024) 525312      resnet50_activation_71[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv1_bn (BatchNormal (None, 112, 112, 32) 128         mobilenet_conv1[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4a_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4a_branch1 (BatchNor (None, 14, 14, 1024) 4096        resnet50_res4a_branch1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv1_relu (ReLU)     (None, 112, 112, 32) 0           mobilenet_conv1_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_add_24 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4a_branch2c[0][0]
#                                                                  resnet50_bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_1 (DepthwiseC (None, 112, 112, 32) 288         mobilenet_conv1_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_74 (Activat (None, 14, 14, 1024) 0           resnet50_add_24[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_1_bn (BatchNo (None, 112, 112, 32) 128         mobilenet_conv_dw_1[0][0]
# __________________________________________________________________________________________________
# resnet50_res4b_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_74[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_1_relu (ReLU) (None, 112, 112, 32) 0           mobilenet_conv_dw_1_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4b_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_1 (Conv2D)    (None, 112, 112, 64) 2048        mobilenet_conv_dw_1_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_75 (Activat (None, 14, 14, 256)  0           resnet50_bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_1_bn (BatchNo (None, 112, 112, 64) 256         mobilenet_conv_pw_1[0][0]
# __________________________________________________________________________________________________
# resnet50_res4b_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_75[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_1_relu (ReLU) (None, 112, 112, 64) 0           mobilenet_conv_pw_1_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4b_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pad_2 (ZeroPaddi (None, 113, 113, 64) 0           mobilenet_conv_pw_1_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_76 (Activat (None, 14, 14, 256)  0           resnet50_bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_2 (DepthwiseC (None, 56, 56, 64)   576         mobilenet_conv_pad_2[0][0]
# __________________________________________________________________________________________________
# resnet50_res4b_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_76[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_2_bn (BatchNo (None, 56, 56, 64)   256         mobilenet_conv_dw_2[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4b_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_2_relu (ReLU) (None, 56, 56, 64)   0           mobilenet_conv_dw_2_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_add_25 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4b_branch2c[0][0]
#                                                                  resnet50_activation_74[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_2 (Conv2D)    (None, 56, 56, 128)  8192        mobilenet_conv_dw_2_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_77 (Activat (None, 14, 14, 1024) 0           resnet50_add_25[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_2_bn (BatchNo (None, 56, 56, 128)  512         mobilenet_conv_pw_2[0][0]
# __________________________________________________________________________________________________
# resnet50_res4c_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_77[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_2_relu (ReLU) (None, 56, 56, 128)  0           mobilenet_conv_pw_2_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4c_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_3 (DepthwiseC (None, 56, 56, 128)  1152        mobilenet_conv_pw_2_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_78 (Activat (None, 14, 14, 256)  0           resnet50_bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_3_bn (BatchNo (None, 56, 56, 128)  512         mobilenet_conv_dw_3[0][0]
# __________________________________________________________________________________________________
# resnet50_res4c_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_78[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_3_relu (ReLU) (None, 56, 56, 128)  0           mobilenet_conv_dw_3_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4c_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_3 (Conv2D)    (None, 56, 56, 128)  16384       mobilenet_conv_dw_3_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_79 (Activat (None, 14, 14, 256)  0           resnet50_bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_3_bn (BatchNo (None, 56, 56, 128)  512         mobilenet_conv_pw_3[0][0]
# __________________________________________________________________________________________________
# resnet50_res4c_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_79[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_3_relu (ReLU) (None, 56, 56, 128)  0           mobilenet_conv_pw_3_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4c_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pad_4 (ZeroPaddi (None, 57, 57, 128)  0           mobilenet_conv_pw_3_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_add_26 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4c_branch2c[0][0]
#                                                                  resnet50_activation_77[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_4 (DepthwiseC (None, 28, 28, 128)  1152        mobilenet_conv_pad_4[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_80 (Activat (None, 14, 14, 1024) 0           resnet50_add_26[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_4_bn (BatchNo (None, 28, 28, 128)  512         mobilenet_conv_dw_4[0][0]
# __________________________________________________________________________________________________
# resnet50_res4d_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_80[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_4_relu (ReLU) (None, 28, 28, 128)  0           mobilenet_conv_dw_4_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4d_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_4 (Conv2D)    (None, 28, 28, 256)  32768       mobilenet_conv_dw_4_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_81 (Activat (None, 14, 14, 256)  0           resnet50_bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_4_bn (BatchNo (None, 28, 28, 256)  1024        mobilenet_conv_pw_4[0][0]
# __________________________________________________________________________________________________
# resnet50_res4d_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_81[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_4_relu (ReLU) (None, 28, 28, 256)  0           mobilenet_conv_pw_4_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4d_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_5 (DepthwiseC (None, 28, 28, 256)  2304        mobilenet_conv_pw_4_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_82 (Activat (None, 14, 14, 256)  0           resnet50_bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_5_bn (BatchNo (None, 28, 28, 256)  1024        mobilenet_conv_dw_5[0][0]
# __________________________________________________________________________________________________
# resnet50_res4d_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_82[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_5_relu (ReLU) (None, 28, 28, 256)  0           mobilenet_conv_dw_5_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4d_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_5 (Conv2D)    (None, 28, 28, 256)  65536       mobilenet_conv_dw_5_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_add_27 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4d_branch2c[0][0]
#                                                                  resnet50_activation_80[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_5_bn (BatchNo (None, 28, 28, 256)  1024        mobilenet_conv_pw_5[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_83 (Activat (None, 14, 14, 1024) 0           resnet50_add_27[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_5_relu (ReLU) (None, 28, 28, 256)  0           mobilenet_conv_pw_5_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_res4e_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_83[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pad_6 (ZeroPaddi (None, 29, 29, 256)  0           mobilenet_conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4e_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_6 (DepthwiseC (None, 14, 14, 256)  2304        mobilenet_conv_pad_6[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_84 (Activat (None, 14, 14, 256)  0           resnet50_bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_6_bn (BatchNo (None, 14, 14, 256)  1024        mobilenet_conv_dw_6[0][0]
# __________________________________________________________________________________________________
# resnet50_res4e_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_84[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_6_relu (ReLU) (None, 14, 14, 256)  0           mobilenet_conv_dw_6_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4e_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_6 (Conv2D)    (None, 14, 14, 512)  131072      mobilenet_conv_dw_6_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_85 (Activat (None, 14, 14, 256)  0           resnet50_bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_6_bn (BatchNo (None, 14, 14, 512)  2048        mobilenet_conv_pw_6[0][0]
# __________________________________________________________________________________________________
# resnet50_res4e_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_85[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_6_relu (ReLU) (None, 14, 14, 512)  0           mobilenet_conv_pw_6_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4e_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_7 (DepthwiseC (None, 14, 14, 512)  4608        mobilenet_conv_pw_6_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_add_28 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4e_branch2c[0][0]
#                                                                  resnet50_activation_83[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_7_bn (BatchNo (None, 14, 14, 512)  2048        mobilenet_conv_dw_7[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_86 (Activat (None, 14, 14, 1024) 0           resnet50_add_28[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_7_relu (ReLU) (None, 14, 14, 512)  0           mobilenet_conv_dw_7_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_res4f_branch2a (Conv2D (None, 14, 14, 256)  262400      resnet50_activation_86[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_7 (Conv2D)    (None, 14, 14, 512)  262144      mobilenet_conv_dw_7_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4f_branch2a (BatchNo (None, 14, 14, 256)  1024        resnet50_res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_7_bn (BatchNo (None, 14, 14, 512)  2048        mobilenet_conv_pw_7[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_87 (Activat (None, 14, 14, 256)  0           resnet50_bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_7_relu (ReLU) (None, 14, 14, 512)  0           mobilenet_conv_pw_7_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_res4f_branch2b (Conv2D (None, 14, 14, 256)  590080      resnet50_activation_87[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_8 (DepthwiseC (None, 14, 14, 512)  4608        mobilenet_conv_pw_7_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4f_branch2b (BatchNo (None, 14, 14, 256)  1024        resnet50_res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_8_bn (BatchNo (None, 14, 14, 512)  2048        mobilenet_conv_dw_8[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_88 (Activat (None, 14, 14, 256)  0           resnet50_bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_8_relu (ReLU) (None, 14, 14, 512)  0           mobilenet_conv_dw_8_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_res4f_branch2c (Conv2D (None, 14, 14, 1024) 263168      resnet50_activation_88[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_8 (Conv2D)    (None, 14, 14, 512)  262144      mobilenet_conv_dw_8_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_bn4f_branch2c (BatchNo (None, 14, 14, 1024) 4096        resnet50_res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_8_bn (BatchNo (None, 14, 14, 512)  2048        mobilenet_conv_pw_8[0][0]
# __________________________________________________________________________________________________
# resnet50_add_29 (Add)           (None, 14, 14, 1024) 0           resnet50_bn4f_branch2c[0][0]
#                                                                  resnet50_activation_86[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_8_relu (ReLU) (None, 14, 14, 512)  0           mobilenet_conv_pw_8_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_89 (Activat (None, 14, 14, 1024) 0           resnet50_add_29[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_9 (DepthwiseC (None, 14, 14, 512)  4608        mobilenet_conv_pw_8_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_res5a_branch2a (Conv2D (None, 7, 7, 512)    524800      resnet50_activation_89[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_9_bn (BatchNo (None, 14, 14, 512)  2048        mobilenet_conv_dw_9[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5a_branch2a (BatchNo (None, 7, 7, 512)    2048        resnet50_res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_9_relu (ReLU) (None, 14, 14, 512)  0           mobilenet_conv_dw_9_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_90 (Activat (None, 7, 7, 512)    0           resnet50_bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_9 (Conv2D)    (None, 14, 14, 512)  262144      mobilenet_conv_dw_9_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_res5a_branch2b (Conv2D (None, 7, 7, 512)    2359808     resnet50_activation_90[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_9_bn (BatchNo (None, 14, 14, 512)  2048        mobilenet_conv_pw_9[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5a_branch2b (BatchNo (None, 7, 7, 512)    2048        resnet50_res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_9_relu (ReLU) (None, 14, 14, 512)  0           mobilenet_conv_pw_9_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_91 (Activat (None, 7, 7, 512)    0           resnet50_bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_10 (Depthwise (None, 14, 14, 512)  4608        mobilenet_conv_pw_9_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_res5a_branch2c (Conv2D (None, 7, 7, 2048)   1050624     resnet50_activation_91[0][0]
# __________________________________________________________________________________________________
# resnet50_res5a_branch1 (Conv2D) (None, 7, 7, 2048)   2099200     resnet50_activation_89[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_10_bn (BatchN (None, 14, 14, 512)  2048        mobilenet_conv_dw_10[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5a_branch2c (BatchNo (None, 7, 7, 2048)   8192        resnet50_res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5a_branch1 (BatchNor (None, 7, 7, 2048)   8192        resnet50_res5a_branch1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_10_relu (ReLU (None, 14, 14, 512)  0           mobilenet_conv_dw_10_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_add_30 (Add)           (None, 7, 7, 2048)   0           resnet50_bn5a_branch2c[0][0]
#                                                                  resnet50_bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_10 (Conv2D)   (None, 14, 14, 512)  262144      mobilenet_conv_dw_10_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_92 (Activat (None, 7, 7, 2048)   0           resnet50_add_30[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_10_bn (BatchN (None, 14, 14, 512)  2048        mobilenet_conv_pw_10[0][0]
# __________________________________________________________________________________________________
# resnet50_res5b_branch2a (Conv2D (None, 7, 7, 512)    1049088     resnet50_activation_92[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_10_relu (ReLU (None, 14, 14, 512)  0           mobilenet_conv_pw_10_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5b_branch2a (BatchNo (None, 7, 7, 512)    2048        resnet50_res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_11 (Depthwise (None, 14, 14, 512)  4608        mobilenet_conv_pw_10_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_93 (Activat (None, 7, 7, 512)    0           resnet50_bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# vgg16_block1_conv1 (Conv2D)     (None, 224, 224, 64) 1792        mobilenet_vgg16_resnet50_input_2[
# __________________________________________________________________________________________________
# mobilenet_conv_dw_11_bn (BatchN (None, 14, 14, 512)  2048        mobilenet_conv_dw_11[0][0]
# __________________________________________________________________________________________________
# resnet50_res5b_branch2b (Conv2D (None, 7, 7, 512)    2359808     resnet50_activation_93[0][0]
# __________________________________________________________________________________________________
# vgg16_block1_conv2 (Conv2D)     (None, 224, 224, 64) 36928       vgg16_block1_conv1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_11_relu (ReLU (None, 14, 14, 512)  0           mobilenet_conv_dw_11_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5b_branch2b (BatchNo (None, 7, 7, 512)    2048        resnet50_res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# vgg16_block1_pool (MaxPooling2D (None, 112, 112, 64) 0           vgg16_block1_conv2[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_11 (Conv2D)   (None, 14, 14, 512)  262144      mobilenet_conv_dw_11_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_94 (Activat (None, 7, 7, 512)    0           resnet50_bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# vgg16_block2_conv1 (Conv2D)     (None, 112, 112, 128 73856       vgg16_block1_pool[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_11_bn (BatchN (None, 14, 14, 512)  2048        mobilenet_conv_pw_11[0][0]
# __________________________________________________________________________________________________
# resnet50_res5b_branch2c (Conv2D (None, 7, 7, 2048)   1050624     resnet50_activation_94[0][0]
# __________________________________________________________________________________________________
# vgg16_block2_conv2 (Conv2D)     (None, 112, 112, 128 147584      vgg16_block2_conv1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_11_relu (ReLU (None, 14, 14, 512)  0           mobilenet_conv_pw_11_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5b_branch2c (BatchNo (None, 7, 7, 2048)   8192        resnet50_res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# vgg16_block2_pool (MaxPooling2D (None, 56, 56, 128)  0           vgg16_block2_conv2[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pad_12 (ZeroPadd (None, 15, 15, 512)  0           mobilenet_conv_pw_11_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_add_31 (Add)           (None, 7, 7, 2048)   0           resnet50_bn5b_branch2c[0][0]
#                                                                  resnet50_activation_92[0][0]
# __________________________________________________________________________________________________
# vgg16_block3_conv1 (Conv2D)     (None, 56, 56, 256)  295168      vgg16_block2_pool[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_12 (Depthwise (None, 7, 7, 512)    4608        mobilenet_conv_pad_12[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_95 (Activat (None, 7, 7, 2048)   0           resnet50_add_31[0][0]
# __________________________________________________________________________________________________
# vgg16_block3_conv2 (Conv2D)     (None, 56, 56, 256)  590080      vgg16_block3_conv1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_12_bn (BatchN (None, 7, 7, 512)    2048        mobilenet_conv_dw_12[0][0]
# __________________________________________________________________________________________________
# resnet50_res5c_branch2a (Conv2D (None, 7, 7, 512)    1049088     resnet50_activation_95[0][0]
# __________________________________________________________________________________________________
# vgg16_block3_conv3 (Conv2D)     (None, 56, 56, 256)  590080      vgg16_block3_conv2[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_12_relu (ReLU (None, 7, 7, 512)    0           mobilenet_conv_dw_12_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5c_branch2a (BatchNo (None, 7, 7, 512)    2048        resnet50_res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# vgg16_block3_pool (MaxPooling2D (None, 28, 28, 256)  0           vgg16_block3_conv3[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_12 (Conv2D)   (None, 7, 7, 1024)   524288      mobilenet_conv_dw_12_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_96 (Activat (None, 7, 7, 512)    0           resnet50_bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_conv1 (Conv2D)     (None, 28, 28, 512)  1180160     vgg16_block3_pool[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_12_bn (BatchN (None, 7, 7, 1024)   4096        mobilenet_conv_pw_12[0][0]
# __________________________________________________________________________________________________
# resnet50_res5c_branch2b (Conv2D (None, 7, 7, 512)    2359808     resnet50_activation_96[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_conv2 (Conv2D)     (None, 28, 28, 512)  2359808     vgg16_block4_conv1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_12_relu (ReLU (None, 7, 7, 1024)   0           mobilenet_conv_pw_12_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5c_branch2b (BatchNo (None, 7, 7, 512)    2048        resnet50_res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_conv3 (Conv2D)     (None, 28, 28, 512)  2359808     vgg16_block4_conv2[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_13 (Depthwise (None, 7, 7, 1024)   9216        mobilenet_conv_pw_12_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_97 (Activat (None, 7, 7, 512)    0           resnet50_bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_pool (MaxPooling2D (None, 14, 14, 512)  0           vgg16_block4_conv3[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_13_bn (BatchN (None, 7, 7, 1024)   4096        mobilenet_conv_dw_13[0][0]
# __________________________________________________________________________________________________
# resnet50_res5c_branch2c (Conv2D (None, 7, 7, 2048)   1050624     resnet50_activation_97[0][0]
# __________________________________________________________________________________________________
# vgg16_block5_conv1 (Conv2D)     (None, 14, 14, 512)  2359808     vgg16_block4_pool[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_dw_13_relu (ReLU (None, 7, 7, 1024)   0           mobilenet_conv_dw_13_bn[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5c_branch2c (BatchNo (None, 7, 7, 2048)   8192        resnet50_res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# vgg16_block5_conv2 (Conv2D)     (None, 14, 14, 512)  2359808     vgg16_block5_conv1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_13 (Conv2D)   (None, 7, 7, 1024)   1048576     mobilenet_conv_dw_13_relu[0][0]
# __________________________________________________________________________________________________
# resnet50_add_32 (Add)           (None, 7, 7, 2048)   0           resnet50_bn5c_branch2c[0][0]
#                                                                  resnet50_activation_95[0][0]
# __________________________________________________________________________________________________
# vgg16_block5_conv3 (Conv2D)     (None, 14, 14, 512)  2359808     vgg16_block5_conv2[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_13_bn (BatchN (None, 7, 7, 1024)   4096        mobilenet_conv_pw_13[0][0]
# __________________________________________________________________________________________________
# resnet50_activation_98 (Activat (None, 7, 7, 2048)   0           resnet50_add_32[0][0]
# __________________________________________________________________________________________________
# vgg16_block5_pool (MaxPooling2D (None, 7, 7, 512)    0           vgg16_block5_conv3[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv_pw_13_relu (ReLU (None, 7, 7, 1024)   0           mobilenet_conv_pw_13_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 2048)         0           resnet50_activation_98[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 512)          0           vgg16_block5_pool[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 1024)         0           mobilenet_conv_pw_13_relu[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 3584)         0           global_average_pooling2d_3[0][0]
#                                                                  global_average_pooling2d_4[0][0]
#                                                                  global_average_pooling2d_5[0][0]
# ==================================================================================================
# Total params: 41,531,264
# Trainable params: 75,008
# Non-trainable params: 41,456,256
# __________________________________________________________________________________________________

# %%
len(train_gen.x) // 60
# Out:
# 35

# %%
# # model.fit_generator(image_gen.flow(x_train, y_train.toarray(), batch_size=batch_size),
# #           steps_per_epoch=  x_train.shape[0]//batch_size,
# #           epochs=epochs,
# #           verbose=1,
# #           class_weight=class_weight_dic)

# hist = model.fit_generator(train_gen,
#                     steps_per_epoch=len(train_gen.x)//BATCH_SIZE,
#                     epochs=EPOCHS,
#                     validation_data=(X_val, y_val),
#                     validation_steps=X_val.shape[0]//BATCH_SIZE)

# %%
# hist = model.fit(X_train, 
#                  y_train, 
#                  batch_size=BATCH_SIZE, 
#                  epochs=3, 
#                  verbose=1, 
#                  callbacks=None, 
#                  validation_data=(X_val, y_val))

# %%
features, labels = model.predict(X_train), y_train

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from xgboost import XGBClassifier

y_labels = np.argmax(labels,axis = 1) 

folds = 4
param_comb = 5

start = time.time()

# A parameter grid for XGBoost
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }

xgb = XGBClassifier(learning_rate=0.02, 
                    n_estimators=600, 
                    objective='multi:softmax', 
                    silent=True, 
                    nthread=1)

skf = StratifiedKFold(n_splits=folds, shuffle = True, random_state = 2020)

random_search = RandomizedSearchCV(xgb, 
                                   param_distributions=params, 
                                   n_iter=param_comb, 
                                  #  scoring='roc_auc', 
                                   n_jobs=4, 
                                   cv=skf.split(features,y_labels), 
                                   verbose=3, 
                                   random_state=2020)

random_search.fit(features, y_labels)

end = time.time()
print('Time taken in grid search: {0: .2f}'.format(end - start))
# Out:
# Fitting 4 folds for each of 5 candidates, totalling 20 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  20 out of  20 | elapsed: 109.2min remaining:    0.0s
# [Parallel(n_jobs=4)]: Done  20 out of  20 | elapsed: 109.2min finished
# Time taken in grid search:  7064.35

# %%
best_score = random_search.best_score_
best_params = random_search.best_params_
print('Best Score using random search: \n', best_score)
print('Best Parameters using random search: \n', best_params)
# Out:
# Best Score using random search:
#  0.939622641509434
# Best Parameters using random search:
#  {'subsample': 0.6, 'min_child_weight': 5, 'max_depth': 4, 'gamma': 1, 'colsample_bytree': 0.8}

# %%
# # Set best parameters given by random search 
# xgb = XGBClassifier(learning_rate=0.02, 
#                     n_estimators=600, 
#                     objective='multi:softmax', 
#                     silent=True, 
#                     nthread=1)
xgb.set_params(subsample=0.6, 
               min_child_weight=5, 
               max_depth=4, 
               gamma=1, 
              #  max_features=None,
               colsample_bytree=0.8)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=1,
#               learning_rate=0.02, max_delta_step=0, max_depth=4,
#               min_child_weight=5, missing=None, n_estimators=600, n_jobs=1,
#               nthread=1, objective='multi:softmax', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#               subsample=0.6, verbosity=1)

# %%
test_features, test_labels = model.predict(X_test), y_test

# %%
xgb.fit(features, y_labels)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=1,
#               learning_rate=0.02, max_delta_step=0, max_depth=4,
#               min_child_weight=5, missing=None, n_estimators=600, n_jobs=1,
#               nthread=1, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=True, subsample=0.6, verbosity=1)

# %%
predictions_xgb = xgb.predict(test_features)

# %%
y_test_labels = np.argmax(test_labels, axis = 1) 
accuracy_xgb = xgb.score(test_features, y_test_labels)

# %%
print("accuracy : ", accuracy_xgb)
# Out:
# accuracy :  0.9476758953517908

# %%
# model.evaluate(X_test, y_test)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

# Plot training & validation accuracy values
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy') 
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Confusion matrix
# Credit: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.round(cm, 2)
    thresh = np.max(cm) // 2 
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Y_pred = model.predict(X_test)
# Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Y_true = np.argmax(y_test,axis = 1) 
# confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)

# %%
# plot_confusion_matrix(confusion_mtx, classes = CLASSES)

# %%
Y_pred = predictions_xgb
# Y_pred_classes = np.argmax(Y_pred,axis = 1) 
Y_pred_classes = Y_pred
# Y_true = np.argmax(test_labels,axis = 1) 
Y_true = y_test_labels
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)

# %%
plot_confusion_matrix(confusion_mtx, classes = CLASSES)

# %%
# from sklearn.metrics import confusion_matrix
# import seaborn as sns

# # plot_confusion_matrix(confusion_mtx, classes = CLASSES, normalize=True)
# conf_mat = confusion_matrix(Y_true, Y_pred_classes)
# # Normalise
# conf_mat_norm = conf_mat.astype('float') / conf_mat.sum(axis=1)[:, np.newaxis]
# fig, ax = plt.subplots(figsize=(10,10))
# sns.heatmap(conf_mat_norm, annot=True, cmap=plt.cm.Blues, fmt='.2f', xticklabels=CLASSES, yticklabels=CLASSES)
# plt.ylabel('Actual')
# plt.xlabel('Predicted')
# plt.show(block=False)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# plot_confusion_matrix(confusion_mtx, classes = CLASSES, normalize=True)
conf_mat = confusion_matrix(Y_true, Y_pred_classes)
# Normalise
conf_mat_norm = conf_mat.astype('float') / conf_mat.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat_norm, annot=True, cmap=plt.cm.Blues, fmt='.2f', xticklabels=CLASSES, yticklabels=CLASSES)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show(block=False)

# %%
model.save_weights('Covid19_Detection_pretrained_VGG_Resnet_XGB.h5')

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True, to_file='Covid19_Detection_pretrained_VGG_Resnet_XGB.png')

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(random_state=2020)

# %%
from sklearn.model_selection import GridSearchCV

np.random.seed(2020)
start = time.time()

param_dist = {'max_depth': [2, 3, 4],
              'bootstrap': [True, False],
              'max_features': ['auto', 'sqrt', 'log2', None],
              'criterion': ['gini', 'entropy']}

cv_rf = GridSearchCV(rf_clf, cv = 2,
                     param_grid=param_dist, 
                     n_jobs = 3)

cv_rf.fit(features, labels)
print('Best Parameters using grid search: \n', cv_rf.best_params_)
end = time.time()
print('Time taken in grid search: {0: .2f}'.format(end - start))
# Out:
# Best Parameters using grid search:
#  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None}
# Time taken in grid search:  4322.98

# %%
# Set best parameters given by grid search 
rf_clf.set_params(bootstrap=True, criterion='entropy', max_depth=4, max_features=None)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=4, max_features=None,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=2020,
#                        verbose=0, warm_start=False)

# %%
rf_clf.fit(features, labels)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=4, max_features=None,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=2020,
#                        verbose=0, warm_start=False)

# %%
test_features, test_labels = model.predict(X_test), y_test

# %%
predictions_rf = rf_clf.predict(test_features)

# %%
accuracy_rf = rf_clf.score(test_features, test_labels)

# %%
print("accuracy : ", accuracy_rf)
# Out:
# accuracy :  0.8953517907035814
