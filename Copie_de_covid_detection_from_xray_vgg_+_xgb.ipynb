# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/ieee8023/covid-chestxray-dataset.git
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 3213, done.
# remote: Total 3213 (delta 0), reused 0 (delta 0), pack-reused 3213
# Receiving objects: 100% (3213/3213), 582.57 MiB | 38.94 MiB/s, done.
# Resolving deltas: 100% (1276/1276), done.
# Checking out files: 100% (991/991), done.

# %%
# !mkdir -p /content/dataset/covid/
# !mkdir -p /content/dataset/normal/
# !mkdir -p /content/dataset/pneumonia/

# %%
# !unzip "/content/drive/My Drive/Datasets/Chest X-Ray Images (Pneumonia).zip"

# %%
# !mv /content/chest_xray/train/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/train/PNEUMONIA/* /content/dataset/pneumonia/
# !mv /content/chest_xray/val/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/val/PNEUMONIA/* /content/dataset/pneumonia/
# !mv /content/chest_xray/test/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/test/PNEUMONIA/* /content/dataset/pneumonia/

# %%
import pandas as pd
import shutil
import os

# Selecting all combination of 'COVID-19' patients with 'PA' X-Ray view
virus = "COVID-19" # Virus to look for
x_ray_view = "PA" # View of X-Ray

meta_data = "/content/covid-chestxray-dataset/metadata.csv"
images_dir = "/content/covid-chestxray-dataset/images"
output_dir = "/content/dataset/covid/"

metadata_csv = pd.read_csv(meta_data)

for (i, row) in metadata_csv.iterrows():
	if row["finding"] != virus or row["view"] != x_ray_view:
		continue

	filename = row["filename"].split(os.path.sep)[-1]
	filePath = os.path.sep.join([images_dir, filename])
	shutil.copy2(filePath, output_dir)

# %% [markdown]
# ### Adding covid images

# %%
# !git clone https://github.com/UCSD-AI4H/COVID-CT.git
# Out:
# Cloning into 'COVID-CT'...
# remote: Enumerating objects: 5459, done.
# remote: Total 5459 (delta 0), reused 0 (delta 0), pack-reused 5459
# Receiving objects: 100% (5459/5459), 1.09 GiB | 37.07 MiB/s, done.
# Resolving deltas: 100% (363/363), done.
# Checking out files: 100% (1048/1048), done.

# %%
# !unzip /content/COVID-CT/Images-processed/CT_COVID.zip
# !unzip /content/COVID-CT/Images-processed/CT_NonCOVID.zip

# %%
# !mv /content/CT_COVID/* /content/dataset/covid/

# %%
# !unzip "/content/drive/My Drive/Datasets/COVID19/COV-Img.zip"
# Out:
# unzip:  cannot find or open /content/drive/My Drive/Datasets/COVID19/COV-Img.zip, /content/drive/My Drive/Datasets/COVID19/COV-Img.zip.zip or /content/drive/My Drive/Datasets/COVID19/COV-Img.zip.ZIP.

# %%
# !mkdir -p /content/test/covid/

# %%
# !mv /content/COV-Img/* /content/test/covid/

# %% [markdown]
#   ## Dependencies

# %%
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Input, average, Average, concatenate
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense

from keras.models import Sequential, Model
from keras.applications.xception import Xception
from keras.applications.resnet50 import ResNet50
from keras.applications import ResNet101
from keras.applications import DenseNet201
from keras.applications import MobileNet
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.optimizers import Adam, SGD, RMSprop

import tensorflow as tf

import os
import numpy as np
import pandas as pd
import time

import random

from PIL import Image
import glob
import matplotlib.pyplot as plt
from matplotlib import pyplot
import matplotlib.image as mpimg
# %matplotlib inline

# %%
DATASET_DIR = "/content/dataset"

NORMAL_DIR = DATASET_DIR + "/normal"
PNEUMONIA_DIR = DATASET_DIR + "/pneumonia"
COVID_DIR = DATASET_DIR + "/covid"

NORMAL_TRAIN_SAMPLES = 500 # total samples = 1583
PNEUMONIA_TRAIN_SAMPLES = 500 # total samples = 4273
COVID_TRAIN_SAMPLES = 120 # total samples = 201

IMG_W = 224
IMG_H = 224
IMG_C = 1
INPUT_SHAPE = (IMG_W, IMG_H, IMG_C)

CLASSES = [ "NORMAL", "PNEUMONIA", "COVID" ]
NB_CLASSES = len(CLASSES)

EPOCHS = 2
BATCH_SIZE = 16

# %%
normal_images = []
pneumonia_images = []
covid_images = []

# %%
for img_path in glob.glob(NORMAL_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    normal_images.append(img[:np.newaxis])

for img_path in glob.glob(PNEUMONIA_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    pneumonia_images.append(img[:np.newaxis])

for img_path in glob.glob(COVID_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    covid_images.append(img[:np.newaxis])

# %%
len(normal_images), len(pneumonia_images), len(covid_images)
# Out:
# (1583, 4273, 201)

# %%
width=150
height=150
rows = 1
cols = 3

imgs = [ normal_images[0], pneumonia_images[0], covid_images[0]]

axes=[]
fig=plt.figure()

for i in range(rows*cols):
    img = imgs[i]
    axes.append( fig.add_subplot(rows, cols, i+1) )
    plt.imshow(img)

axes[0].set_title('NORMAL')
axes[1].set_title('PNEUMONIA')
axes[2].set_title('COVID')
fig.tight_layout()    
plt.show()

# %%
# X = []
# y = []

# for item in normal_images:
#     img = np.asarray(item)
#     img = img.reshape(INPUT_SHAPE)
#     X.append(img)    
#     y.append(CLASSES.index("NORMAL"))

# for item in pneumonia_images:
#     img = np.asarray(item)
#     img = img.reshape(INPUT_SHAPE)
#     X.append(img)    
#     y.append(CLASSES.index("PNEUMONIA"))

# for item in covid_images:
#     img = np.asarray(item)
#     img = img.reshape(INPUT_SHAPE)
#     X.append(img)    
#     y.append(CLASSES.index("COVID"))

# X = np.asarray(X)
# y = np.asarray(y)

# %%
normal_X = []
pneumonia_X = []
covid_X = []
normal_y = []
pneumonia_y = []
covid_y = []
X = []
y = []

for item in normal_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    normal_X.append(img)    
    normal_y.append(CLASSES.index("NORMAL"))   
    X.append(img)    
    y.append(CLASSES.index("NORMAL"))

for item in pneumonia_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    pneumonia_X.append(img)    
    pneumonia_y.append(CLASSES.index("PNEUMONIA"))   
    X.append(img)    
    y.append(CLASSES.index("PNEUMONIA"))

for item in covid_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    covid_X.append(img) 
    covid_y.append(CLASSES.index("COVID"))   
    X.append(img)    
    y.append(CLASSES.index("COVID"))

X = np.asarray(X)
y = np.asarray(y)

# %%
X.shape, y.shape
# Out:
# ((6057, 224, 224, 1), (6057,))

# %%
# from sklearn.model_selection import train_test_split
# # X_train, X_test, y_train, y_test = train_test_split(
# #     X, y, test_size=0.2, random_state=2020)


# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2

# %%
X_train_normal = normal_X[:NORMAL_TRAIN_SAMPLES]
X_train_pneumonia = pneumonia_X[:PNEUMONIA_TRAIN_SAMPLES]
X_train_covid = covid_X[:COVID_TRAIN_SAMPLES]
X_test_normal = normal_X[NORMAL_TRAIN_SAMPLES:]
X_test_pneumonia = pneumonia_X[PNEUMONIA_TRAIN_SAMPLES:]
X_test_covid = covid_X[COVID_TRAIN_SAMPLES:]

y_train_normal = normal_y[:NORMAL_TRAIN_SAMPLES]
y_train_pneumonia = pneumonia_y[:PNEUMONIA_TRAIN_SAMPLES]
y_train_covid = covid_y[:COVID_TRAIN_SAMPLES]
y_test_normal = normal_y[NORMAL_TRAIN_SAMPLES:]
y_test_pneumonia = pneumonia_y[PNEUMONIA_TRAIN_SAMPLES:]
y_test_covid = covid_y[COVID_TRAIN_SAMPLES:]


X_train = np.concatenate((X_train_normal, X_train_pneumonia, X_train_covid), axis=0) 
y_train = np.concatenate((y_train_normal, y_train_pneumonia, y_train_covid), axis=0) 

X_test = np.concatenate((X_test_normal, X_test_pneumonia, X_test_covid), axis=0) 
y_test = np.concatenate((y_test_normal, y_test_pneumonia, y_test_covid), axis=0)

# %%
# np.full((len(X_train_normal), 1), y_test_normal[0]).shape

# %%
X_train.shape, y_train.shape
# Out:
# ((1120, 224, 224, 1), (1120,))

# %%
X_test.shape, y_test.shape
# Out:
# ((4937, 224, 224, 1), (4937,))

# %%
a = list(zip(X_train, y_train))
random.shuffle(a)
X_train, y_train = zip(*a)
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
# a = list(zip(X_train, y_train))
# random.shuffle(a)
# X_test, y_test = zip(*a)

# %%
X_train.shape, y_train.shape
# Out:
# ((1120, 224, 224, 1), (1120,))

# %%
# ----------------------

# %%
from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.2, random_state=2020)


# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2
X_val = X_test
y_val = y_test

# %%
X_train = np.repeat(X_train[...,], 3, 3)
X_val = np.repeat(X_val[...,], 3, 3)
X_test = np.repeat(X_test[...,], 3, 3)

# %%
X_train.shape, y_train.shape
# Out:
# ((1120, 224, 224, 3), (1120,))

# %%
X_test.shape, y_test.shape
# Out:
# ((4937, 224, 224, 3), (4937,))

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1, 2]), array([500, 500, 120]))

# %%
np.unique(y_test, return_counts=True)
# Out:
# (array([0, 1, 2]), array([1083, 3773,   81]))

# %%
from keras.utils import to_categorical

y_train = to_categorical(y_train)
y_val = to_categorical(y_val)
y_test = to_categorical(y_test)

# %%
train_da_args = dict(rescale=1./255, 
               shear_range=0.2,
               zoom_range=0.05,
               width_shift_range=0.05,
               height_shift_range=0.05,
               rotation_range=360,
               #  brightness_range=[0.2,1.0],
               vertical_flip=True,
               horizontal_flip=True)

# val_da_args = dict(rescale=1./255)

train_da = ImageDataGenerator(train_da_args)
# val_da = ImageDataGenerator(val_da_args)

train_da.fit(X_train, augment=True)
# val_da.fit(X_train)

train_gen = train_da.flow(X_train, y_train, batch_size=BATCH_SIZE)
# val_gen = train_da.flow(X_val, y_val)

# %%
for i in range(9):
	pyplot.subplot(330 + 1 + i)
	batch = train_gen.next()
	image = batch[0][0].astype('uint8')
	pyplot.imshow(image)

pyplot.show()

# %%
for i in range(9):
	pyplot.subplot(330 + 1 + i)
	batch = train_gen.next()
	image = batch[0][-1].astype('uint8')
	pyplot.imshow(image)

pyplot.show()

# %%
# augmented_data = []
# num_augmented = 0
# for X_batch, y_batch in train_da.flow(X_train, y_train, batch_size=BATCH_SIZE, shuffle=False):
#     augmented_data.append(X_batch)
#     num_augmented += BATCH_SIZE
#     if num_augmented == X_train.shape[0]:
#         break
# augmented_data = np.concatenate(augmented_data)

# %%
# -------------------------

# %%
# len(train_gen.x)

# %%
# vgg_model = VGG16(weights='imagenet', 
#                         include_top=False, 
#                         input_shape=(IMG_H, IMG_W, 3))

# for layer in vgg_model.layers:
#     if isinstance(layer, BatchNormalization):
#         layer.trainable = True
#     else:
#         layer.trainable = False

# model = Sequential()
# model.add(vgg_model)
# model.add(GlobalAveragePooling2D())
# model.add(Dense(256, activation='relu'))
# model.add(Dropout(0.5))
# model.add(BatchNormalization())
# model.add(Dense(NB_CLASSES, activation='softmax'))

# %%
models_input = Input(shape=(IMG_H, IMG_W, 3))

resnet_model = ResNet50(weights='imagenet', 
                        include_top=False, 
                        input_tensor=models_input)

for layer in resnet_model.layers:
    layer.name = "resnet50_" + layer.name
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False
        
        
resnet_gap = GlobalAveragePooling2D()(resnet_model.output)

vgg_model = VGG16(weights='imagenet', 
                        include_top=False, 
                        input_tensor=models_input)

for layer in vgg_model.layers:
    layer.name = "vgg16_" + layer.name
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False

        
vgg_gap = GlobalAveragePooling2D()(vgg_model.output)


densenet_model = DenseNet201(weights='imagenet', 
                        include_top=False, 
                        input_tensor=models_input)

for layer in densenet_model.layers:
    layer.name = "mobilenet_" + layer.name
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False

        
densenet_gap = GlobalAveragePooling2D()(densenet_model.output)

# Merging subnetworks
merged_nets = concatenate([resnet_gap, vgg_gap, densenet_gap])

# x = Dense(NB_CLASSES)(merged_nets)
# out = Activation('softmax')(x)

inputs = input_tensor=models_input
outputs = merged_nets # out # average([resnet_model.output, vgg_model.output])
model = Model(inputs, outputs)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 2s 0us/step

# %%
# model.compile(loss='categorical_crossentropy',
#               optimizer='adam',
#               metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# mobilenet_vgg16_resnet50_input_ (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# mobilenet_zero_padding2d_1 (Zer (None, 230, 230, 3)  0           mobilenet_vgg16_resnet50_input_2[
# __________________________________________________________________________________________________
# mobilenet_conv1/conv (Conv2D)   (None, 112, 112, 64) 9408        mobilenet_zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv1/bn (BatchNormal (None, 112, 112, 64) 256         mobilenet_conv1/conv[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv1/relu (Activatio (None, 112, 112, 64) 0           mobilenet_conv1/bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_zero_padding2d_2 (Zer (None, 114, 114, 64) 0           mobilenet_conv1/relu[0][0]
# __________________________________________________________________________________________________
# mobilenet_pool1 (MaxPooling2D)  (None, 56, 56, 64)   0           mobilenet_zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv2_block1_0_bn (Ba (None, 56, 56, 64)   256         mobilenet_pool1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv2_block1_0_relu ( (None, 56, 56, 64)   0           mobilenet_conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv2_block1_1_conv ( (None, 56, 56, 128)  8192        mobilenet_conv2_block1_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block1_1_bn (Ba (None, 56, 56, 128)  512         mobilenet_conv2_block1_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block1_1_relu ( (None, 56, 56, 128)  0           mobilenet_conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv2_block1_2_conv ( (None, 56, 56, 32)   36864       mobilenet_conv2_block1_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block1_concat ( (None, 56, 56, 96)   0           mobilenet_pool1[0][0]
#                                                                  mobilenet_conv2_block1_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block2_0_bn (Ba (None, 56, 56, 96)   384         mobilenet_conv2_block1_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block2_0_relu ( (None, 56, 56, 96)   0           mobilenet_conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv2_block2_1_conv ( (None, 56, 56, 128)  12288       mobilenet_conv2_block2_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block2_1_bn (Ba (None, 56, 56, 128)  512         mobilenet_conv2_block2_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block2_1_relu ( (None, 56, 56, 128)  0           mobilenet_conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv2_block2_2_conv ( (None, 56, 56, 32)   36864       mobilenet_conv2_block2_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block2_concat ( (None, 56, 56, 128)  0           mobilenet_conv2_block1_concat[0][
#                                                                  mobilenet_conv2_block2_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block3_0_bn (Ba (None, 56, 56, 128)  512         mobilenet_conv2_block2_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block3_0_relu ( (None, 56, 56, 128)  0           mobilenet_conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv2_block3_1_conv ( (None, 56, 56, 128)  16384       mobilenet_conv2_block3_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block3_1_bn (Ba (None, 56, 56, 128)  512         mobilenet_conv2_block3_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block3_1_relu ( (None, 56, 56, 128)  0           mobilenet_conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv2_block3_2_conv ( (None, 56, 56, 32)   36864       mobilenet_conv2_block3_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block3_concat ( (None, 56, 56, 160)  0           mobilenet_conv2_block2_concat[0][
#                                                                  mobilenet_conv2_block3_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block4_0_bn (Ba (None, 56, 56, 160)  640         mobilenet_conv2_block3_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block4_0_relu ( (None, 56, 56, 160)  0           mobilenet_conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv2_block4_1_conv ( (None, 56, 56, 128)  20480       mobilenet_conv2_block4_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block4_1_bn (Ba (None, 56, 56, 128)  512         mobilenet_conv2_block4_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block4_1_relu ( (None, 56, 56, 128)  0           mobilenet_conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv2_block4_2_conv ( (None, 56, 56, 32)   36864       mobilenet_conv2_block4_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block4_concat ( (None, 56, 56, 192)  0           mobilenet_conv2_block3_concat[0][
#                                                                  mobilenet_conv2_block4_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block5_0_bn (Ba (None, 56, 56, 192)  768         mobilenet_conv2_block4_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block5_0_relu ( (None, 56, 56, 192)  0           mobilenet_conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv2_block5_1_conv ( (None, 56, 56, 128)  24576       mobilenet_conv2_block5_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block5_1_bn (Ba (None, 56, 56, 128)  512         mobilenet_conv2_block5_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block5_1_relu ( (None, 56, 56, 128)  0           mobilenet_conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv2_block5_2_conv ( (None, 56, 56, 32)   36864       mobilenet_conv2_block5_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block5_concat ( (None, 56, 56, 224)  0           mobilenet_conv2_block4_concat[0][
#                                                                  mobilenet_conv2_block5_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block6_0_bn (Ba (None, 56, 56, 224)  896         mobilenet_conv2_block5_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block6_0_relu ( (None, 56, 56, 224)  0           mobilenet_conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv2_block6_1_conv ( (None, 56, 56, 128)  28672       mobilenet_conv2_block6_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block6_1_bn (Ba (None, 56, 56, 128)  512         mobilenet_conv2_block6_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block6_1_relu ( (None, 56, 56, 128)  0           mobilenet_conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv2_block6_2_conv ( (None, 56, 56, 32)   36864       mobilenet_conv2_block6_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv2_block6_concat ( (None, 56, 56, 256)  0           mobilenet_conv2_block5_concat[0][
#                                                                  mobilenet_conv2_block6_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_pool2_bn (BatchNormal (None, 56, 56, 256)  1024        mobilenet_conv2_block6_concat[0][
# __________________________________________________________________________________________________
# mobilenet_pool2_relu (Activatio (None, 56, 56, 256)  0           mobilenet_pool2_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_pool2_conv (Conv2D)   (None, 56, 56, 128)  32768       mobilenet_pool2_relu[0][0]
# __________________________________________________________________________________________________
# mobilenet_pool2_pool (AveragePo (None, 28, 28, 128)  0           mobilenet_pool2_conv[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block1_0_bn (Ba (None, 28, 28, 128)  512         mobilenet_pool2_pool[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block1_0_relu ( (None, 28, 28, 128)  0           mobilenet_conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block1_1_conv ( (None, 28, 28, 128)  16384       mobilenet_conv3_block1_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block1_1_bn (Ba (None, 28, 28, 128)  512         mobilenet_conv3_block1_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block1_1_relu ( (None, 28, 28, 128)  0           mobilenet_conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block1_2_conv ( (None, 28, 28, 32)   36864       mobilenet_conv3_block1_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block1_concat ( (None, 28, 28, 160)  0           mobilenet_pool2_pool[0][0]
#                                                                  mobilenet_conv3_block1_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block2_0_bn (Ba (None, 28, 28, 160)  640         mobilenet_conv3_block1_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block2_0_relu ( (None, 28, 28, 160)  0           mobilenet_conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block2_1_conv ( (None, 28, 28, 128)  20480       mobilenet_conv3_block2_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block2_1_bn (Ba (None, 28, 28, 128)  512         mobilenet_conv3_block2_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block2_1_relu ( (None, 28, 28, 128)  0           mobilenet_conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block2_2_conv ( (None, 28, 28, 32)   36864       mobilenet_conv3_block2_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block2_concat ( (None, 28, 28, 192)  0           mobilenet_conv3_block1_concat[0][
#                                                                  mobilenet_conv3_block2_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block3_0_bn (Ba (None, 28, 28, 192)  768         mobilenet_conv3_block2_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block3_0_relu ( (None, 28, 28, 192)  0           mobilenet_conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block3_1_conv ( (None, 28, 28, 128)  24576       mobilenet_conv3_block3_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block3_1_bn (Ba (None, 28, 28, 128)  512         mobilenet_conv3_block3_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block3_1_relu ( (None, 28, 28, 128)  0           mobilenet_conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block3_2_conv ( (None, 28, 28, 32)   36864       mobilenet_conv3_block3_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block3_concat ( (None, 28, 28, 224)  0           mobilenet_conv3_block2_concat[0][
#                                                                  mobilenet_conv3_block3_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block4_0_bn (Ba (None, 28, 28, 224)  896         mobilenet_conv3_block3_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block4_0_relu ( (None, 28, 28, 224)  0           mobilenet_conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block4_1_conv ( (None, 28, 28, 128)  28672       mobilenet_conv3_block4_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block4_1_bn (Ba (None, 28, 28, 128)  512         mobilenet_conv3_block4_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block4_1_relu ( (None, 28, 28, 128)  0           mobilenet_conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block4_2_conv ( (None, 28, 28, 32)   36864       mobilenet_conv3_block4_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block4_concat ( (None, 28, 28, 256)  0           mobilenet_conv3_block3_concat[0][
#                                                                  mobilenet_conv3_block4_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block5_0_bn (Ba (None, 28, 28, 256)  1024        mobilenet_conv3_block4_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block5_0_relu ( (None, 28, 28, 256)  0           mobilenet_conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block5_1_conv ( (None, 28, 28, 128)  32768       mobilenet_conv3_block5_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block5_1_bn (Ba (None, 28, 28, 128)  512         mobilenet_conv3_block5_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block5_1_relu ( (None, 28, 28, 128)  0           mobilenet_conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block5_2_conv ( (None, 28, 28, 32)   36864       mobilenet_conv3_block5_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block5_concat ( (None, 28, 28, 288)  0           mobilenet_conv3_block4_concat[0][
#                                                                  mobilenet_conv3_block5_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block6_0_bn (Ba (None, 28, 28, 288)  1152        mobilenet_conv3_block5_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block6_0_relu ( (None, 28, 28, 288)  0           mobilenet_conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block6_1_conv ( (None, 28, 28, 128)  36864       mobilenet_conv3_block6_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block6_1_bn (Ba (None, 28, 28, 128)  512         mobilenet_conv3_block6_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block6_1_relu ( (None, 28, 28, 128)  0           mobilenet_conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block6_2_conv ( (None, 28, 28, 32)   36864       mobilenet_conv3_block6_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block6_concat ( (None, 28, 28, 320)  0           mobilenet_conv3_block5_concat[0][
#                                                                  mobilenet_conv3_block6_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block7_0_bn (Ba (None, 28, 28, 320)  1280        mobilenet_conv3_block6_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block7_0_relu ( (None, 28, 28, 320)  0           mobilenet_conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block7_1_conv ( (None, 28, 28, 128)  40960       mobilenet_conv3_block7_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block7_1_bn (Ba (None, 28, 28, 128)  512         mobilenet_conv3_block7_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block7_1_relu ( (None, 28, 28, 128)  0           mobilenet_conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block7_2_conv ( (None, 28, 28, 32)   36864       mobilenet_conv3_block7_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block7_concat ( (None, 28, 28, 352)  0           mobilenet_conv3_block6_concat[0][
#                                                                  mobilenet_conv3_block7_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block8_0_bn (Ba (None, 28, 28, 352)  1408        mobilenet_conv3_block7_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block8_0_relu ( (None, 28, 28, 352)  0           mobilenet_conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block8_1_conv ( (None, 28, 28, 128)  45056       mobilenet_conv3_block8_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block8_1_bn (Ba (None, 28, 28, 128)  512         mobilenet_conv3_block8_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block8_1_relu ( (None, 28, 28, 128)  0           mobilenet_conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block8_2_conv ( (None, 28, 28, 32)   36864       mobilenet_conv3_block8_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block8_concat ( (None, 28, 28, 384)  0           mobilenet_conv3_block7_concat[0][
#                                                                  mobilenet_conv3_block8_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block9_0_bn (Ba (None, 28, 28, 384)  1536        mobilenet_conv3_block8_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block9_0_relu ( (None, 28, 28, 384)  0           mobilenet_conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block9_1_conv ( (None, 28, 28, 128)  49152       mobilenet_conv3_block9_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block9_1_bn (Ba (None, 28, 28, 128)  512         mobilenet_conv3_block9_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block9_1_relu ( (None, 28, 28, 128)  0           mobilenet_conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block9_2_conv ( (None, 28, 28, 32)   36864       mobilenet_conv3_block9_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block9_concat ( (None, 28, 28, 416)  0           mobilenet_conv3_block8_concat[0][
#                                                                  mobilenet_conv3_block9_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block10_0_bn (B (None, 28, 28, 416)  1664        mobilenet_conv3_block9_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv3_block10_0_relu  (None, 28, 28, 416)  0           mobilenet_conv3_block10_0_bn[0][0
# __________________________________________________________________________________________________
# mobilenet_conv3_block10_1_conv  (None, 28, 28, 128)  53248       mobilenet_conv3_block10_0_relu[0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block10_1_bn (B (None, 28, 28, 128)  512         mobilenet_conv3_block10_1_conv[0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block10_1_relu  (None, 28, 28, 128)  0           mobilenet_conv3_block10_1_bn[0][0
# __________________________________________________________________________________________________
# mobilenet_conv3_block10_2_conv  (None, 28, 28, 32)   36864       mobilenet_conv3_block10_1_relu[0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block10_concat  (None, 28, 28, 448)  0           mobilenet_conv3_block9_concat[0][
#                                                                  mobilenet_conv3_block10_2_conv[0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block11_0_bn (B (None, 28, 28, 448)  1792        mobilenet_conv3_block10_concat[0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block11_0_relu  (None, 28, 28, 448)  0           mobilenet_conv3_block11_0_bn[0][0
# __________________________________________________________________________________________________
# mobilenet_conv3_block11_1_conv  (None, 28, 28, 128)  57344       mobilenet_conv3_block11_0_relu[0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block11_1_bn (B (None, 28, 28, 128)  512         mobilenet_conv3_block11_1_conv[0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block11_1_relu  (None, 28, 28, 128)  0           mobilenet_conv3_block11_1_bn[0][0
# __________________________________________________________________________________________________
# mobilenet_conv3_block11_2_conv  (None, 28, 28, 32)   36864       mobilenet_conv3_block11_1_relu[0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block11_concat  (None, 28, 28, 480)  0           mobilenet_conv3_block10_concat[0]
#                                                                  mobilenet_conv3_block11_2_conv[0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block12_0_bn (B (None, 28, 28, 480)  1920        mobilenet_conv3_block11_concat[0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block12_0_relu  (None, 28, 28, 480)  0           mobilenet_conv3_block12_0_bn[0][0
# __________________________________________________________________________________________________
# mobilenet_conv3_block12_1_conv  (None, 28, 28, 128)  61440       mobilenet_conv3_block12_0_relu[0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block12_1_bn (B (None, 28, 28, 128)  512         mobilenet_conv3_block12_1_conv[0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block12_1_relu  (None, 28, 28, 128)  0           mobilenet_conv3_block12_1_bn[0][0
# __________________________________________________________________________________________________
# mobilenet_conv3_block12_2_conv  (None, 28, 28, 32)   36864       mobilenet_conv3_block12_1_relu[0]
# __________________________________________________________________________________________________
# mobilenet_conv3_block12_concat  (None, 28, 28, 512)  0           mobilenet_conv3_block11_concat[0]
#                                                                  mobilenet_conv3_block12_2_conv[0]
# __________________________________________________________________________________________________
# mobilenet_pool3_bn (BatchNormal (None, 28, 28, 512)  2048        mobilenet_conv3_block12_concat[0]
# __________________________________________________________________________________________________
# mobilenet_pool3_relu (Activatio (None, 28, 28, 512)  0           mobilenet_pool3_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_pool3_conv (Conv2D)   (None, 28, 28, 256)  131072      mobilenet_pool3_relu[0][0]
# __________________________________________________________________________________________________
# mobilenet_pool3_pool (AveragePo (None, 14, 14, 256)  0           mobilenet_pool3_conv[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block1_0_bn (Ba (None, 14, 14, 256)  1024        mobilenet_pool3_pool[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block1_0_relu ( (None, 14, 14, 256)  0           mobilenet_conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block1_1_conv ( (None, 14, 14, 128)  32768       mobilenet_conv4_block1_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block1_1_bn (Ba (None, 14, 14, 128)  512         mobilenet_conv4_block1_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block1_1_relu ( (None, 14, 14, 128)  0           mobilenet_conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block1_2_conv ( (None, 14, 14, 32)   36864       mobilenet_conv4_block1_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block1_concat ( (None, 14, 14, 288)  0           mobilenet_pool3_pool[0][0]
#                                                                  mobilenet_conv4_block1_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block2_0_bn (Ba (None, 14, 14, 288)  1152        mobilenet_conv4_block1_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block2_0_relu ( (None, 14, 14, 288)  0           mobilenet_conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block2_1_conv ( (None, 14, 14, 128)  36864       mobilenet_conv4_block2_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block2_1_bn (Ba (None, 14, 14, 128)  512         mobilenet_conv4_block2_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block2_1_relu ( (None, 14, 14, 128)  0           mobilenet_conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block2_2_conv ( (None, 14, 14, 32)   36864       mobilenet_conv4_block2_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block2_concat ( (None, 14, 14, 320)  0           mobilenet_conv4_block1_concat[0][
#                                                                  mobilenet_conv4_block2_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block3_0_bn (Ba (None, 14, 14, 320)  1280        mobilenet_conv4_block2_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block3_0_relu ( (None, 14, 14, 320)  0           mobilenet_conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block3_1_conv ( (None, 14, 14, 128)  40960       mobilenet_conv4_block3_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block3_1_bn (Ba (None, 14, 14, 128)  512         mobilenet_conv4_block3_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block3_1_relu ( (None, 14, 14, 128)  0           mobilenet_conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block3_2_conv ( (None, 14, 14, 32)   36864       mobilenet_conv4_block3_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block3_concat ( (None, 14, 14, 352)  0           mobilenet_conv4_block2_concat[0][
#                                                                  mobilenet_conv4_block3_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block4_0_bn (Ba (None, 14, 14, 352)  1408        mobilenet_conv4_block3_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block4_0_relu ( (None, 14, 14, 352)  0           mobilenet_conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block4_1_conv ( (None, 14, 14, 128)  45056       mobilenet_conv4_block4_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block4_1_bn (Ba (None, 14, 14, 128)  512         mobilenet_conv4_block4_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block4_1_relu ( (None, 14, 14, 128)  0           mobilenet_conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block4_2_conv ( (None, 14, 14, 32)   36864       mobilenet_conv4_block4_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block4_concat ( (None, 14, 14, 384)  0           mobilenet_conv4_block3_concat[0][
#                                                                  mobilenet_conv4_block4_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block5_0_bn (Ba (None, 14, 14, 384)  1536        mobilenet_conv4_block4_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block5_0_relu ( (None, 14, 14, 384)  0           mobilenet_conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block5_1_conv ( (None, 14, 14, 128)  49152       mobilenet_conv4_block5_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block5_1_bn (Ba (None, 14, 14, 128)  512         mobilenet_conv4_block5_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block5_1_relu ( (None, 14, 14, 128)  0           mobilenet_conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block5_2_conv ( (None, 14, 14, 32)   36864       mobilenet_conv4_block5_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block5_concat ( (None, 14, 14, 416)  0           mobilenet_conv4_block4_concat[0][
#                                                                  mobilenet_conv4_block5_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block6_0_bn (Ba (None, 14, 14, 416)  1664        mobilenet_conv4_block5_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block6_0_relu ( (None, 14, 14, 416)  0           mobilenet_conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block6_1_conv ( (None, 14, 14, 128)  53248       mobilenet_conv4_block6_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block6_1_bn (Ba (None, 14, 14, 128)  512         mobilenet_conv4_block6_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block6_1_relu ( (None, 14, 14, 128)  0           mobilenet_conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block6_2_conv ( (None, 14, 14, 32)   36864       mobilenet_conv4_block6_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block6_concat ( (None, 14, 14, 448)  0           mobilenet_conv4_block5_concat[0][
#                                                                  mobilenet_conv4_block6_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block7_0_bn (Ba (None, 14, 14, 448)  1792        mobilenet_conv4_block6_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block7_0_relu ( (None, 14, 14, 448)  0           mobilenet_conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block7_1_conv ( (None, 14, 14, 128)  57344       mobilenet_conv4_block7_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block7_1_bn (Ba (None, 14, 14, 128)  512         mobilenet_conv4_block7_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block7_1_relu ( (None, 14, 14, 128)  0           mobilenet_conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block7_2_conv ( (None, 14, 14, 32)   36864       mobilenet_conv4_block7_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block7_concat ( (None, 14, 14, 480)  0           mobilenet_conv4_block6_concat[0][
#                                                                  mobilenet_conv4_block7_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block8_0_bn (Ba (None, 14, 14, 480)  1920        mobilenet_conv4_block7_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block8_0_relu ( (None, 14, 14, 480)  0           mobilenet_conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block8_1_conv ( (None, 14, 14, 128)  61440       mobilenet_conv4_block8_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block8_1_bn (Ba (None, 14, 14, 128)  512         mobilenet_conv4_block8_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block8_1_relu ( (None, 14, 14, 128)  0           mobilenet_conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block8_2_conv ( (None, 14, 14, 32)   36864       mobilenet_conv4_block8_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block8_concat ( (None, 14, 14, 512)  0           mobilenet_conv4_block7_concat[0][
#                                                                  mobilenet_conv4_block8_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block9_0_bn (Ba (None, 14, 14, 512)  2048        mobilenet_conv4_block8_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block9_0_relu ( (None, 14, 14, 512)  0           mobilenet_conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block9_1_conv ( (None, 14, 14, 128)  65536       mobilenet_conv4_block9_0_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block9_1_bn (Ba (None, 14, 14, 128)  512         mobilenet_conv4_block9_1_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block9_1_relu ( (None, 14, 14, 128)  0           mobilenet_conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block9_2_conv ( (None, 14, 14, 32)   36864       mobilenet_conv4_block9_1_relu[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block9_concat ( (None, 14, 14, 544)  0           mobilenet_conv4_block8_concat[0][
#                                                                  mobilenet_conv4_block9_2_conv[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block10_0_bn (B (None, 14, 14, 544)  2176        mobilenet_conv4_block9_concat[0][
# __________________________________________________________________________________________________
# mobilenet_conv4_block10_0_relu  (None, 14, 14, 544)  0           mobilenet_conv4_block10_0_bn[0][0
# __________________________________________________________________________________________________
# mobilenet_conv4_block10_1_conv  (None, 14, 14, 128)  69632       mobilenet_conv4_block10_0_relu[0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block10_1_bn (B (None, 14, 14, 128)  512         mobilenet_conv4_block10_1_conv[0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block10_1_relu  (None, 14, 14, 128)  0           mobilenet_conv4_block10_1_bn[0][0
# __________________________________________________________________________________________________
# mobilenet_conv4_block10_2_conv  (None, 14, 14, 32)   36864       mobilenet_conv4_block10_1_relu[0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block10_concat  (None, 14, 14, 576)  0           mobilenet_conv4_block9_concat[0][
#                                                                  mobilenet_conv4_block10_2_conv[0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block11_0_bn (B (None, 14, 14, 576)  2304        mobilenet_conv4_block10_concat[0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block11_0_relu  (None, 14, 14, 576)  0           mobilenet_conv4_block11_0_bn[0][0
# __________________________________________________________________________________________________
# mobilenet_conv4_block11_1_conv  (None, 14, 14, 128)  73728       mobilenet_conv4_block11_0_relu[0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block11_1_bn (B (None, 14, 14, 128)  512         mobilenet_conv4_block11_1_conv[0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block11_1_relu  (None, 14, 14, 128)  0           mobilenet_conv4_block11_1_bn[0][0
# __________________________________________________________________________________________________
# mobilenet_conv4_block11_2_conv  (None, 14, 14, 32)   36864       mobilenet_conv4_block11_1_relu[0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block11_concat  (None, 14, 14, 608)  0           mobilenet_conv4_block10_concat[0]
#                                                                  mobilenet_conv4_block11_2_conv[0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block12_0_bn (B (None, 14, 14, 608)  2432        mobilenet_conv4_block11_concat[0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block12_0_relu  (None, 14, 14, 608)  0           mobilenet_conv4_block12_0_bn[0][0
# __________________________________________________________________________________________________
# mobilenet_conv4_block12_1_conv  (None, 14, 14, 128)  77824       mobilenet_conv4_block12_0_relu[0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block12_1_bn (B (None, 14, 14, 128)  512         mobilenet_conv4_block12_1_conv[0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block12_1_relu  (None, 14, 14, 128)  0           mobilenet_conv4_block12_1_bn[0][0
# __________________________________________________________________________________________________
# mobilenet_conv4_block12_2_conv  (None, 14, 14, 32)   36864       mobilenet_conv4_block12_1_relu[0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block12_concat  (None, 14, 14, 640)  0           mobilenet_conv4_block11_concat[0]
#                                                                  mobilenet_conv4_block12_2_conv[0]
# __________________________________________________________________________________________________
# mobilenet_conv4_block13_0_bn (B (None, 14, 14, 640)  2560        mobilenet_conv4_block12_concat[0]
# ...
# mobilenet_conv5_block29_1_relu  (None, 7, 7, 128)    0           mobilenet_conv5_block29_1_bn[0][0
# __________________________________________________________________________________________________
# resnet50_activation_91 (Activat (None, 7, 7, 512)    0           resnet50_bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block29_2_conv  (None, 7, 7, 32)     36864       mobilenet_conv5_block29_1_relu[0]
# __________________________________________________________________________________________________
# resnet50_res5a_branch2c (Conv2D (None, 7, 7, 2048)   1050624     resnet50_activation_91[0][0]
# __________________________________________________________________________________________________
# resnet50_res5a_branch1 (Conv2D) (None, 7, 7, 2048)   2099200     resnet50_activation_89[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block29_concat  (None, 7, 7, 1824)   0           mobilenet_conv5_block28_concat[0]
#                                                                  mobilenet_conv5_block29_2_conv[0]
# __________________________________________________________________________________________________
# resnet50_bn5a_branch2c (BatchNo (None, 7, 7, 2048)   8192        resnet50_res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# resnet50_bn5a_branch1 (BatchNor (None, 7, 7, 2048)   8192        resnet50_res5a_branch1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block30_0_bn (B (None, 7, 7, 1824)   7296        mobilenet_conv5_block29_concat[0]
# __________________________________________________________________________________________________
# resnet50_add_30 (Add)           (None, 7, 7, 2048)   0           resnet50_bn5a_branch2c[0][0]
#                                                                  resnet50_bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block30_0_relu  (None, 7, 7, 1824)   0           mobilenet_conv5_block30_0_bn[0][0
# __________________________________________________________________________________________________
# resnet50_activation_92 (Activat (None, 7, 7, 2048)   0           resnet50_add_30[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block30_1_conv  (None, 7, 7, 128)    233472      mobilenet_conv5_block30_0_relu[0]
# __________________________________________________________________________________________________
# resnet50_res5b_branch2a (Conv2D (None, 7, 7, 512)    1049088     resnet50_activation_92[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block30_1_bn (B (None, 7, 7, 128)    512         mobilenet_conv5_block30_1_conv[0]
# __________________________________________________________________________________________________
# resnet50_bn5b_branch2a (BatchNo (None, 7, 7, 512)    2048        resnet50_res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block30_1_relu  (None, 7, 7, 128)    0           mobilenet_conv5_block30_1_bn[0][0
# __________________________________________________________________________________________________
# resnet50_activation_93 (Activat (None, 7, 7, 512)    0           resnet50_bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# vgg16_block1_conv1 (Conv2D)     (None, 224, 224, 64) 1792        mobilenet_vgg16_resnet50_input_2[
# __________________________________________________________________________________________________
# mobilenet_conv5_block30_2_conv  (None, 7, 7, 32)     36864       mobilenet_conv5_block30_1_relu[0]
# __________________________________________________________________________________________________
# resnet50_res5b_branch2b (Conv2D (None, 7, 7, 512)    2359808     resnet50_activation_93[0][0]
# __________________________________________________________________________________________________
# vgg16_block1_conv2 (Conv2D)     (None, 224, 224, 64) 36928       vgg16_block1_conv1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block30_concat  (None, 7, 7, 1856)   0           mobilenet_conv5_block29_concat[0]
#                                                                  mobilenet_conv5_block30_2_conv[0]
# __________________________________________________________________________________________________
# resnet50_bn5b_branch2b (BatchNo (None, 7, 7, 512)    2048        resnet50_res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# vgg16_block1_pool (MaxPooling2D (None, 112, 112, 64) 0           vgg16_block1_conv2[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block31_0_bn (B (None, 7, 7, 1856)   7424        mobilenet_conv5_block30_concat[0]
# __________________________________________________________________________________________________
# resnet50_activation_94 (Activat (None, 7, 7, 512)    0           resnet50_bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# vgg16_block2_conv1 (Conv2D)     (None, 112, 112, 128 73856       vgg16_block1_pool[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block31_0_relu  (None, 7, 7, 1856)   0           mobilenet_conv5_block31_0_bn[0][0
# __________________________________________________________________________________________________
# resnet50_res5b_branch2c (Conv2D (None, 7, 7, 2048)   1050624     resnet50_activation_94[0][0]
# __________________________________________________________________________________________________
# vgg16_block2_conv2 (Conv2D)     (None, 112, 112, 128 147584      vgg16_block2_conv1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block31_1_conv  (None, 7, 7, 128)    237568      mobilenet_conv5_block31_0_relu[0]
# __________________________________________________________________________________________________
# resnet50_bn5b_branch2c (BatchNo (None, 7, 7, 2048)   8192        resnet50_res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# vgg16_block2_pool (MaxPooling2D (None, 56, 56, 128)  0           vgg16_block2_conv2[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block31_1_bn (B (None, 7, 7, 128)    512         mobilenet_conv5_block31_1_conv[0]
# __________________________________________________________________________________________________
# resnet50_add_31 (Add)           (None, 7, 7, 2048)   0           resnet50_bn5b_branch2c[0][0]
#                                                                  resnet50_activation_92[0][0]
# __________________________________________________________________________________________________
# vgg16_block3_conv1 (Conv2D)     (None, 56, 56, 256)  295168      vgg16_block2_pool[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block31_1_relu  (None, 7, 7, 128)    0           mobilenet_conv5_block31_1_bn[0][0
# __________________________________________________________________________________________________
# resnet50_activation_95 (Activat (None, 7, 7, 2048)   0           resnet50_add_31[0][0]
# __________________________________________________________________________________________________
# vgg16_block3_conv2 (Conv2D)     (None, 56, 56, 256)  590080      vgg16_block3_conv1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block31_2_conv  (None, 7, 7, 32)     36864       mobilenet_conv5_block31_1_relu[0]
# __________________________________________________________________________________________________
# resnet50_res5c_branch2a (Conv2D (None, 7, 7, 512)    1049088     resnet50_activation_95[0][0]
# __________________________________________________________________________________________________
# vgg16_block3_conv3 (Conv2D)     (None, 56, 56, 256)  590080      vgg16_block3_conv2[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block31_concat  (None, 7, 7, 1888)   0           mobilenet_conv5_block30_concat[0]
#                                                                  mobilenet_conv5_block31_2_conv[0]
# __________________________________________________________________________________________________
# resnet50_bn5c_branch2a (BatchNo (None, 7, 7, 512)    2048        resnet50_res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# vgg16_block3_pool (MaxPooling2D (None, 28, 28, 256)  0           vgg16_block3_conv3[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block32_0_bn (B (None, 7, 7, 1888)   7552        mobilenet_conv5_block31_concat[0]
# __________________________________________________________________________________________________
# resnet50_activation_96 (Activat (None, 7, 7, 512)    0           resnet50_bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_conv1 (Conv2D)     (None, 28, 28, 512)  1180160     vgg16_block3_pool[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block32_0_relu  (None, 7, 7, 1888)   0           mobilenet_conv5_block32_0_bn[0][0
# __________________________________________________________________________________________________
# resnet50_res5c_branch2b (Conv2D (None, 7, 7, 512)    2359808     resnet50_activation_96[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_conv2 (Conv2D)     (None, 28, 28, 512)  2359808     vgg16_block4_conv1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block32_1_conv  (None, 7, 7, 128)    241664      mobilenet_conv5_block32_0_relu[0]
# __________________________________________________________________________________________________
# resnet50_bn5c_branch2b (BatchNo (None, 7, 7, 512)    2048        resnet50_res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_conv3 (Conv2D)     (None, 28, 28, 512)  2359808     vgg16_block4_conv2[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block32_1_bn (B (None, 7, 7, 128)    512         mobilenet_conv5_block32_1_conv[0]
# __________________________________________________________________________________________________
# resnet50_activation_97 (Activat (None, 7, 7, 512)    0           resnet50_bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_pool (MaxPooling2D (None, 14, 14, 512)  0           vgg16_block4_conv3[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block32_1_relu  (None, 7, 7, 128)    0           mobilenet_conv5_block32_1_bn[0][0
# __________________________________________________________________________________________________
# resnet50_res5c_branch2c (Conv2D (None, 7, 7, 2048)   1050624     resnet50_activation_97[0][0]
# __________________________________________________________________________________________________
# vgg16_block5_conv1 (Conv2D)     (None, 14, 14, 512)  2359808     vgg16_block4_pool[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block32_2_conv  (None, 7, 7, 32)     36864       mobilenet_conv5_block32_1_relu[0]
# __________________________________________________________________________________________________
# resnet50_bn5c_branch2c (BatchNo (None, 7, 7, 2048)   8192        resnet50_res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# vgg16_block5_conv2 (Conv2D)     (None, 14, 14, 512)  2359808     vgg16_block5_conv1[0][0]
# __________________________________________________________________________________________________
# mobilenet_conv5_block32_concat  (None, 7, 7, 1920)   0           mobilenet_conv5_block31_concat[0]
#                                                                  mobilenet_conv5_block32_2_conv[0]
# __________________________________________________________________________________________________
# resnet50_add_32 (Add)           (None, 7, 7, 2048)   0           resnet50_bn5c_branch2c[0][0]
#                                                                  resnet50_activation_95[0][0]
# __________________________________________________________________________________________________
# vgg16_block5_conv3 (Conv2D)     (None, 14, 14, 512)  2359808     vgg16_block5_conv2[0][0]
# __________________________________________________________________________________________________
# mobilenet_bn (BatchNormalizatio (None, 7, 7, 1920)   7680        mobilenet_conv5_block32_concat[0]
# __________________________________________________________________________________________________
# resnet50_activation_98 (Activat (None, 7, 7, 2048)   0           resnet50_add_32[0][0]
# __________________________________________________________________________________________________
# vgg16_block5_pool (MaxPooling2D (None, 7, 7, 512)    0           vgg16_block5_conv3[0][0]
# __________________________________________________________________________________________________
# mobilenet_relu (Activation)     (None, 7, 7, 1920)   0           mobilenet_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 2048)         0           resnet50_activation_98[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 512)          0           vgg16_block5_pool[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 1920)         0           mobilenet_relu[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4480)         0           global_average_pooling2d_3[0][0]
#                                                                  global_average_pooling2d_4[0][0]
#                                                                  global_average_pooling2d_5[0][0]
# ==================================================================================================
# Total params: 56,624,384
# Trainable params: 282,176
# Non-trainable params: 56,342,208
# __________________________________________________________________________________________________

# %%
len(train_gen.x) // 60
# Out:
# 18

# %%
# # model.fit_generator(image_gen.flow(x_train, y_train.toarray(), batch_size=batch_size),
# #           steps_per_epoch=  x_train.shape[0]//batch_size,
# #           epochs=epochs,
# #           verbose=1,
# #           class_weight=class_weight_dic)

# hist = model.fit_generator(train_gen,
#                     steps_per_epoch=len(train_gen.x)//BATCH_SIZE,
#                     epochs=EPOCHS,
#                     validation_data=(X_val, y_val),
#                     validation_steps=X_val.shape[0]//BATCH_SIZE)

# %%
# hist = model.fit(X_train, 
#                  y_train, 
#                  batch_size=BATCH_SIZE, 
#                  epochs=3, 
#                  verbose=1, 
#                  callbacks=None, 
#                  validation_data=(X_val, y_val))

# %%
features, labels = model.predict(X_train), y_train

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(learning_rate=0.02, 
                    n_estimators=600, 
                    objective='multi:softmax', 
                    silent=True, 
                    nthread=1)

# %%
y_labels = np.argmax(labels,axis = 1)

# %%
# from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
# from sklearn.metrics import roc_auc_score
# from sklearn.model_selection import StratifiedKFold


# y_labels = np.argmax(labels,axis = 1) 

# folds = 4
# param_comb = 5

# start = time.time()

# # A parameter grid for XGBoost
# params = {
#         'min_child_weight': [1, 5, 10],
#         'gamma': [0.5, 1, 1.5, 2, 5],
#         'subsample': [0.6, 0.8, 1.0],
#         'colsample_bytree': [0.6, 0.8, 1.0],
#         'max_depth': [3, 4, 5]
#         }

# xgb = XGBClassifier(learning_rate=0.02, 
#                     n_estimators=600, 
#                     objective='multi:softmax', 
#                     silent=True, 
#                     nthread=1)

# skf = StratifiedKFold(n_splits=folds, shuffle = True, random_state = 2020)

# random_search = RandomizedSearchCV(xgb, 
#                                    param_distributions=params, 
#                                    n_iter=param_comb, 
#                                   #  scoring='roc_auc', 
#                                    n_jobs=4, 
#                                    cv=skf.split(features,y_labels), 
#                                    verbose=3, 
#                                    random_state=2020)

# random_search.fit(features, y_labels)

# end = time.time()
# print('Time taken in grid search: {0: .2f}'.format(end - start))

# %%
# best_score = random_search.best_score_
# best_params = random_search.best_params_
# print('Best Score using random search: \n', best_score)
# print('Best Parameters using random search: \n', best_params)

# %%
# # # Set best parameters given by random search 
# # xgb = XGBClassifier(learning_rate=0.02, 
# #                     n_estimators=600, 
# #                     objective='multi:softmax', 
# #                     silent=True, 
# #                     nthread=1)
xgb.set_params(subsample=0.6, 
               min_child_weight=5, 
               max_depth=4, 
               gamma=1, 
              #  max_features=None,
               colsample_bytree=0.8)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=1,
#               learning_rate=0.02, max_delta_step=0, max_depth=4,
#               min_child_weight=5, missing=None, n_estimators=600, n_jobs=1,
#               nthread=1, objective='multi:softmax', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#               subsample=0.6, verbosity=1)

# %%
test_features, test_labels = model.predict(X_test), y_test

# %%
xgb.fit(features, y_labels)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=1,
#               learning_rate=0.02, max_delta_step=0, max_depth=4,
#               min_child_weight=5, missing=None, n_estimators=600, n_jobs=1,
#               nthread=1, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=True, subsample=0.6, verbosity=1)

# %%
predictions_xgb = xgb.predict(test_features)

# %%
y_test_labels = np.argmax(test_labels, axis = 1) 
accuracy_xgb = xgb.score(test_features, y_test_labels)

# %%
print("accuracy : ", accuracy_xgb)
# Out:
# accuracy :  0.9400445614745797

# %%
# model.evaluate(X_test, y_test)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

# Plot training & validation accuracy values
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy') 
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Confusion matrix
# Credit: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.round(cm, 2)
    thresh = np.max(cm) // 2 
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Y_pred = model.predict(X_test)
# Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Y_true = np.argmax(y_test,axis = 1) 
# confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)

# %%
# plot_confusion_matrix(confusion_mtx, classes = CLASSES)

# %%
Y_pred = predictions_xgb
# Y_pred_classes = np.argmax(Y_pred,axis = 1) 
Y_pred_classes = Y_pred
# Y_true = np.argmax(test_labels,axis = 1) 
Y_true = y_test_labels
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)

# %%
plot_confusion_matrix(confusion_mtx, classes = CLASSES)

# %%
# from sklearn.metrics import confusion_matrix
# import seaborn as sns

# # plot_confusion_matrix(confusion_mtx, classes = CLASSES, normalize=True)
# conf_mat = confusion_matrix(Y_true, Y_pred_classes)
# # Normalise
# conf_mat_norm = conf_mat.astype('float') / conf_mat.sum(axis=1)[:, np.newaxis]
# fig, ax = plt.subplots(figsize=(10,10))
# sns.heatmap(conf_mat_norm, annot=True, cmap=plt.cm.Blues, fmt='.2f', xticklabels=CLASSES, yticklabels=CLASSES)
# plt.ylabel('Actual')
# plt.xlabel('Predicted')
# plt.show(block=False)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# plot_confusion_matrix(confusion_mtx, classes = CLASSES, normalize=True)
conf_mat = confusion_matrix(Y_true, Y_pred_classes)
# Normalise
conf_mat_norm = conf_mat.astype('float') / conf_mat.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat_norm, annot=True, cmap=plt.cm.Blues, fmt='.2f', xticklabels=CLASSES, yticklabels=CLASSES)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show(block=False)

# %%
model.save_weights('Covid19_Detection_pretrained_VGG_Resnet_XGB.h5')

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True, to_file='Covid19_Detection_pretrained_VGG_Resnet_XGB.png')

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(random_state=2020)

# %%
# from sklearn.model_selection import GridSearchCV

# np.random.seed(2020)
# start = time.time()

# param_dist = {'max_depth': [2, 3, 4],
#               'bootstrap': [True, False],
#               'max_features': ['auto', 'sqrt', 'log2', None],
#               'criterion': ['gini', 'entropy']}

# cv_rf = GridSearchCV(rf_clf, cv = 2,
#                      param_grid=param_dist, 
#                      n_jobs = 3)

# cv_rf.fit(features, labels)
# print('Best Parameters using grid search: \n', cv_rf.best_params_)
# end = time.time()
# print('Time taken in grid search: {0: .2f}'.format(end - start))

# %%
# Set best parameters given by grid search 
rf_clf.set_params(bootstrap=True, criterion='entropy', max_depth=4, max_features=None)

# %%
rf_clf.fit(features, labels)

# %%
test_features, test_labels = model.predict(X_test), y_test

# %%
predictions_rf = rf_clf.predict(test_features)

# %%
accuracy_rf = rf_clf.score(test_features, test_labels)

# %%
print("accuracy : ", accuracy_rf)
