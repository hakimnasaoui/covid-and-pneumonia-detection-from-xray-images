# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/ieee8023/covid-chestxray-dataset.git
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 3237, done.
# remote: Total 3237 (delta 0), reused 0 (delta 0), pack-reused 3237
# Receiving objects: 100% (3237/3237), 582.59 MiB | 47.54 MiB/s, done.
# Resolving deltas: 100% (1292/1292), done.
# Checking out files: 100% (987/987), done.

# %%
# !mkdir -p /content/dataset/covid/
# !mkdir -p /content/dataset/normal/
# !mkdir -p /content/dataset/pneumonia/

# %%
# !unzip "/content/drive/My Drive/Datasets/Chest X-Ray Images (Pneumonia).zip"

# %%
# !mv /content/chest_xray/train/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/train/PNEUMONIA/* /content/dataset/pneumonia/
# !mv /content/chest_xray/val/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/val/PNEUMONIA/* /content/dataset/pneumonia/
# !mv /content/chest_xray/test/NORMAL/* /content/dataset/normal/
# !mv /content/chest_xray/test/PNEUMONIA/* /content/dataset/pneumonia/

# %%
import pandas as pd
import shutil
import os

# Selecting all combination of 'COVID-19' patients with 'PA' X-Ray view
virus = "COVID-19" # Virus to look for
x_ray_view = "PA" # View of X-Ray

meta_data = "/content/covid-chestxray-dataset/metadata.csv"
images_dir = "/content/covid-chestxray-dataset/images"
output_dir = "/content/dataset/covid/"

metadata_csv = pd.read_csv(meta_data)

for (i, row) in metadata_csv.iterrows():
	if row["finding"] != virus or row["view"] != x_ray_view:
		continue

	filename = row["filename"].split(os.path.sep)[-1]
	filePath = os.path.sep.join([images_dir, filename])
	shutil.copy2(filePath, output_dir)

# %%
# !git clone https://github.com/UCSD-AI4H/COVID-CT.git

# %%
# !unzip /content/COVID-CT/Images-processed/CT_COVID.zip
# !unzip /content/COVID-CT/Images-processed/CT_NonCOVID.zip

# %%
# !mv /content/CT_COVID/* /content/dataset/covid/

# %%
# !unzip "/content/drive/My Drive/Datasets/COVID19/COV-Img.zip"

# %%
# !mkdir -p /content/test/covid/

# %%
# !mv /content/COV-Img/* /content/test/covid/

# %% [markdown]
#   ## Dependencies

# %%
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Input, average, Average, concatenate
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense

from keras.models import Sequential, Model
from keras.applications.xception import Xception
from keras.applications.resnet50 import ResNet50
from keras.applications import ResNet101
from keras.applications import DenseNet201
from keras.applications import MobileNet
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.optimizers import Adam, SGD, RMSprop

import tensorflow as tf

import os
import numpy as np
import pandas as pd
import time

import random

from PIL import Image
import glob
import matplotlib.pyplot as plt
from matplotlib import pyplot
import matplotlib.image as mpimg
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
DATASET_DIR = "/content/dataset"

NORMAL_DIR = DATASET_DIR + "/normal"
PNEUMONIA_DIR = DATASET_DIR + "/pneumonia"
COVID_DIR = DATASET_DIR + "/covid"

NORMAL_TRAIN_SAMPLES = 1200 # total samples = 1583
PNEUMONIA_TRAIN_SAMPLES = 2000 # total samples = 4273
COVID_TRAIN_SAMPLES = 160 # total samples = 201

IMG_W = 224
IMG_H = 224
IMG_C = 1
INPUT_SHAPE = (IMG_W, IMG_H, IMG_C)

CLASSES = [ "NORMAL", "PNEUMONIA", "COVID" ]
NB_CLASSES = len(CLASSES)

EPOCHS = 2
BATCH_SIZE = 16

# %%
normal_images = []
pneumonia_images = []
covid_images = []

# %%
for img_path in glob.glob(NORMAL_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    # img = img / 255.
    normal_images.append(img[:np.newaxis])

for img_path in glob.glob(PNEUMONIA_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    # img = img / 255.
    pneumonia_images.append(img[:np.newaxis])

for img_path in glob.glob(COVID_DIR + '/*'):
    img = Image.open(img_path).convert('L')
    img = img.resize((IMG_H,IMG_H))
    img = np.asarray(img)
    # img = img / 255.
    covid_images.append(img[:np.newaxis])

# %%
len(normal_images), len(pneumonia_images), len(covid_images)
# Out:
# (1583, 4273, 204)

# %%
width=150
height=150
rows = 1
cols = 3

imgs = [ normal_images[0], pneumonia_images[0], covid_images[0]]

axes=[]
fig=plt.figure()

for i in range(rows*cols):
    img = imgs[i]
    axes.append( fig.add_subplot(rows, cols, i+1) )
    plt.imshow(img)

axes[0].set_title('NORMAL')
axes[1].set_title('PNEUMONIA')
axes[2].set_title('COVID')
fig.tight_layout()    
plt.show()

# %%
normal_X = []
pneumonia_X = []
covid_X = []
normal_y = []
pneumonia_y = []
covid_y = []
X = []
y = []

for item in normal_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    normal_X.append(img)    
    normal_y.append(CLASSES.index("NORMAL"))   
    X.append(img)    
    y.append(CLASSES.index("NORMAL"))

for item in pneumonia_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    pneumonia_X.append(img)    
    pneumonia_y.append(CLASSES.index("PNEUMONIA"))   
    X.append(img)    
    y.append(CLASSES.index("PNEUMONIA"))

for item in covid_images:
    img = np.asarray(item)
    img = img.reshape(INPUT_SHAPE)
    covid_X.append(img) 
    covid_y.append(CLASSES.index("COVID"))   
    X.append(img)    
    y.append(CLASSES.index("COVID"))

X = np.asarray(X)
y = np.asarray(y)

# %%
X.shape, y.shape
# Out:
# ((6060, 224, 224, 1), (6060,))

# %%
X_train_normal = normal_X[:NORMAL_TRAIN_SAMPLES]
X_train_pneumonia = pneumonia_X[:PNEUMONIA_TRAIN_SAMPLES]
X_train_covid = covid_X[:COVID_TRAIN_SAMPLES]
X_test_normal = normal_X[NORMAL_TRAIN_SAMPLES:]
X_test_pneumonia = pneumonia_X[PNEUMONIA_TRAIN_SAMPLES:]
X_test_covid = covid_X[COVID_TRAIN_SAMPLES:]

y_train_normal = normal_y[:NORMAL_TRAIN_SAMPLES]
y_train_pneumonia = pneumonia_y[:PNEUMONIA_TRAIN_SAMPLES]
y_train_covid = covid_y[:COVID_TRAIN_SAMPLES]
y_test_normal = normal_y[NORMAL_TRAIN_SAMPLES:]
y_test_pneumonia = pneumonia_y[PNEUMONIA_TRAIN_SAMPLES:]
y_test_covid = covid_y[COVID_TRAIN_SAMPLES:]


X_train = np.concatenate((X_train_normal, X_train_pneumonia, X_train_covid), axis=0) 
y_train = np.concatenate((y_train_normal, y_train_pneumonia, y_train_covid), axis=0) 

X_test = np.concatenate((X_test_normal, X_test_pneumonia, X_test_covid), axis=0) 
y_test = np.concatenate((y_test_normal, y_test_pneumonia, y_test_covid), axis=0)

# %%
# np.full((len(X_train_normal), 1), y_test_normal[0]).shape

# %%
X_train.shape, y_train.shape
# Out:
# ((3360, 224, 224, 1), (3360,))

# %%
X_test.shape, y_test.shape
# Out:
# ((2700, 224, 224, 1), (2700,))

# %%
a = list(zip(X_train, y_train))
random.shuffle(a)
X_train, y_train = zip(*a)
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
# a = list(zip(X_train, y_train))
# random.shuffle(a)
# X_test, y_test = zip(*a)

# %%
X_train.shape, y_train.shape
# Out:
# ((3360, 224, 224, 1), (3360,))

# %%
# ----------------------

# %%
from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.2, random_state=2020)


# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2
X_val = X_test
y_val = y_test

# %%
X_train = np.repeat(X_train[...,], 3, 3)
X_val = np.repeat(X_val[...,], 3, 3)
X_test = np.repeat(X_test[...,], 3, 3)

# %%
X_train.shape, y_train.shape
# Out:
# ((3360, 224, 224, 3), (3360,))

# %%
X_test.shape, y_test.shape
# Out:
# ((2700, 224, 224, 3), (2700,))

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1, 2]), array([1200, 2000,  160]))

# %%
np.unique(y_test, return_counts=True)
# Out:
# (array([0, 1, 2]), array([ 383, 2273,   44]))

# %%
from keras.utils import to_categorical

y_train = to_categorical(y_train)
y_val = to_categorical(y_val)
y_test = to_categorical(y_test)

# %%
train_da_args = dict(rescale=1./255, 
               shear_range=0.2,
               zoom_range=0.05,
               width_shift_range=0.05,
               height_shift_range=0.05,
               rotation_range=360,
               #  brightness_range=[0.2,1.0],
               vertical_flip=True,
               horizontal_flip=True)

# val_da_args = dict(rescale=1./255)

train_da = ImageDataGenerator(train_da_args)
# val_da = ImageDataGenerator(val_da_args)

train_da.fit(X_train, augment=True)
# val_da.fit(X_train)

train_gen = train_da.flow(X_train, y_train, batch_size=BATCH_SIZE)
# val_gen = train_da.flow(X_val, y_val)

# %%
for i in range(9):
	pyplot.subplot(330 + 1 + i)
	batch = train_gen.next()
	image = batch[0][0].astype('uint8')
	pyplot.imshow(image)

pyplot.show()

# %%
for i in range(9):
	
	pyplot.subplot(330 + 1 + i)
	batch = train_gen.next()
	image = batch[0][-1].astype('uint8')
	pyplot.imshow(image)

pyplot.show()

# %%
# augmented_data = []
# num_augmented = 0
# for X_batch, y_batch in train_da.flow(X_train, y_train, batch_size=BATCH_SIZE, shuffle=False):
#     augmented_data.append(X_batch)
#     num_augmented += BATCH_SIZE
#     if num_augmented == X_train.shape[0]:
#         break
# augmented_data = np.concatenate(augmented_data)

# %%
# -------------------------

# %%
# len(train_gen.x)

# %%
# vgg_model = VGG16(weights='imagenet', 
#                         include_top=False, 
#                         input_shape=(IMG_H, IMG_W, 3))

# for layer in vgg_model.layers:
#     if isinstance(layer, BatchNormalization):
#         layer.trainable = True
#     else:
#         layer.trainable = False

# model = Sequential()
# model.add(vgg_model)
# model.add(GlobalAveragePooling2D())
# model.add(Dense(256, activation='relu'))
# model.add(Dropout(0.5))
# model.add(BatchNormalization())
# model.add(Dense(NB_CLASSES, activation='softmax'))

# %%
models_input = Input(shape=(IMG_H, IMG_W, 3))


vgg_model = VGG16(weights='imagenet', 
                        include_top=False, 
                        input_tensor=models_input)

for layer in vgg_model.layers:
    layer.name = "vgg16_" + layer.name
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False
        
        
vgg_gap = GlobalAveragePooling2D()(vgg_model.output)

# x = Dense(256)(x)
# x = Activation('relu')(x)
# x = Dropout(0.5)(x)
# x = Activation('relu')(x)
# x = BatchNormalization()(x)
# x = Dense(NB_CLASSES)(x)
# out = Activation('softmax')(x)
# resnet_model = Model(inputs=resnet_model.input, outputs=out)


xception_model = Xception(weights='imagenet', 
                        include_top=False, 
                        input_tensor=models_input)

for layer in xception_model.layers:
    layer.name = "xception_" + layer.name
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False

        
xception_gap = GlobalAveragePooling2D()(xception_model.output)

# # x = GlobalAveragePooling2D()(vgg_model.output)
# x = Dense(256)(vgg_gap)
# x = Activation('relu')(x)
# x = Dropout(0.5)(x)
# x = Activation('relu')(x)
# vgg_out = BatchNormalization()(x)
# x = Dense(NB_CLASSES)(x)
# out = Activation('softmax')(x)

merged_nets = concatenate([vgg_gap, xception_gap])

# x = Dense(NB_CLASSES)(merged_nets)
# out = Activation('softmax')(x)

inputs = input_tensor=models_input
outputs = merged_nets # out # average([resnet_model.output, vgg_model.output])
model = Model(inputs, outputs)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 2s 0us/step
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.4/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 2s 0us/step

# %%
# model.compile(loss='categorical_crossentropy',
#               optimizer='adam',
#               metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# xception_vgg16_input_1 (InputLa (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# xception_block1_conv1 (Conv2D)  (None, 111, 111, 32) 864         xception_vgg16_input_1[0][0]
# __________________________________________________________________________________________________
# xception_block1_conv1_bn (Batch (None, 111, 111, 32) 128         xception_block1_conv1[0][0]
# __________________________________________________________________________________________________
# xception_block1_conv1_act (Acti (None, 111, 111, 32) 0           xception_block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# xception_block1_conv2 (Conv2D)  (None, 109, 109, 64) 18432       xception_block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# xception_block1_conv2_bn (Batch (None, 109, 109, 64) 256         xception_block1_conv2[0][0]
# __________________________________________________________________________________________________
# xception_block1_conv2_act (Acti (None, 109, 109, 64) 0           xception_block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# xception_block2_sepconv1 (Separ (None, 109, 109, 128 8768        xception_block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# xception_block2_sepconv1_bn (Ba (None, 109, 109, 128 512         xception_block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# xception_block2_sepconv2_act (A (None, 109, 109, 128 0           xception_block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# xception_block2_sepconv2 (Separ (None, 109, 109, 128 17536       xception_block2_sepconv2_act[0][0
# __________________________________________________________________________________________________
# xception_block2_sepconv2_bn (Ba (None, 109, 109, 128 512         xception_block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# xception_conv2d_1 (Conv2D)      (None, 55, 55, 128)  8192        xception_block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# xception_block2_pool (MaxPoolin (None, 55, 55, 128)  0           xception_block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# xception_batch_normalization_1  (None, 55, 55, 128)  512         xception_conv2d_1[0][0]
# __________________________________________________________________________________________________
# xception_add_1 (Add)            (None, 55, 55, 128)  0           xception_block2_pool[0][0]
#                                                                  xception_batch_normalization_1[0]
# __________________________________________________________________________________________________
# xception_block3_sepconv1_act (A (None, 55, 55, 128)  0           xception_add_1[0][0]
# __________________________________________________________________________________________________
# xception_block3_sepconv1 (Separ (None, 55, 55, 256)  33920       xception_block3_sepconv1_act[0][0
# __________________________________________________________________________________________________
# xception_block3_sepconv1_bn (Ba (None, 55, 55, 256)  1024        xception_block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# xception_block3_sepconv2_act (A (None, 55, 55, 256)  0           xception_block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# xception_block3_sepconv2 (Separ (None, 55, 55, 256)  67840       xception_block3_sepconv2_act[0][0
# __________________________________________________________________________________________________
# xception_block3_sepconv2_bn (Ba (None, 55, 55, 256)  1024        xception_block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# xception_conv2d_2 (Conv2D)      (None, 28, 28, 256)  32768       xception_add_1[0][0]
# __________________________________________________________________________________________________
# xception_block3_pool (MaxPoolin (None, 28, 28, 256)  0           xception_block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# xception_batch_normalization_2  (None, 28, 28, 256)  1024        xception_conv2d_2[0][0]
# __________________________________________________________________________________________________
# xception_add_2 (Add)            (None, 28, 28, 256)  0           xception_block3_pool[0][0]
#                                                                  xception_batch_normalization_2[0]
# __________________________________________________________________________________________________
# xception_block4_sepconv1_act (A (None, 28, 28, 256)  0           xception_add_2[0][0]
# __________________________________________________________________________________________________
# xception_block4_sepconv1 (Separ (None, 28, 28, 728)  188672      xception_block4_sepconv1_act[0][0
# __________________________________________________________________________________________________
# xception_block4_sepconv1_bn (Ba (None, 28, 28, 728)  2912        xception_block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# xception_block4_sepconv2_act (A (None, 28, 28, 728)  0           xception_block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# xception_block4_sepconv2 (Separ (None, 28, 28, 728)  536536      xception_block4_sepconv2_act[0][0
# __________________________________________________________________________________________________
# xception_block4_sepconv2_bn (Ba (None, 28, 28, 728)  2912        xception_block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# xception_conv2d_3 (Conv2D)      (None, 14, 14, 728)  186368      xception_add_2[0][0]
# __________________________________________________________________________________________________
# xception_block4_pool (MaxPoolin (None, 14, 14, 728)  0           xception_block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# xception_batch_normalization_3  (None, 14, 14, 728)  2912        xception_conv2d_3[0][0]
# __________________________________________________________________________________________________
# xception_add_3 (Add)            (None, 14, 14, 728)  0           xception_block4_pool[0][0]
#                                                                  xception_batch_normalization_3[0]
# __________________________________________________________________________________________________
# xception_block5_sepconv1_act (A (None, 14, 14, 728)  0           xception_add_3[0][0]
# __________________________________________________________________________________________________
# xception_block5_sepconv1 (Separ (None, 14, 14, 728)  536536      xception_block5_sepconv1_act[0][0
# __________________________________________________________________________________________________
# xception_block5_sepconv1_bn (Ba (None, 14, 14, 728)  2912        xception_block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# xception_block5_sepconv2_act (A (None, 14, 14, 728)  0           xception_block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# xception_block5_sepconv2 (Separ (None, 14, 14, 728)  536536      xception_block5_sepconv2_act[0][0
# __________________________________________________________________________________________________
# xception_block5_sepconv2_bn (Ba (None, 14, 14, 728)  2912        xception_block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# xception_block5_sepconv3_act (A (None, 14, 14, 728)  0           xception_block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# xception_block5_sepconv3 (Separ (None, 14, 14, 728)  536536      xception_block5_sepconv3_act[0][0
# __________________________________________________________________________________________________
# xception_block5_sepconv3_bn (Ba (None, 14, 14, 728)  2912        xception_block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# xception_add_4 (Add)            (None, 14, 14, 728)  0           xception_block5_sepconv3_bn[0][0]
#                                                                  xception_add_3[0][0]
# __________________________________________________________________________________________________
# xception_block6_sepconv1_act (A (None, 14, 14, 728)  0           xception_add_4[0][0]
# __________________________________________________________________________________________________
# xception_block6_sepconv1 (Separ (None, 14, 14, 728)  536536      xception_block6_sepconv1_act[0][0
# __________________________________________________________________________________________________
# xception_block6_sepconv1_bn (Ba (None, 14, 14, 728)  2912        xception_block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# xception_block6_sepconv2_act (A (None, 14, 14, 728)  0           xception_block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# xception_block6_sepconv2 (Separ (None, 14, 14, 728)  536536      xception_block6_sepconv2_act[0][0
# __________________________________________________________________________________________________
# xception_block6_sepconv2_bn (Ba (None, 14, 14, 728)  2912        xception_block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# xception_block6_sepconv3_act (A (None, 14, 14, 728)  0           xception_block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# xception_block6_sepconv3 (Separ (None, 14, 14, 728)  536536      xception_block6_sepconv3_act[0][0
# __________________________________________________________________________________________________
# xception_block6_sepconv3_bn (Ba (None, 14, 14, 728)  2912        xception_block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# xception_add_5 (Add)            (None, 14, 14, 728)  0           xception_block6_sepconv3_bn[0][0]
#                                                                  xception_add_4[0][0]
# __________________________________________________________________________________________________
# xception_block7_sepconv1_act (A (None, 14, 14, 728)  0           xception_add_5[0][0]
# __________________________________________________________________________________________________
# xception_block7_sepconv1 (Separ (None, 14, 14, 728)  536536      xception_block7_sepconv1_act[0][0
# __________________________________________________________________________________________________
# xception_block7_sepconv1_bn (Ba (None, 14, 14, 728)  2912        xception_block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# xception_block7_sepconv2_act (A (None, 14, 14, 728)  0           xception_block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# xception_block7_sepconv2 (Separ (None, 14, 14, 728)  536536      xception_block7_sepconv2_act[0][0
# __________________________________________________________________________________________________
# xception_block7_sepconv2_bn (Ba (None, 14, 14, 728)  2912        xception_block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# xception_block7_sepconv3_act (A (None, 14, 14, 728)  0           xception_block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# xception_block7_sepconv3 (Separ (None, 14, 14, 728)  536536      xception_block7_sepconv3_act[0][0
# __________________________________________________________________________________________________
# xception_block7_sepconv3_bn (Ba (None, 14, 14, 728)  2912        xception_block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# xception_add_6 (Add)            (None, 14, 14, 728)  0           xception_block7_sepconv3_bn[0][0]
#                                                                  xception_add_5[0][0]
# __________________________________________________________________________________________________
# xception_block8_sepconv1_act (A (None, 14, 14, 728)  0           xception_add_6[0][0]
# __________________________________________________________________________________________________
# xception_block8_sepconv1 (Separ (None, 14, 14, 728)  536536      xception_block8_sepconv1_act[0][0
# __________________________________________________________________________________________________
# xception_block8_sepconv1_bn (Ba (None, 14, 14, 728)  2912        xception_block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# xception_block8_sepconv2_act (A (None, 14, 14, 728)  0           xception_block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# xception_block8_sepconv2 (Separ (None, 14, 14, 728)  536536      xception_block8_sepconv2_act[0][0
# __________________________________________________________________________________________________
# xception_block8_sepconv2_bn (Ba (None, 14, 14, 728)  2912        xception_block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# xception_block8_sepconv3_act (A (None, 14, 14, 728)  0           xception_block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# xception_block8_sepconv3 (Separ (None, 14, 14, 728)  536536      xception_block8_sepconv3_act[0][0
# __________________________________________________________________________________________________
# xception_block8_sepconv3_bn (Ba (None, 14, 14, 728)  2912        xception_block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# xception_add_7 (Add)            (None, 14, 14, 728)  0           xception_block8_sepconv3_bn[0][0]
#                                                                  xception_add_6[0][0]
# __________________________________________________________________________________________________
# xception_block9_sepconv1_act (A (None, 14, 14, 728)  0           xception_add_7[0][0]
# __________________________________________________________________________________________________
# xception_block9_sepconv1 (Separ (None, 14, 14, 728)  536536      xception_block9_sepconv1_act[0][0
# __________________________________________________________________________________________________
# xception_block9_sepconv1_bn (Ba (None, 14, 14, 728)  2912        xception_block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# xception_block9_sepconv2_act (A (None, 14, 14, 728)  0           xception_block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# xception_block9_sepconv2 (Separ (None, 14, 14, 728)  536536      xception_block9_sepconv2_act[0][0
# __________________________________________________________________________________________________
# xception_block9_sepconv2_bn (Ba (None, 14, 14, 728)  2912        xception_block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# xception_block9_sepconv3_act (A (None, 14, 14, 728)  0           xception_block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# xception_block9_sepconv3 (Separ (None, 14, 14, 728)  536536      xception_block9_sepconv3_act[0][0
# __________________________________________________________________________________________________
# xception_block9_sepconv3_bn (Ba (None, 14, 14, 728)  2912        xception_block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# xception_add_8 (Add)            (None, 14, 14, 728)  0           xception_block9_sepconv3_bn[0][0]
#                                                                  xception_add_7[0][0]
# __________________________________________________________________________________________________
# xception_block10_sepconv1_act ( (None, 14, 14, 728)  0           xception_add_8[0][0]
# __________________________________________________________________________________________________
# xception_block10_sepconv1 (Sepa (None, 14, 14, 728)  536536      xception_block10_sepconv1_act[0][
# __________________________________________________________________________________________________
# xception_block10_sepconv1_bn (B (None, 14, 14, 728)  2912        xception_block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# xception_block10_sepconv2_act ( (None, 14, 14, 728)  0           xception_block10_sepconv1_bn[0][0
# __________________________________________________________________________________________________
# xception_block10_sepconv2 (Sepa (None, 14, 14, 728)  536536      xception_block10_sepconv2_act[0][
# __________________________________________________________________________________________________
# xception_block10_sepconv2_bn (B (None, 14, 14, 728)  2912        xception_block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# xception_block10_sepconv3_act ( (None, 14, 14, 728)  0           xception_block10_sepconv2_bn[0][0
# __________________________________________________________________________________________________
# xception_block10_sepconv3 (Sepa (None, 14, 14, 728)  536536      xception_block10_sepconv3_act[0][
# __________________________________________________________________________________________________
# xception_block10_sepconv3_bn (B (None, 14, 14, 728)  2912        xception_block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# xception_add_9 (Add)            (None, 14, 14, 728)  0           xception_block10_sepconv3_bn[0][0
#                                                                  xception_add_8[0][0]
# __________________________________________________________________________________________________
# xception_block11_sepconv1_act ( (None, 14, 14, 728)  0           xception_add_9[0][0]
# __________________________________________________________________________________________________
# xception_block11_sepconv1 (Sepa (None, 14, 14, 728)  536536      xception_block11_sepconv1_act[0][
# __________________________________________________________________________________________________
# xception_block11_sepconv1_bn (B (None, 14, 14, 728)  2912        xception_block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# xception_block11_sepconv2_act ( (None, 14, 14, 728)  0           xception_block11_sepconv1_bn[0][0
# __________________________________________________________________________________________________
# xception_block11_sepconv2 (Sepa (None, 14, 14, 728)  536536      xception_block11_sepconv2_act[0][
# __________________________________________________________________________________________________
# xception_block11_sepconv2_bn (B (None, 14, 14, 728)  2912        xception_block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# xception_block11_sepconv3_act ( (None, 14, 14, 728)  0           xception_block11_sepconv2_bn[0][0
# __________________________________________________________________________________________________
# xception_block11_sepconv3 (Sepa (None, 14, 14, 728)  536536      xception_block11_sepconv3_act[0][
# __________________________________________________________________________________________________
# xception_block11_sepconv3_bn (B (None, 14, 14, 728)  2912        xception_block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# xception_add_10 (Add)           (None, 14, 14, 728)  0           xception_block11_sepconv3_bn[0][0
#                                                                  xception_add_9[0][0]
# __________________________________________________________________________________________________
# xception_block12_sepconv1_act ( (None, 14, 14, 728)  0           xception_add_10[0][0]
# __________________________________________________________________________________________________
# xception_block12_sepconv1 (Sepa (None, 14, 14, 728)  536536      xception_block12_sepconv1_act[0][
# __________________________________________________________________________________________________
# xception_block12_sepconv1_bn (B (None, 14, 14, 728)  2912        xception_block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# xception_block12_sepconv2_act ( (None, 14, 14, 728)  0           xception_block12_sepconv1_bn[0][0
# __________________________________________________________________________________________________
# xception_block12_sepconv2 (Sepa (None, 14, 14, 728)  536536      xception_block12_sepconv2_act[0][
# __________________________________________________________________________________________________
# xception_block12_sepconv2_bn (B (None, 14, 14, 728)  2912        xception_block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# vgg16_block1_conv1 (Conv2D)     (None, 224, 224, 64) 1792        xception_vgg16_input_1[0][0]
# __________________________________________________________________________________________________
# xception_block12_sepconv3_act ( (None, 14, 14, 728)  0           xception_block12_sepconv2_bn[0][0
# __________________________________________________________________________________________________
# vgg16_block1_conv2 (Conv2D)     (None, 224, 224, 64) 36928       vgg16_block1_conv1[0][0]
# __________________________________________________________________________________________________
# xception_block12_sepconv3 (Sepa (None, 14, 14, 728)  536536      xception_block12_sepconv3_act[0][
# __________________________________________________________________________________________________
# vgg16_block1_pool (MaxPooling2D (None, 112, 112, 64) 0           vgg16_block1_conv2[0][0]
# __________________________________________________________________________________________________
# xception_block12_sepconv3_bn (B (None, 14, 14, 728)  2912        xception_block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# vgg16_block2_conv1 (Conv2D)     (None, 112, 112, 128 73856       vgg16_block1_pool[0][0]
# __________________________________________________________________________________________________
# xception_add_11 (Add)           (None, 14, 14, 728)  0           xception_block12_sepconv3_bn[0][0
#                                                                  xception_add_10[0][0]
# __________________________________________________________________________________________________
# vgg16_block2_conv2 (Conv2D)     (None, 112, 112, 128 147584      vgg16_block2_conv1[0][0]
# __________________________________________________________________________________________________
# xception_block13_sepconv1_act ( (None, 14, 14, 728)  0           xception_add_11[0][0]
# __________________________________________________________________________________________________
# vgg16_block2_pool (MaxPooling2D (None, 56, 56, 128)  0           vgg16_block2_conv2[0][0]
# __________________________________________________________________________________________________
# xception_block13_sepconv1 (Sepa (None, 14, 14, 728)  536536      xception_block13_sepconv1_act[0][
# __________________________________________________________________________________________________
# vgg16_block3_conv1 (Conv2D)     (None, 56, 56, 256)  295168      vgg16_block2_pool[0][0]
# __________________________________________________________________________________________________
# xception_block13_sepconv1_bn (B (None, 14, 14, 728)  2912        xception_block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# vgg16_block3_conv2 (Conv2D)     (None, 56, 56, 256)  590080      vgg16_block3_conv1[0][0]
# __________________________________________________________________________________________________
# xception_block13_sepconv2_act ( (None, 14, 14, 728)  0           xception_block13_sepconv1_bn[0][0
# __________________________________________________________________________________________________
# vgg16_block3_conv3 (Conv2D)     (None, 56, 56, 256)  590080      vgg16_block3_conv2[0][0]
# __________________________________________________________________________________________________
# xception_block13_sepconv2 (Sepa (None, 14, 14, 1024) 752024      xception_block13_sepconv2_act[0][
# __________________________________________________________________________________________________
# vgg16_block3_pool (MaxPooling2D (None, 28, 28, 256)  0           vgg16_block3_conv3[0][0]
# __________________________________________________________________________________________________
# xception_block13_sepconv2_bn (B (None, 14, 14, 1024) 4096        xception_block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# xception_conv2d_4 (Conv2D)      (None, 7, 7, 1024)   745472      xception_add_11[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_conv1 (Conv2D)     (None, 28, 28, 512)  1180160     vgg16_block3_pool[0][0]
# __________________________________________________________________________________________________
# xception_block13_pool (MaxPooli (None, 7, 7, 1024)   0           xception_block13_sepconv2_bn[0][0
# __________________________________________________________________________________________________
# xception_batch_normalization_4  (None, 7, 7, 1024)   4096        xception_conv2d_4[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_conv2 (Conv2D)     (None, 28, 28, 512)  2359808     vgg16_block4_conv1[0][0]
# __________________________________________________________________________________________________
# xception_add_12 (Add)           (None, 7, 7, 1024)   0           xception_block13_pool[0][0]
#                                                                  xception_batch_normalization_4[0]
# __________________________________________________________________________________________________
# vgg16_block4_conv3 (Conv2D)     (None, 28, 28, 512)  2359808     vgg16_block4_conv2[0][0]
# __________________________________________________________________________________________________
# xception_block14_sepconv1 (Sepa (None, 7, 7, 1536)   1582080     xception_add_12[0][0]
# __________________________________________________________________________________________________
# vgg16_block4_pool (MaxPooling2D (None, 14, 14, 512)  0           vgg16_block4_conv3[0][0]
# __________________________________________________________________________________________________
# xception_block14_sepconv1_bn (B (None, 7, 7, 1536)   6144        xception_block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# vgg16_block5_conv1 (Conv2D)     (None, 14, 14, 512)  2359808     vgg16_block4_pool[0][0]
# __________________________________________________________________________________________________
# xception_block14_sepconv1_act ( (None, 7, 7, 1536)   0           xception_block14_sepconv1_bn[0][0
# __________________________________________________________________________________________________
# vgg16_block5_conv2 (Conv2D)     (None, 14, 14, 512)  2359808     vgg16_block5_conv1[0][0]
# __________________________________________________________________________________________________
# xception_block14_sepconv2 (Sepa (None, 7, 7, 2048)   3159552     xception_block14_sepconv1_act[0][
# __________________________________________________________________________________________________
# vgg16_block5_conv3 (Conv2D)     (None, 14, 14, 512)  2359808     vgg16_block5_conv2[0][0]
# __________________________________________________________________________________________________
# xception_block14_sepconv2_bn (B (None, 7, 7, 2048)   8192        xception_block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# vgg16_block5_pool (MaxPooling2D (None, 7, 7, 512)    0           vgg16_block5_conv3[0][0]
# __________________________________________________________________________________________________
# xception_block14_sepconv2_act ( (None, 7, 7, 2048)   0           xception_block14_sepconv2_bn[0][0
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 512)          0           vgg16_block5_pool[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 2048)         0           xception_block14_sepconv2_act[0][
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2560)         0           global_average_pooling2d_1[0][0]
#                                                                  global_average_pooling2d_2[0][0]
# ==================================================================================================
# Total params: 35,576,168
# Trainable params: 54,528
# Non-trainable params: 35,521,640
# __________________________________________________________________________________________________

# %%
len(train_gen.x) // 60
# Out:
# 56

# %%
# # model.fit_generator(image_gen.flow(x_train, y_train.toarray(), batch_size=batch_size),
# #           steps_per_epoch=  x_train.shape[0]//batch_size,
# #           epochs=epochs,
# #           verbose=1,
# #           class_weight=class_weight_dic)

# hist = model.fit_generator(train_gen,
#                     steps_per_epoch=len(train_gen.x)//BATCH_SIZE,
#                     epochs=EPOCHS,
#                     validation_data=(X_val, y_val),
#                     validation_steps=X_val.shape[0]//BATCH_SIZE)

# %%
# hist = model.fit(X_train, 
#                  y_train, 
#                  batch_size=BATCH_SIZE, 
#                  epochs=3, 
#                  verbose=1, 
#                  callbacks=None, 
#                  validation_data=(X_val, y_val))

# %%
features, labels = model.predict(X_train), y_train

# %%
features.shape, labels.shape
# Out:
# ((3360, 2560), (3360, 3))

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(learning_rate=0.02, 
                    n_estimators=600, 
                    objective='multi:softmax', 
                    silent=True, 
                    nthread=1)

# %%
y_labels = np.argmax(labels,axis = 1)

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold


y_labels = np.argmax(labels,axis = 1) 

folds = 4
param_comb = 5

start = time.time()

# A parameter grid for XGBoost
params = {
        'learning_rate': [0.02, 0.05, 0.1, 0.2],
        'min_child_weight': [2, 3, 5, 10],
        'gamma': [0.8, 1, 1.5, 2, 5],
        'subsample': [0.5, 0.6, 0.7, 0.8],
        'colsample_bytree': [0.5, 0.6, 0.8, 1.0],
        'max_depth': [2, 3, 4, 5]
        }

xgb = XGBClassifier(learning_rate=0.02, 
                    n_estimators=600, 
                    objective='multi:softmax', 
                    silent=True, 
                    nthread=1)

skf = StratifiedKFold(n_splits=folds, shuffle = True, random_state = 2020)

random_search = RandomizedSearchCV(xgb, 
                                   param_distributions=params, 
                                   n_iter=param_comb, 
                                  #  scoring='roc_auc', 
                                   n_jobs=4, 
                                   cv=skf.split(features,y_labels), 
                                   verbose=3, 
                                   random_state=2020)

random_search.fit(features, y_labels)

end = time.time()
print('Time taken in random search: {0: .2f}'.format(end - start))
# Out:
# Fitting 4 folds for each of 5 candidates, totalling 20 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  20 out of  20 | elapsed: 57.6min remaining:    0.0s
# [Parallel(n_jobs=4)]: Done  20 out of  20 | elapsed: 57.6min finished
# Time taken in random search:  3776.59

# %%
best_score = random_search.best_score_
best_params = random_search.best_params_
print('Best Score using random search: \n', best_score)
print('Best Parameters using random search: \n', best_params)
# Out:
# Best Score using random search:
#  0.9511904761904763
# Best Parameters using random search:
#  {'subsample': 0.5, 'min_child_weight': 5, 'max_depth': 2, 'learning_rate': 0.1, 'gamma': 1.5, 'colsample_bytree': 1.0}
# Best Score using random search:
#  0.9511904761904763
# Best Parameters using random search:
#  {'subsample': 0.5, 'min_child_weight': 5, 'max_depth': 2, 'learning_rate': 0.1, 'gamma': 1.5, 'colsample_bytree': 1.0}

# %% [markdown]
# Best Score using random search:
#
#  0.9511904761904763
#
# Best Parameters using random search:
#
#  {'subsample': 0.5, 'min_child_weight': 5, 'max_depth': 2, 'learning_rate': 0.1, 'gamma': 1.5, 'colsample_bytree': 1.0}
# Best Score using random search:
#  0.9511904761904763
# Best Parameters using random search:
#  {'subsample': 0.5, 'min_child_weight': 5, 'max_depth': 2, 'learning_rate': 0.1, 'gamma': 1.5, 'colsample_bytree': 1.0}

# %%
# # # # Set best parameters given by random search 
# # # xgb = XGBClassifier(learning_rate=0.02, 
# # #                     n_estimators=600, 
# # #                     objective='multi:softmax', 
# # #                     silent=True, 
# # #                     nthread=1)
# xgb.set_params(subsample=0.6, 
#                min_child_weight=10, 
#                max_depth=5, 
#                gamma=1, 
#                learning_rate=0.05,
#               #  max_features=None,
#                colsample_bytree=0.6)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.6, gamma=1,
#               learning_rate=0.05, max_delta_step=0, max_depth=5,
#               min_child_weight=10, missing=None, n_estimators=600, n_jobs=1,
#               nthread=1, objective='multi:softmax', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#               subsample=0.6, verbosity=1)

# %%
# # # Set best parameters given by random search 
# # xgb = XGBClassifier(learning_rate=0.02, 
# #                     n_estimators=600, 
# #                     objective='multi:softmax', 
# #                     silent=True, 
# #                     nthread=1)
xgb.set_params(subsample=0.6, 
               min_child_weight=10, 
               max_depth=5, 
               gamma=1, 
               learning_rate=0.05,
              #  max_features=None,
               colsample_bytree=0.6)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.6, gamma=1,
#               learning_rate=0.05, max_delta_step=0, max_depth=5,
#               min_child_weight=10, missing=None, n_estimators=600, n_jobs=1,
#               nthread=1, objective='multi:softmax', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#               subsample=0.6, verbosity=1)

# %%
test_features, test_labels = model.predict(X_test), y_test

# %%
xgb.fit(features, y_labels, eval_metric="error", verbose=True)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.6, gamma=1,
#               learning_rate=0.05, max_delta_step=0, max_depth=5,
#               min_child_weight=10, missing=None, n_estimators=600, n_jobs=1,
#               nthread=1, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=True, subsample=0.6, verbosity=1)

# %%
predictions_xgb = xgb.predict(test_features)

# %%
y_test_labels = np.argmax(test_labels, axis = 1) 
accuracy_xgb = xgb.score(test_features, y_test_labels)

# %%
print("accuracy : ", accuracy_xgb)
# Out:
# accuracy :  0.9618518518518518

# %%
# model.evaluate(X_test, y_test)

# %%
# Confusion matrix
# Credit: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.round(cm, 2)
    thresh = np.max(cm) // 2 
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Y_pred = model.predict(X_test)
# Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Y_true = np.argmax(y_test,axis = 1) 
# confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)

# %%
# plot_confusion_matrix(confusion_mtx, classes = CLASSES)

# %%
Y_pred = predictions_xgb
# Y_pred_classes = np.argmax(Y_pred,axis = 1) 
Y_pred_classes = Y_pred
# Y_true = np.argmax(test_labels,axis = 1) 
Y_true = y_test_labels
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)

# %%
plot_confusion_matrix(confusion_mtx, classes = CLASSES)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# plot_confusion_matrix(confusion_mtx, classes = CLASSES, normalize=True)
conf_mat = confusion_matrix(Y_true, Y_pred_classes)
# Normalise
conf_mat_norm = conf_mat.astype('float') / conf_mat.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat_norm, annot=True, cmap=plt.cm.Blues, fmt='.2f', xticklabels=CLASSES, yticklabels=CLASSES)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show(block=False)

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_true, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88       383
#            1       0.99      0.97      0.98      2273
#            2       0.95      0.93      0.94        44
#
#     accuracy                           0.96      2700
#    macro avg       0.92      0.94      0.93      2700
# weighted avg       0.96      0.96      0.96      2700

# %%
model.save_weights('Covid19_Detection_pretrained_VGG_Resnet_XGB.h5')

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True, to_file='Covid19_Detection_pretrained_VGG_Resnet_XGB.png')

# %% [markdown]
# ### Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(random_state=2020)

# %%
# from sklearn.model_selection import GridSearchCV

# np.random.seed(2020)
# start = time.time()

# param_dist = {'max_depth': [2, 3, 4],
#               'bootstrap': [True, False],
#               'max_features': ['auto', 'sqrt', 'log2', None],
#               'criterion': ['gini', 'entropy']}

# cv_rf = GridSearchCV(rf_clf, cv = 2,
#                      param_grid=param_dist, 
#                      n_jobs = 3)

# cv_rf.fit(features, labels)
# print('Best Parameters using grid search: \n', cv_rf.best_params_)
# end = time.time()
# print('Time taken in grid search: {0: .2f}'.format(end - start))

# %%
# Set best parameters given by grid search 
rf_clf.set_params(bootstrap=True, criterion='entropy', max_depth=4, max_features=None)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=4, max_features=None,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=2020,
#                        verbose=0, warm_start=False)

# %%
rf_clf.fit(features, labels)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=4, max_features=None,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=2020,
#                        verbose=0, warm_start=False)

# %%
test_features, test_labels = model.predict(X_test), y_test

# %%
predictions_rf = rf_clf.predict(test_features)

# %%
accuracy_rf = rf_clf.score(test_features, test_labels)

# %%
print("accuracy : ", accuracy_rf)
# Out:
# accuracy :  0.9174074074074074
